# %%
from scipy.optimize import differential_evolution
import numpy as np

# %%
import numpy as np

def sumXExp2(x):
  sumX = 0  
  for value in x:
    sumX += np.power(value, 2)
  return sumX

def sumSinExp2Modx(x):
  sumX = 0
  for value in x:
    sumX += pow(np.sin(np.sqrt(abs(value))),2)
  return sumX

def term1Left(x):
  sum = 0
  for value in x:
    sum += pow(np.sin(value),2) - np.exp(-(sumXExp2(x)))
  return sum

def xinSheYangN4(x):
  value = term1Left(x) * np.exp(-(sumSinExp2Modx(x)))
  return value

# %%
bounds = [(-10, 10)]*10

# %% [markdown]
# **Strategy best1bin ---- CR = 0.9 & F = 0.8**

# %%
CR = 0.9
F = 0.8

for i in range(5):
  result = differential_evolution(xinSheYangN4, bounds, init = "random", mutation = F, recombination = CR, popsize=30, maxiter = 1200, strategy = "best1bin", disp=True)
  print( " -> " , result.nfev, " -> " , result.success, " -> " , result.fun)
  # summarize the result
  print(result)
# Out:
# differential_evolution step 1: f(x)= 0.0011005
# differential_evolution step 2: f(x)= 0.000595212
# differential_evolution step 3: f(x)= 0.000442483
# differential_evolution step 4: f(x)= 0.000442483
# differential_evolution step 5: f(x)= 0.000297736
# differential_evolution step 6: f(x)= 0.000297736
# differential_evolution step 7: f(x)= 0.000297736
# differential_evolution step 8: f(x)= 0.000297736
# differential_evolution step 9: f(x)= 0.000297736
# differential_evolution step 10: f(x)= 0.000297736
# differential_evolution step 11: f(x)= 0.000297736
# differential_evolution step 12: f(x)= 0.000247164
# differential_evolution step 13: f(x)= 0.000247164
# differential_evolution step 14: f(x)= 0.000247164
# differential_evolution step 15: f(x)= 0.000247164
# differential_evolution step 16: f(x)= 0.000247164
# differential_evolution step 17: f(x)= 0.000247164
# differential_evolution step 18: f(x)= 0.000247164
# differential_evolution step 19: f(x)= 0.000247164
# differential_evolution step 20: f(x)= 0.000247164
# differential_evolution step 21: f(x)= 0.000247164
# differential_evolution step 22: f(x)= 0.000247164
# differential_evolution step 23: f(x)= 0.000247164
# differential_evolution step 24: f(x)= 0.000247164
# differential_evolution step 25: f(x)= 0.000247164
# differential_evolution step 26: f(x)= 0.000247164
# differential_evolution step 27: f(x)= 0.000247164
# differential_evolution step 28: f(x)= 0.000247164
# differential_evolution step 29: f(x)= 0.000247164
# differential_evolution step 30: f(x)= 0.000142804
# differential_evolution step 31: f(x)= 0.000142804
# differential_evolution step 32: f(x)= 0.000142804
# differential_evolution step 33: f(x)= 0.000142804
# differential_evolution step 34: f(x)= 0.000142804
# differential_evolution step 35: f(x)= 0.000142804
# differential_evolution step 36: f(x)= 0.000142804
# differential_evolution step 37: f(x)= 0.000142804
# differential_evolution step 38: f(x)= 0.000142804
# differential_evolution step 39: f(x)= 0.000142804
# differential_evolution step 40: f(x)= 0.000142804
# differential_evolution step 41: f(x)= 0.000142804
# differential_evolution step 42: f(x)= 0.000142804
# differential_evolution step 43: f(x)= 0.000142804
# differential_evolution step 44: f(x)= 0.000142804
# differential_evolution step 45: f(x)= 0.000142804
# differential_evolution step 46: f(x)= 0.000142804
# differential_evolution step 47: f(x)= 0.000142804
# differential_evolution step 48: f(x)= 0.000142804
# differential_evolution step 49: f(x)= 0.000142804
# differential_evolution step 50: f(x)= 0.000142804
# differential_evolution step 51: f(x)= 0.000142804
# differential_evolution step 52: f(x)= 0.000142804
# differential_evolution step 53: f(x)= 0.000142804
# differential_evolution step 54: f(x)= 0.000142804
# differential_evolution step 55: f(x)= 0.000142804
# differential_evolution step 56: f(x)= 0.000142804
# differential_evolution step 57: f(x)= 0.000142804
# differential_evolution step 58: f(x)= 0.000113093
# differential_evolution step 59: f(x)= 0.000113093
# differential_evolution step 60: f(x)= 0.000113093
# differential_evolution step 61: f(x)= 0.000113093
# differential_evolution step 62: f(x)= 0.000113093
# differential_evolution step 63: f(x)= 0.000113093
# differential_evolution step 64: f(x)= 9.51697e-05
# differential_evolution step 65: f(x)= 9.51697e-05
# differential_evolution step 66: f(x)= 9.49825e-05
# differential_evolution step 67: f(x)= 9.49825e-05
# differential_evolution step 68: f(x)= 9.49825e-05
# differential_evolution step 69: f(x)= 9.49825e-05
# differential_evolution step 70: f(x)= 9.49825e-05
# differential_evolution step 71: f(x)= 7.19466e-05
# differential_evolution step 72: f(x)= 6.61923e-05
# differential_evolution step 73: f(x)= 6.61923e-05
# differential_evolution step 74: f(x)= 6.61923e-05
# differential_evolution step 75: f(x)= 5.67976e-05
# differential_evolution step 76: f(x)= 5.67976e-05
# differential_evolution step 77: f(x)= 5.01946e-05
# differential_evolution step 78: f(x)= 5.01946e-05
# differential_evolution step 79: f(x)= 5.01946e-05
# differential_evolution step 80: f(x)= 4.88876e-05
# differential_evolution step 81: f(x)= 4.22089e-05
# differential_evolution step 82: f(x)= 2.96642e-05
# differential_evolution step 83: f(x)= 2.96479e-05
# differential_evolution step 84: f(x)= 2.96479e-05
# differential_evolution step 85: f(x)= 1.42096e-05
# differential_evolution step 86: f(x)= 1.42096e-05
# differential_evolution step 87: f(x)= 1.42096e-05
# differential_evolution step 88: f(x)= 1.42096e-05
# differential_evolution step 89: f(x)= 1.42096e-05
# differential_evolution step 90: f(x)= 1.42096e-05
# differential_evolution step 91: f(x)= 1.42096e-05
# differential_evolution step 92: f(x)= 1.06195e-05
# differential_evolution step 93: f(x)= 6.13227e-06
# differential_evolution step 94: f(x)= 6.13227e-06
# differential_evolution step 95: f(x)= 6.13227e-06
# differential_evolution step 96: f(x)= 6.13227e-06
# differential_evolution step 97: f(x)= 6.13227e-06
# differential_evolution step 98: f(x)= 6.13227e-06
# differential_evolution step 99: f(x)= 6.13227e-06
# differential_evolution step 100: f(x)= 2.86779e-06
# differential_evolution step 101: f(x)= 2.86779e-06
# differential_evolution step 102: f(x)= 2.82011e-06
# differential_evolution step 103: f(x)= 2.82011e-06
# differential_evolution step 104: f(x)= 2.82011e-06
# differential_evolution step 105: f(x)= 2.82011e-06
# differential_evolution step 106: f(x)= 2.22166e-06
# differential_evolution step 107: f(x)= 2.22166e-06
# differential_evolution step 108: f(x)= 9.4564e-07
# differential_evolution step 109: f(x)= 9.4564e-07
# differential_evolution step 110: f(x)= 9.4564e-07
# differential_evolution step 111: f(x)= 9.41361e-07
# differential_evolution step 112: f(x)= 7.04366e-07
# differential_evolution step 113: f(x)= 6.28087e-07
# differential_evolution step 114: f(x)= 6.28087e-07
# differential_evolution step 115: f(x)= 6.28087e-07
# differential_evolution step 116: f(x)= 2.86024e-07
# differential_evolution step 117: f(x)= 2.80197e-07
# differential_evolution step 118: f(x)= 2.80197e-07
# differential_evolution step 119: f(x)= 2.80197e-07
# differential_evolution step 120: f(x)= 2.80197e-07
# differential_evolution step 121: f(x)= 2.80197e-07
# differential_evolution step 122: f(x)= 2.38829e-07
# differential_evolution step 123: f(x)= 2.38829e-07
# differential_evolution step 124: f(x)= 1.69957e-07
# differential_evolution step 125: f(x)= 1.69957e-07
# differential_evolution step 126: f(x)= 1.69957e-07
# differential_evolution step 127: f(x)= 1.69957e-07
# differential_evolution step 128: f(x)= 1.28835e-07
# differential_evolution step 129: f(x)= 1.23297e-07
# differential_evolution step 130: f(x)= 1.11187e-07
# differential_evolution step 131: f(x)= 8.84056e-08
# differential_evolution step 132: f(x)= 8.84056e-08
# differential_evolution step 133: f(x)= 6.59176e-08
# differential_evolution step 134: f(x)= 5.0929e-08
# differential_evolution step 135: f(x)= 5.0929e-08
# differential_evolution step 136: f(x)= 5.0929e-08
# differential_evolution step 137: f(x)= 4.50338e-08
# differential_evolution step 138: f(x)= 4.50338e-08
# differential_evolution step 139: f(x)= 4.50338e-08
# differential_evolution step 140: f(x)= 4.50338e-08
# differential_evolution step 141: f(x)= 3.29602e-08
# differential_evolution step 142: f(x)= 2.85493e-08
# differential_evolution step 143: f(x)= 2.36219e-08
# differential_evolution step 144: f(x)= 1.61512e-08
# differential_evolution step 145: f(x)= 1.5914e-08
# differential_evolution step 146: f(x)= 1.01539e-08
# differential_evolution step 147: f(x)= 1.01539e-08
# differential_evolution step 148: f(x)= 1.01539e-08
# differential_evolution step 149: f(x)= 1.01539e-08
# differential_evolution step 150: f(x)= 1.01539e-08
# differential_evolution step 151: f(x)= 8.46452e-09
# differential_evolution step 152: f(x)= 8.46452e-09
# differential_evolution step 153: f(x)= 5.22383e-09
# differential_evolution step 154: f(x)= 5.22383e-09
# differential_evolution step 155: f(x)= 5.22383e-09
# differential_evolution step 156: f(x)= 4.22803e-09
# differential_evolution step 157: f(x)= 4.22803e-09
# differential_evolution step 158: f(x)= 4.22803e-09
# differential_evolution step 159: f(x)= 3.96665e-09
# differential_evolution step 160: f(x)= 3.88021e-09
# differential_evolution step 161: f(x)= 2.64095e-09
# differential_evolution step 162: f(x)= 2.31333e-09
# differential_evolution step 163: f(x)= 2.31333e-09
# differential_evolution step 164: f(x)= 1.65388e-09
# differential_evolution step 165: f(x)= 1.65388e-09
# differential_evolution step 166: f(x)= 1.65388e-09
# differential_evolution step 167: f(x)= 1.50813e-09
# differential_evolution step 168: f(x)= 1.50813e-09
# differential_evolution step 169: f(x)= 1.47742e-09
# differential_evolution step 170: f(x)= 1.47742e-09
# differential_evolution step 171: f(x)= 1.10292e-09
# differential_evolution step 172: f(x)= 8.27883e-10
# differential_evolution step 173: f(x)= 8.27883e-10
# differential_evolution step 174: f(x)= 8.27883e-10
# differential_evolution step 175: f(x)= 2.85549e-10
# differential_evolution step 176: f(x)= 2.85549e-10
# differential_evolution step 177: f(x)= 2.85549e-10
# differential_evolution step 178: f(x)= 2.85549e-10
# differential_evolution step 179: f(x)= 2.65484e-10
# differential_evolution step 180: f(x)= 2.65484e-10
# differential_evolution step 181: f(x)= 1.71235e-10
# differential_evolution step 182: f(x)= 1.71235e-10
# differential_evolution step 183: f(x)= 1.71235e-10
# differential_evolution step 184: f(x)= 1.15756e-10
# differential_evolution step 185: f(x)= 1.15756e-10
# differential_evolution step 186: f(x)= 1.15756e-10
# differential_evolution step 187: f(x)= 6.8367e-11
# differential_evolution step 188: f(x)= 6.8367e-11
# differential_evolution step 189: f(x)= 6.8367e-11
# differential_evolution step 190: f(x)= 6.8367e-11
# differential_evolution step 191: f(x)= 6.14328e-11
# differential_evolution step 192: f(x)= 6.14328e-11
# differential_evolution step 193: f(x)= 6.14328e-11
# differential_evolution step 194: f(x)= 6.14328e-11
# differential_evolution step 195: f(x)= 4.65533e-11
# differential_evolution step 196: f(x)= 3.88756e-11
# differential_evolution step 197: f(x)= 2.40904e-11
# differential_evolution step 198: f(x)= 2.1051e-11
# differential_evolution step 199: f(x)= 1.71025e-11
# differential_evolution step 200: f(x)= 1.71025e-11
# differential_evolution step 201: f(x)= 1.71025e-11
# differential_evolution step 202: f(x)= 1.71025e-11
# differential_evolution step 203: f(x)= 1.71025e-11
# differential_evolution step 204: f(x)= 1.36623e-11
# differential_evolution step 205: f(x)= 1.15469e-11
# differential_evolution step 206: f(x)= 8.83095e-12
# differential_evolution step 207: f(x)= 8.83095e-12
# differential_evolution step 208: f(x)= 6.96552e-12
# differential_evolution step 209: f(x)= 5.78491e-12
# differential_evolution step 210: f(x)= 3.31304e-12
# differential_evolution step 211: f(x)= 3.31304e-12
# differential_evolution step 212: f(x)= 3.31304e-12
# differential_evolution step 213: f(x)= 3.31304e-12
# differential_evolution step 214: f(x)= 3.31304e-12
# differential_evolution step 215: f(x)= 3.31304e-12
# differential_evolution step 216: f(x)= 3.21402e-12
# differential_evolution step 217: f(x)= 3.13685e-12
# differential_evolution step 218: f(x)= 7.90575e-13
# differential_evolution step 219: f(x)= 7.90575e-13
# differential_evolution step 220: f(x)= 7.90575e-13
# differential_evolution step 221: f(x)= 7.90575e-13
# differential_evolution step 222: f(x)= 7.90575e-13
# differential_evolution step 223: f(x)= 7.90575e-13
# differential_evolution step 224: f(x)= 7.40583e-13
# differential_evolution step 225: f(x)= 3.97127e-13
# differential_evolution step 226: f(x)= 3.97127e-13
# differential_evolution step 227: f(x)= 3.97127e-13
# differential_evolution step 228: f(x)= 3.97127e-13
# differential_evolution step 229: f(x)= 3.97127e-13
# differential_evolution step 230: f(x)= 3.97127e-13
# differential_evolution step 231: f(x)= 3.97127e-13
# differential_evolution step 232: f(x)= 2.35509e-13
# differential_evolution step 233: f(x)= 2.35509e-13
# differential_evolution step 234: f(x)= 2.35509e-13
# differential_evolution step 235: f(x)= 1.92046e-13
# differential_evolution step 236: f(x)= 1.01965e-13
# differential_evolution step 237: f(x)= 1.01965e-13
# differential_evolution step 238: f(x)= 1.01965e-13
# differential_evolution step 239: f(x)= 1.01965e-13
# differential_evolution step 240: f(x)= 1.01965e-13
# differential_evolution step 241: f(x)= 8.16157e-14
# differential_evolution step 242: f(x)= 5.92791e-14
# differential_evolution step 243: f(x)= 5.54785e-14
# differential_evolution step 244: f(x)= 4.99756e-14
# differential_evolution step 245: f(x)= 4.99756e-14
# differential_evolution step 246: f(x)= 4.99756e-14
# differential_evolution step 247: f(x)= 4.99756e-14
# differential_evolution step 248: f(x)= 3.47758e-14
# differential_evolution step 249: f(x)= 3.47758e-14
# differential_evolution step 250: f(x)= 3.47758e-14
# differential_evolution step 251: f(x)= 3.47758e-14
# differential_evolution step 252: f(x)= 3.40458e-14
# differential_evolution step 253: f(x)= 2.94324e-14
# differential_evolution step 254: f(x)= 2.18498e-14
# differential_evolution step 255: f(x)= 2.18498e-14
# differential_evolution step 256: f(x)= 1.85752e-14
# differential_evolution step 257: f(x)= 1.34544e-14
# differential_evolution step 258: f(x)= 1.34544e-14
# differential_evolution step 259: f(x)= 1.00529e-14
# differential_evolution step 260: f(x)= 5.01747e-15
# differential_evolution step 261: f(x)= 5.01747e-15
# differential_evolution step 262: f(x)= 5.01747e-15
# differential_evolution step 263: f(x)= 5.01747e-15
# differential_evolution step 264: f(x)= 5.01747e-15
# differential_evolution step 265: f(x)= 4.26196e-15
# differential_evolution step 266: f(x)= 3.75218e-15
# differential_evolution step 267: f(x)= 3.42044e-15
# differential_evolution step 268: f(x)= 3.42044e-15
# differential_evolution step 269: f(x)= 3.42044e-15
# differential_evolution step 270: f(x)= 3.00173e-15
# differential_evolution step 271: f(x)= 3.00173e-15
# differential_evolution step 272: f(x)= 3.00173e-15
# differential_evolution step 273: f(x)= 2.57147e-15
# differential_evolution step 274: f(x)= 1.90944e-15
# differential_evolution step 275: f(x)= 1.90944e-15
# differential_evolution step 276: f(x)= 1.74446e-15
# differential_evolution step 277: f(x)= 1.35942e-15
# differential_evolution step 278: f(x)= 1.06185e-15
# differential_evolution step 279: f(x)= 5.63988e-16
# differential_evolution step 280: f(x)= 5.63988e-16
# differential_evolution step 281: f(x)= 5.63988e-16
# differential_evolution step 282: f(x)= 5.52737e-16
# differential_evolution step 283: f(x)= 5.52737e-16
# differential_evolution step 284: f(x)= 4.76714e-16
# differential_evolution step 285: f(x)= 4.76714e-16
# differential_evolution step 286: f(x)= 4.76714e-16
# differential_evolution step 287: f(x)= 3.24484e-16
# differential_evolution step 288: f(x)= 3.24484e-16
# differential_evolution step 289: f(x)= 3.12868e-16
# differential_evolution step 290: f(x)= 3.12868e-16
# differential_evolution step 291: f(x)= 1.79911e-16
# differential_evolution step 292: f(x)= 1.79911e-16
# differential_evolution step 293: f(x)= 1.79911e-16
# differential_evolution step 294: f(x)= 1.79911e-16
# differential_evolution step 295: f(x)= 1.79911e-16
# differential_evolution step 296: f(x)= 1.53846e-16
# differential_evolution step 297: f(x)= 1.53846e-16
# differential_evolution step 298: f(x)= 1.23552e-16
# differential_evolution step 299: f(x)= 8.49714e-17
# differential_evolution step 300: f(x)= 6.37664e-17
# differential_evolution step 301: f(x)= 6.37664e-17
# differential_evolution step 302: f(x)= 4.19512e-17
# differential_evolution step 303: f(x)= 4.19512e-17
# differential_evolution step 304: f(x)= 4.19512e-17
# differential_evolution step 305: f(x)= 4.19512e-17
# differential_evolution step 306: f(x)= 3.91052e-17
# differential_evolution step 307: f(x)= 3.91052e-17
# differential_evolution step 308: f(x)= 3.91052e-17
# differential_evolution step 309: f(x)= 2.6316e-17
# differential_evolution step 310: f(x)= 2.6316e-17
# differential_evolution step 311: f(x)= 2.57837e-17
# differential_evolution step 312: f(x)= 2.33987e-17
# differential_evolution step 313: f(x)= 9.76731e-18
# differential_evolution step 314: f(x)= 9.76731e-18
# differential_evolution step 315: f(x)= 8.77585e-18
# differential_evolution step 316: f(x)= 8.77585e-18
# differential_evolution step 317: f(x)= 8.77585e-18
# differential_evolution step 318: f(x)= 8.77585e-18
# differential_evolution step 319: f(x)= 8.77585e-18
# differential_evolution step 320: f(x)= 3.3736e-18
# differential_evolution step 321: f(x)= 3.3736e-18
# differential_evolution step 322: f(x)= 3.3736e-18
# differential_evolution step 323: f(x)= 3.3736e-18
# differential_evolution step 324: f(x)= 3.3736e-18
# differential_evolution step 325: f(x)= 3.3736e-18
# differential_evolution step 326: f(x)= 3.3736e-18
# differential_evolution step 327: f(x)= 3.3736e-18
# differential_evolution step 328: f(x)= 2.94644e-18
# differential_evolution step 329: f(x)= 2.94644e-18
# differential_evolution step 330: f(x)= 2.68853e-18
# differential_evolution step 331: f(x)= 1.80455e-18
# differential_evolution step 332: f(x)= 1.33911e-18
# differential_evolution step 333: f(x)= 1.33911e-18
# differential_evolution step 334: f(x)= 1.00767e-18
# differential_evolution step 335: f(x)= 1.00767e-18
# differential_evolution step 336: f(x)= 1.00767e-18
# differential_evolution step 337: f(x)= 9.11353e-19
# differential_evolution step 338: f(x)= 7.93252e-19
# differential_evolution step 339: f(x)= 7.93252e-19
# differential_evolution step 340: f(x)= 6.04013e-19
# differential_evolution step 341: f(x)= 6.04013e-19
# differential_evolution step 342: f(x)= 6.04013e-19
# differential_evolution step 343: f(x)= 5.72697e-19
# differential_evolution step 344: f(x)= 2.81213e-19
# differential_evolution step 345: f(x)= 2.81213e-19
# differential_evolution step 346: f(x)= 2.81213e-19
# differential_evolution step 347: f(x)= 2.81213e-19
# differential_evolution step 348: f(x)= 2.66385e-19
# differential_evolution step 349: f(x)= 2.66385e-19
# differential_evolution step 350: f(x)= 2.1637e-19
# differential_evolution step 351: f(x)= 1.38911e-19
# differential_evolution step 352: f(x)= 1.01121e-19
# differential_evolution step 353: f(x)= 1.01121e-19
# differential_evolution step 354: f(x)= 1.01121e-19
# differential_evolution step 355: f(x)= 9.45189e-20
# differential_evolution step 356: f(x)= 9.45189e-20
# differential_evolution step 357: f(x)= 9.45189e-20
# differential_evolution step 358: f(x)= 9.45189e-20
# differential_evolution step 359: f(x)= 6.67933e-20
# differential_evolution step 360: f(x)= 6.07813e-20
# differential_evolution step 361: f(x)= 4.74121e-20
# differential_evolution step 362: f(x)= 4.74121e-20
# differential_evolution step 363: f(x)= 4.5361e-20
# differential_evolution step 364: f(x)= 3.54145e-20
# differential_evolution step 365: f(x)= 3.54145e-20
# differential_evolution step 366: f(x)= 3.15439e-20
# differential_evolution step 367: f(x)= 2.0322e-20
# differential_evolution step 368: f(x)= 2.0322e-20
# differential_evolution step 369: f(x)= 2.0322e-20
# differential_evolution step 370: f(x)= 2.0322e-20
# differential_evolution step 371: f(x)= 7.88125e-21
# differential_evolution step 372: f(x)= 7.88125e-21
# differential_evolution step 373: f(x)= 7.88125e-21
# differential_evolution step 374: f(x)= 7.88125e-21
# differential_evolution step 375: f(x)= 7.88125e-21
# differential_evolution step 376: f(x)= 7.88125e-21
# differential_evolution step 377: f(x)= 7.88125e-21
# differential_evolution step 378: f(x)= 5.82315e-21
# differential_evolution step 379: f(x)= 3.73354e-21
# differential_evolution step 380: f(x)= 1.5346e-21
# differential_evolution step 381: f(x)= 1.5346e-21
# differential_evolution step 382: f(x)= 1.5346e-21
# differential_evolution step 383: f(x)= 1.5346e-21
# differential_evolution step 384: f(x)= 1.5346e-21
# differential_evolution step 385: f(x)= 1.5346e-21
# differential_evolution step 386: f(x)= 1.5346e-21
# differential_evolution step 387: f(x)= 1.5346e-21
# differential_evolution step 388: f(x)= 1.5346e-21
# differential_evolution step 389: f(x)= 1.5346e-21
# differential_evolution step 390: f(x)= 1.5346e-21
# differential_evolution step 391: f(x)= 1.5346e-21
# differential_evolution step 392: f(x)= 1.06092e-21
# differential_evolution step 393: f(x)= 6.68538e-22
# differential_evolution step 394: f(x)= 6.68538e-22
# differential_evolution step 395: f(x)= 6.68538e-22
# differential_evolution step 396: f(x)= 6.22884e-22
# differential_evolution step 397: f(x)= 3.77598e-22
# differential_evolution step 398: f(x)= 3.13616e-22
# differential_evolution step 399: f(x)= 3.13616e-22
# differential_evolution step 400: f(x)= 2.3834e-22
# differential_evolution step 401: f(x)= 2.3834e-22
# differential_evolution step 402: f(x)= 2.3834e-22
# differential_evolution step 403: f(x)= 2.3834e-22
# differential_evolution step 404: f(x)= 2.3834e-22
# differential_evolution step 405: f(x)= 1.61653e-22
# differential_evolution step 406: f(x)= 1.61653e-22
# differential_evolution step 407: f(x)= 1.61653e-22
# differential_evolution step 408: f(x)= 1.34048e-22
# differential_evolution step 409: f(x)= 1.34048e-22
# differential_evolution step 410: f(x)= 1.09878e-22
# differential_evolution step 411: f(x)= 6.62953e-23
# differential_evolution step 412: f(x)= 6.59668e-23
# differential_evolution step 413: f(x)= 6.59668e-23
# differential_evolution step 414: f(x)= 6.59668e-23
# differential_evolution step 415: f(x)= 5.7029e-23
# differential_evolution step 416: f(x)= 4.9409e-23
# differential_evolution step 417: f(x)= 4.9409e-23
# differential_evolution step 418: f(x)= 4.9409e-23
# differential_evolution step 419: f(x)= 4.9409e-23
# differential_evolution step 420: f(x)= 4.9409e-23
# differential_evolution step 421: f(x)= 2.66255e-23
# differential_evolution step 422: f(x)= 1.69562e-23
# differential_evolution step 423: f(x)= 1.69562e-23
# differential_evolution step 424: f(x)= 1.46739e-23
# differential_evolution step 425: f(x)= 1.46739e-23
# differential_evolution step 426: f(x)= 1.46739e-23
# differential_evolution step 427: f(x)= 1.46739e-23
# differential_evolution step 428: f(x)= 1.11452e-23
# differential_evolution step 429: f(x)= 8.66755e-24
# differential_evolution step 430: f(x)= 8.66755e-24
# differential_evolution step 431: f(x)= 8.66755e-24
# differential_evolution step 432: f(x)= 8.66755e-24
# differential_evolution step 433: f(x)= 8.66755e-24
# differential_evolution step 434: f(x)= 7.13623e-24
# differential_evolution step 435: f(x)= 7.13623e-24
# differential_evolution step 436: f(x)= 7.13623e-24
# differential_evolution step 437: f(x)= 5.04331e-24
# differential_evolution step 438: f(x)= 3.9514e-24
# differential_evolution step 439: f(x)= 3.9514e-24
# differential_evolution step 440: f(x)= 3.9514e-24
# differential_evolution step 441: f(x)= 3.87351e-24
# differential_evolution step 442: f(x)= 3.36221e-24
# differential_evolution step 443: f(x)= 3.16229e-24
# differential_evolution step 444: f(x)= 2.65816e-24
# differential_evolution step 445: f(x)= 2.65816e-24
# differential_evolution step 446: f(x)= 1.9395e-24
# differential_evolution step 447: f(x)= 1.9395e-24
# differential_evolution step 448: f(x)= 1.84461e-24
# differential_evolution step 449: f(x)= 1.84461e-24
# differential_evolution step 450: f(x)= 1.67236e-24
# differential_evolution step 451: f(x)= 9.99571e-25
# differential_evolution step 452: f(x)= 3.7266e-25
# differential_evolution step 453: f(x)= 3.7266e-25
# differential_evolution step 454: f(x)= 3.7266e-25
# differential_evolution step 455: f(x)= 3.7266e-25
# differential_evolution step 456: f(x)= 3.7266e-25
# differential_evolution step 457: f(x)= 2.29345e-25
# differential_evolution step 458: f(x)= 2.29345e-25
# differential_evolution step 459: f(x)= 2.29345e-25
# differential_evolution step 460: f(x)= 2.29345e-25
# differential_evolution step 461: f(x)= 2.29345e-25
# differential_evolution step 462: f(x)= 2.29345e-25
# differential_evolution step 463: f(x)= 2.29345e-25
# differential_evolution step 464: f(x)= 2.29345e-25
# differential_evolution step 465: f(x)= 2.29345e-25
# differential_evolution step 466: f(x)= 2.21267e-25
# differential_evolution step 467: f(x)= 1.56413e-25
# differential_evolution step 468: f(x)= 8.55232e-26
# differential_evolution step 469: f(x)= 8.55232e-26
# differential_evolution step 470: f(x)= 8.55232e-26
# differential_evolution step 471: f(x)= 8.55232e-26
# differential_evolution step 472: f(x)= 4.0731e-26
# differential_evolution step 473: f(x)= 4.0731e-26
# differential_evolution step 474: f(x)= 4.0731e-26
# differential_evolution step 475: f(x)= 4.0731e-26
# differential_evolution step 476: f(x)= 4.0731e-26
# differential_evolution step 477: f(x)= 3.19125e-26
# differential_evolution step 478: f(x)= 3.19125e-26
# differential_evolution step 479: f(x)= 3.19125e-26
# differential_evolution step 480: f(x)= 2.51682e-26
# differential_evolution step 481: f(x)= 2.51682e-26
# differential_evolution step 482: f(x)= 2.51682e-26
# differential_evolution step 483: f(x)= 2.20359e-26
# differential_evolution step 484: f(x)= 2.12891e-26
# differential_evolution step 485: f(x)= 2.12891e-26
# differential_evolution step 486: f(x)= 2.12891e-26
# differential_evolution step 487: f(x)= 1.68459e-26
# differential_evolution step 488: f(x)= 1.2373e-26
# differential_evolution step 489: f(x)= 8.71335e-27
# differential_evolution step 490: f(x)= 6.74358e-27
# differential_evolution step 491: f(x)= 6.74358e-27
# differential_evolution step 492: f(x)= 6.74358e-27
# differential_evolution step 493: f(x)= 6.74358e-27
# differential_evolution step 494: f(x)= 5.65608e-27
# differential_evolution step 495: f(x)= 3.25703e-27
# differential_evolution step 496: f(x)= 3.25703e-27
# differential_evolution step 497: f(x)= 3.25703e-27
# differential_evolution step 498: f(x)= 3.25703e-27
# differential_evolution step 499: f(x)= 3.25703e-27
# differential_evolution step 500: f(x)= 3.25703e-27
# differential_evolution step 501: f(x)= 3.25699e-27
# differential_evolution step 502: f(x)= 2.84162e-27
# differential_evolution step 503: f(x)= 2.56403e-27
# differential_evolution step 504: f(x)= 7.10998e-28
# differential_evolution step 505: f(x)= 7.10998e-28
# differential_evolution step 506: f(x)= 5.6455e-28
# differential_evolution step 507: f(x)= 5.6455e-28
# differential_evolution step 508: f(x)= 5.6455e-28
# differential_evolution step 509: f(x)= 5.6455e-28
# differential_evolution step 510: f(x)= 5.07854e-28
# differential_evolution step 511: f(x)= 5.07854e-28
# differential_evolution step 512: f(x)= 5.07854e-28
# differential_evolution step 513: f(x)= 5.07854e-28
# differential_evolution step 514: f(x)= 4.50621e-28
# differential_evolution step 515: f(x)= 4.10099e-28
# differential_evolution step 516: f(x)= 3.26987e-28
# differential_evolution step 517: f(x)= 3.26987e-28
# differential_evolution step 518: f(x)= 2.416e-28
# differential_evolution step 519: f(x)= 1.98479e-28
# differential_evolution step 520: f(x)= 9.51193e-29
# differential_evolution step 521: f(x)= 9.51193e-29
# differential_evolution step 522: f(x)= 9.51193e-29
# differential_evolution step 523: f(x)= 9.51193e-29
# differential_evolution step 524: f(x)= 9.51193e-29
# differential_evolution step 525: f(x)= 7.64384e-29
# differential_evolution step 526: f(x)= 7.64384e-29
# differential_evolution step 527: f(x)= 7.64384e-29
# differential_evolution step 528: f(x)= 7.64384e-29
# differential_evolution step 529: f(x)= 7.64384e-29
# differential_evolution step 530: f(x)= 7.53814e-29
# differential_evolution step 531: f(x)= 6.70402e-29
# differential_evolution step 532: f(x)= 3.6795e-29
# differential_evolution step 533: f(x)= 3.6795e-29
# differential_evolution step 534: f(x)= 3.6795e-29
# differential_evolution step 535: f(x)= 3.6795e-29
# differential_evolution step 536: f(x)= 3.6795e-29
# differential_evolution step 537: f(x)= 1.88002e-29
# differential_evolution step 538: f(x)= 1.88002e-29
# differential_evolution step 539: f(x)= 1.69451e-29
# differential_evolution step 540: f(x)= 1.69451e-29
# differential_evolution step 541: f(x)= 1.69451e-29
# differential_evolution step 542: f(x)= 1.69451e-29
# differential_evolution step 543: f(x)= 1.37978e-29
# differential_evolution step 544: f(x)= 1.31548e-29
# differential_evolution step 545: f(x)= 9.7225e-30
# differential_evolution step 546: f(x)= 5.99292e-30
# differential_evolution step 547: f(x)= 5.99292e-30
# differential_evolution step 548: f(x)= 5.99292e-30
# differential_evolution step 549: f(x)= 4.97478e-30
# differential_evolution step 550: f(x)= 2.15558e-30
# differential_evolution step 551: f(x)= 2.15558e-30
# differential_evolution step 552: f(x)= 2.15558e-30
# differential_evolution step 553: f(x)= 2.15558e-30
# differential_evolution step 554: f(x)= 2.15558e-30
# differential_evolution step 555: f(x)= 2.15558e-30
# differential_evolution step 556: f(x)= 2.15558e-30
# differential_evolution step 557: f(x)= 8.48451e-31
# differential_evolution step 558: f(x)= 8.48451e-31
# differential_evolution step 559: f(x)= 8.48451e-31
# differential_evolution step 560: f(x)= 8.48451e-31
# differential_evolution step 561: f(x)= 8.48451e-31
# differential_evolution step 562: f(x)= 8.48451e-31
# differential_evolution step 563: f(x)= 7.66893e-31
# differential_evolution step 564: f(x)= 7.66893e-31
# differential_evolution step 565: f(x)= 3.55886e-31
# differential_evolution step 566: f(x)= 3.55886e-31
# differential_evolution step 567: f(x)= 3.55886e-31
# differential_evolution step 568: f(x)= 3.55886e-31
# differential_evolution step 569: f(x)= 3.55886e-31
# differential_evolution step 570: f(x)= 3.55886e-31
# differential_evolution step 571: f(x)= 3.55886e-31
# differential_evolution step 572: f(x)= 3.55886e-31
# differential_evolution step 573: f(x)= 2.21477e-31
# differential_evolution step 574: f(x)= 2.21477e-31
# differential_evolution step 575: f(x)= 1.03872e-31
# differential_evolution step 576: f(x)= 1.03872e-31
# differential_evolution step 577: f(x)= 1.03872e-31
# differential_evolution step 578: f(x)= 8.92835e-32
# differential_evolution step 579: f(x)= 8.92835e-32
# differential_evolution step 580: f(x)= 8.92835e-32
# differential_evolution step 581: f(x)= 8.12767e-32
# differential_evolution step 582: f(x)= 8.12767e-32
# differential_evolution step 583: f(x)= 6.08627e-32
# differential_evolution step 584: f(x)= 6.08627e-32
# differential_evolution step 585: f(x)= 6.08627e-32
# differential_evolution step 586: f(x)= 6.08627e-32
# differential_evolution step 587: f(x)= 6.08627e-32
# differential_evolution step 588: f(x)= 3.8486e-32
# differential_evolution step 589: f(x)= 3.8486e-32
# differential_evolution step 590: f(x)= 3.8486e-32
# differential_evolution step 591: f(x)= 3.8486e-32
# differential_evolution step 592: f(x)= 3.46904e-32
# differential_evolution step 593: f(x)= 2.69303e-32
# differential_evolution step 594: f(x)= 2.69303e-32
# differential_evolution step 595: f(x)= 2.01056e-32
# differential_evolution step 596: f(x)= 2.01056e-32
# differential_evolution step 597: f(x)= 1.05322e-32
# differential_evolution step 598: f(x)= 8.40265e-33
# differential_evolution step 599: f(x)= 8.02836e-33
# differential_evolution step 600: f(x)= 8.02836e-33
# differential_evolution step 601: f(x)= 7.66268e-33
# differential_evolution step 602: f(x)= 6.43789e-33
# differential_evolution step 603: f(x)= 6.43789e-33
# differential_evolution step 604: f(x)= 6.34242e-33
# differential_evolution step 605: f(x)= 6.34242e-33
# differential_evolution step 606: f(x)= 6.34242e-33
# differential_evolution step 607: f(x)= 6.10494e-33
# differential_evolution step 608: f(x)= 4.99183e-33
# differential_evolution step 609: f(x)= 4.99183e-33
# differential_evolution step 610: f(x)= 2.11757e-33
# differential_evolution step 611: f(x)= 2.11757e-33
# differential_evolution step 612: f(x)= 2.11757e-33
# differential_evolution step 613: f(x)= 2.11757e-33
# differential_evolution step 614: f(x)= 2.11757e-33
# differential_evolution step 615: f(x)= 2.11757e-33
# differential_evolution step 616: f(x)= 2.11757e-33
# differential_evolution step 617: f(x)= 2.11757e-33
# differential_evolution step 618: f(x)= 1.91511e-33
# differential_evolution step 619: f(x)= 1.91511e-33
# differential_evolution step 620: f(x)= 1.91511e-33
# differential_evolution step 621: f(x)= 1.91511e-33
# differential_evolution step 622: f(x)= 1.30693e-33
# differential_evolution step 623: f(x)= 1.30693e-33
# differential_evolution step 624: f(x)= 1.30693e-33
# differential_evolution step 625: f(x)= 1.30693e-33
# differential_evolution step 626: f(x)= 1.30693e-33
# differential_evolution step 627: f(x)= 1.30693e-33
# differential_evolution step 628: f(x)= 1.30693e-33
# differential_evolution step 629: f(x)= 1.30693e-33
# differential_evolution step 630: f(x)= 1.30693e-33
# differential_evolution step 631: f(x)= 1.30693e-33
# differential_evolution step 632: f(x)= 1.30693e-33
# differential_evolution step 633: f(x)= 9.70742e-34
# differential_evolution step 634: f(x)= 9.70742e-34
# differential_evolution step 635: f(x)= 8.24535e-34
# differential_evolution step 636: f(x)= 8.24535e-34
# differential_evolution step 637: f(x)= 8.07027e-34
# differential_evolution step 638: f(x)= 8.07027e-34
# differential_evolution step 639: f(x)= 6.43797e-34
# differential_evolution step 640: f(x)= 6.43797e-34
# differential_evolution step 641: f(x)= 6.43797e-34
# differential_evolution step 642: f(x)= 6.43797e-34
# differential_evolution step 643: f(x)= 6.05056e-34
# differential_evolution step 644: f(x)= 6.05056e-34
# differential_evolution step 645: f(x)= 6.05056e-34
# differential_evolution step 646: f(x)= 4.97589e-34
# differential_evolution step 647: f(x)= 4.97589e-34
# differential_evolution step 648: f(x)= 4.44098e-34
# differential_evolution step 649: f(x)= 4.44098e-34
# differential_evolution step 650: f(x)= 4.44098e-34
# differential_evolution step 651: f(x)= 4.44098e-34
# differential_evolution step 652: f(x)= 4.44098e-34
# differential_evolution step 653: f(x)= 4.44098e-34
# differential_evolution step 654: f(x)= 3.85093e-34
# differential_evolution step 655: f(x)= 3.75855e-34
# differential_evolution step 656: f(x)= 3.75855e-34
# differential_evolution step 657: f(x)= 1.46655e-34
# differential_evolution step 658: f(x)= 1.46655e-34
# differential_evolution step 659: f(x)= 1.46655e-34
# differential_evolution step 660: f(x)= 1.46655e-34
# differential_evolution step 661: f(x)= 1.46655e-34
# differential_evolution step 662: f(x)= 8.76502e-35
# differential_evolution step 663: f(x)= 8.76502e-35
# differential_evolution step 664: f(x)= 7.84121e-35
# differential_evolution step 665: f(x)= 7.84121e-35
# differential_evolution step 666: f(x)= 7.84121e-35
# differential_evolution step 667: f(x)= 7.84121e-35
# differential_evolution step 668: f(x)= 1.01696e-35
# differential_evolution step 669: f(x)= 1.01696e-35
# differential_evolution step 670: f(x)= 1.01696e-35
# differential_evolution step 671: f(x)= 1.01696e-35
# differential_evolution step 672: f(x)= 1.01696e-35
# differential_evolution step 673: f(x)= 1.01696e-35
# differential_evolution step 674: f(x)= 1.01696e-35
# differential_evolution step 675: f(x)= 1.01696e-35
# differential_evolution step 676: f(x)= 1.01696e-35
# differential_evolution step 677: f(x)= 1.01696e-35
# differential_evolution step 678: f(x)= 1.01696e-35
# differential_evolution step 679: f(x)= 1.01696e-35
# differential_evolution step 680: f(x)= 1.01696e-35
# differential_evolution step 681: f(x)= 1.01696e-35
# differential_evolution step 682: f(x)= 1.01696e-35
# differential_evolution step 683: f(x)= 1.01696e-35
# differential_evolution step 684: f(x)= 1.01696e-35
# differential_evolution step 685: f(x)= 1.01696e-35
# differential_evolution step 686: f(x)= 1.01696e-35
# differential_evolution step 687: f(x)= 1.01696e-35
# differential_evolution step 688: f(x)= 1.01696e-35
# differential_evolution step 689: f(x)= 1.01696e-35
# differential_evolution step 690: f(x)= 1.01696e-35
# differential_evolution step 691: f(x)= 1.01696e-35
# differential_evolution step 692: f(x)= 1.01696e-35
#  ->  207911  ->  True  ->  1.0169626070716247e-35
#      fun: 1.0169626070716247e-35
#  message: 'Optimization terminated successfully.'
#     nfev: 207911
#      nit: 692
#  success: True
#        x: array([-3.14159265,  3.14159265,  3.14159265,  3.14159265,  3.14159265,
#         3.14159265, -3.14159265,  3.14159265, -3.14159265,  3.14159265])
# differential_evolution step 1: f(x)= 0.000631527
# differential_evolution step 2: f(x)= 0.000631527
# differential_evolution step 3: f(x)= 0.000631527
# differential_evolution step 4: f(x)= 0.000553448
# differential_evolution step 5: f(x)= 0.000553448
# differential_evolution step 6: f(x)= 0.000553448
# differential_evolution step 7: f(x)= 0.000553448
# differential_evolution step 8: f(x)= 0.000553448
# differential_evolution step 9: f(x)= 0.000553448
# differential_evolution step 10: f(x)= 0.000553448
# differential_evolution step 11: f(x)= 0.000470748
# differential_evolution step 12: f(x)= 0.000470748
# differential_evolution step 13: f(x)= 0.000470748
# differential_evolution step 14: f(x)= 0.000470748
# differential_evolution step 15: f(x)= 0.000370652
# differential_evolution step 16: f(x)= 0.000370652
# differential_evolution step 17: f(x)= 0.000370652
# differential_evolution step 18: f(x)= 0.000370652
# differential_evolution step 19: f(x)= 0.000370652
# differential_evolution step 20: f(x)= 0.000370652
# differential_evolution step 21: f(x)= 0.000357574
# differential_evolution step 22: f(x)= 0.000357574
# differential_evolution step 23: f(x)= 0.000357574
# differential_evolution step 24: f(x)= 0.000357574
# differential_evolution step 25: f(x)= 0.000357574
# differential_evolution step 26: f(x)= 0.000357574
# differential_evolution step 27: f(x)= 0.000357574
# differential_evolution step 28: f(x)= 0.000357574
# differential_evolution step 29: f(x)= 0.000357574
# differential_evolution step 30: f(x)= 0.000357574
# differential_evolution step 31: f(x)= 0.000357574
# differential_evolution step 32: f(x)= 0.000357574
# differential_evolution step 33: f(x)= 0.000357574
# differential_evolution step 34: f(x)= 0.000357574
# differential_evolution step 35: f(x)= 0.000357574
# differential_evolution step 36: f(x)= 0.000357574
# differential_evolution step 37: f(x)= 0.000357574
# differential_evolution step 38: f(x)= 0.000356738
# differential_evolution step 39: f(x)= 0.000356738
# differential_evolution step 40: f(x)= 0.000292484
# differential_evolution step 41: f(x)= 0.000292484
# differential_evolution step 42: f(x)= 0.000138674
# differential_evolution step 43: f(x)= 0.000138674
# differential_evolution step 44: f(x)= 0.000138674
# differential_evolution step 45: f(x)= 0.000138674
# differential_evolution step 46: f(x)= 0.000138674
# differential_evolution step 47: f(x)= 0.000138674
# differential_evolution step 48: f(x)= 0.000138674
# differential_evolution step 49: f(x)= 0.000138674
# differential_evolution step 50: f(x)= 0.000138674
# differential_evolution step 51: f(x)= 0.000138674
# differential_evolution step 52: f(x)= 0.000138674
# differential_evolution step 53: f(x)= 0.000138674
# differential_evolution step 54: f(x)= 0.000138674
# differential_evolution step 55: f(x)= 0.000138674
# differential_evolution step 56: f(x)= 0.0001283
# differential_evolution step 57: f(x)= 0.0001283
# differential_evolution step 58: f(x)= 0.0001283
# differential_evolution step 59: f(x)= 0.0001283
# differential_evolution step 60: f(x)= 0.0001283
# differential_evolution step 61: f(x)= 0.0001283
# differential_evolution step 62: f(x)= 0.0001283
# differential_evolution step 63: f(x)= 0.0001283
# differential_evolution step 64: f(x)= 0.0001283
# differential_evolution step 65: f(x)= 0.0001283
# differential_evolution step 66: f(x)= 0.0001283
# differential_evolution step 67: f(x)= 0.0001283
# differential_evolution step 68: f(x)= 0.0001283
# differential_evolution step 69: f(x)= 0.0001283
# differential_evolution step 70: f(x)= 0.0001283
# differential_evolution step 71: f(x)= 0.0001283
# differential_evolution step 72: f(x)= 0.0001283
# differential_evolution step 73: f(x)= 0.0001283
# differential_evolution step 74: f(x)= 0.0001283
# differential_evolution step 75: f(x)= 0.0001283
# differential_evolution step 76: f(x)= 0.0001283
# differential_evolution step 77: f(x)= 0.0001283
# differential_evolution step 78: f(x)= 0.0001283
# differential_evolution step 79: f(x)= 0.0001283
# differential_evolution step 80: f(x)= 0.0001283
# differential_evolution step 81: f(x)= 0.0001283
# differential_evolution step 82: f(x)= 0.0001283
# differential_evolution step 83: f(x)= 0.000121116
# differential_evolution step 84: f(x)= 0.000114742
# differential_evolution step 85: f(x)= 0.000114742
# differential_evolution step 86: f(x)= 0.000114742
# differential_evolution step 87: f(x)= 0.000114742
# differential_evolution step 88: f(x)= 0.000114742
# differential_evolution step 89: f(x)= 0.000114742
# differential_evolution step 90: f(x)= 0.000114742
# differential_evolution step 91: f(x)= 0.000114742
# differential_evolution step 92: f(x)= 0.000114742
# differential_evolution step 93: f(x)= 0.000114742
# differential_evolution step 94: f(x)= 0.000114742
# differential_evolution step 95: f(x)= 0.000114742
# differential_evolution step 96: f(x)= 0.000114742
# differential_evolution step 97: f(x)= 0.000114742
# differential_evolution step 98: f(x)= 0.000114742
# differential_evolution step 99: f(x)= 0.000114742
# differential_evolution step 100: f(x)= 0.000101582
# differential_evolution step 101: f(x)= 0.000101582
# differential_evolution step 102: f(x)= 0.000101582
# differential_evolution step 103: f(x)= 0.000101582
# differential_evolution step 104: f(x)= 0.000101582
# differential_evolution step 105: f(x)= 0.000101582
# differential_evolution step 106: f(x)= 0.000101582
# differential_evolution step 107: f(x)= 0.000101582
# differential_evolution step 108: f(x)= 9.91157e-05
# differential_evolution step 109: f(x)= 9.91157e-05
# differential_evolution step 110: f(x)= 9.91157e-05
# differential_evolution step 111: f(x)= 9.91157e-05
# differential_evolution step 112: f(x)= 9.66996e-05
# differential_evolution step 113: f(x)= 9.66996e-05
# differential_evolution step 114: f(x)= 9.66996e-05
# differential_evolution step 115: f(x)= 9.66996e-05
# differential_evolution step 116: f(x)= 8.73452e-05
# differential_evolution step 117: f(x)= 8.73452e-05
# differential_evolution step 118: f(x)= 8.73452e-05
# differential_evolution step 119: f(x)= 8.73452e-05
# differential_evolution step 120: f(x)= 8.73452e-05
# differential_evolution step 121: f(x)= 8.73452e-05
# differential_evolution step 122: f(x)= 8.73452e-05
# differential_evolution step 123: f(x)= 8.73452e-05
# differential_evolution step 124: f(x)= 8.73452e-05
# differential_evolution step 125: f(x)= 7.00942e-05
# differential_evolution step 126: f(x)= 6.79324e-05
# differential_evolution step 127: f(x)= 6.79324e-05
# differential_evolution step 128: f(x)= 5.08289e-05
# differential_evolution step 129: f(x)= 5.08289e-05
# differential_evolution step 130: f(x)= 5.08289e-05
# differential_evolution step 131: f(x)= 4.6372e-05
# differential_evolution step 132: f(x)= 4.6372e-05
# differential_evolution step 133: f(x)= 4.6372e-05
# differential_evolution step 134: f(x)= 4.6372e-05
# differential_evolution step 135: f(x)= 4.6372e-05
# differential_evolution step 136: f(x)= 4.6372e-05
# differential_evolution step 137: f(x)= 4.6372e-05
# differential_evolution step 138: f(x)= 4.6372e-05
# differential_evolution step 139: f(x)= 4.14337e-05
# differential_evolution step 140: f(x)= 2.44093e-05
# differential_evolution step 141: f(x)= 2.44093e-05
# differential_evolution step 142: f(x)= 2.44093e-05
# differential_evolution step 143: f(x)= 2.44093e-05
# differential_evolution step 144: f(x)= 2.2882e-05
# differential_evolution step 145: f(x)= 2.05483e-05
# differential_evolution step 146: f(x)= 2.05483e-05
# differential_evolution step 147: f(x)= 1.84903e-05
# differential_evolution step 148: f(x)= 1.84903e-05
# differential_evolution step 149: f(x)= 1.70033e-05
# differential_evolution step 150: f(x)= 1.57326e-05
# differential_evolution step 151: f(x)= 1.18612e-05
# differential_evolution step 152: f(x)= 1.18612e-05
# differential_evolution step 153: f(x)= 1.18612e-05
# differential_evolution step 154: f(x)= 1.18612e-05
# differential_evolution step 155: f(x)= 1.18612e-05
# differential_evolution step 156: f(x)= 7.96914e-06
# differential_evolution step 157: f(x)= 7.96914e-06
# differential_evolution step 158: f(x)= 6.60397e-06
# differential_evolution step 159: f(x)= 6.54215e-06
# differential_evolution step 160: f(x)= 4.79349e-06
# differential_evolution step 161: f(x)= 3.67198e-06
# differential_evolution step 162: f(x)= 3.42964e-06
# differential_evolution step 163: f(x)= 3.42964e-06
# differential_evolution step 164: f(x)= 3.42964e-06
# differential_evolution step 165: f(x)= 2.79529e-06
# differential_evolution step 166: f(x)= 2.79529e-06
# differential_evolution step 167: f(x)= 2.14067e-06
# differential_evolution step 168: f(x)= 1.34772e-06
# differential_evolution step 169: f(x)= 1.34772e-06
# differential_evolution step 170: f(x)= 1.34772e-06
# differential_evolution step 171: f(x)= 1.34772e-06
# differential_evolution step 172: f(x)= 1.34772e-06
# differential_evolution step 173: f(x)= 1.16316e-06
# differential_evolution step 174: f(x)= 1.16316e-06
# differential_evolution step 175: f(x)= 1.16316e-06
# differential_evolution step 176: f(x)= 5.57142e-07
# differential_evolution step 177: f(x)= 5.57142e-07
# differential_evolution step 178: f(x)= 5.57142e-07
# differential_evolution step 179: f(x)= 5.57142e-07
# differential_evolution step 180: f(x)= 5.57142e-07
# differential_evolution step 181: f(x)= 2.21701e-07
# differential_evolution step 182: f(x)= 2.21701e-07
# differential_evolution step 183: f(x)= 2.21701e-07
# differential_evolution step 184: f(x)= 2.21701e-07
# differential_evolution step 185: f(x)= 2.21701e-07
# differential_evolution step 186: f(x)= 2.21701e-07
# differential_evolution step 187: f(x)= 2.21701e-07
# differential_evolution step 188: f(x)= 2.21701e-07
# differential_evolution step 189: f(x)= 2.21701e-07
# differential_evolution step 190: f(x)= 1.37803e-07
# differential_evolution step 191: f(x)= 1.37803e-07
# differential_evolution step 192: f(x)= 1.37803e-07
# differential_evolution step 193: f(x)= 1.37803e-07
# differential_evolution step 194: f(x)= 1.26298e-07
# differential_evolution step 195: f(x)= 1.1715e-07
# differential_evolution step 196: f(x)= 1.07421e-07
# differential_evolution step 197: f(x)= 1.07421e-07
# differential_evolution step 198: f(x)= 5.50196e-08
# differential_evolution step 199: f(x)= 5.50196e-08
# differential_evolution step 200: f(x)= 2.85174e-08
# differential_evolution step 201: f(x)= 2.85174e-08
# differential_evolution step 202: f(x)= 2.85174e-08
# differential_evolution step 203: f(x)= 2.85174e-08
# differential_evolution step 204: f(x)= 2.26256e-08
# differential_evolution step 205: f(x)= 2.26256e-08
# differential_evolution step 206: f(x)= 2.26256e-08
# differential_evolution step 207: f(x)= 2.20129e-08
# differential_evolution step 208: f(x)= 1.90693e-08
# differential_evolution step 209: f(x)= 1.37378e-08
# differential_evolution step 210: f(x)= 1.37378e-08
# differential_evolution step 211: f(x)= 1.33519e-08
# differential_evolution step 212: f(x)= 1.04209e-08
# differential_evolution step 213: f(x)= 9.97851e-09
# differential_evolution step 214: f(x)= 9.50921e-09
# differential_evolution step 215: f(x)= 8.48431e-09
# differential_evolution step 216: f(x)= 8.07457e-09
# differential_evolution step 217: f(x)= 8.07457e-09
# differential_evolution step 218: f(x)= 8.07457e-09
# differential_evolution step 219: f(x)= 7.02451e-09
# differential_evolution step 220: f(x)= 3.69223e-09
# differential_evolution step 221: f(x)= 3.69223e-09
# differential_evolution step 222: f(x)= 3.69223e-09
# differential_evolution step 223: f(x)= 3.25472e-09
# differential_evolution step 224: f(x)= 3.25472e-09
# differential_evolution step 225: f(x)= 1.95134e-09
# differential_evolution step 226: f(x)= 1.95134e-09
# differential_evolution step 227: f(x)= 1.95134e-09
# differential_evolution step 228: f(x)= 1.95134e-09
# differential_evolution step 229: f(x)= 1.68185e-09
# differential_evolution step 230: f(x)= 1.68185e-09
# differential_evolution step 231: f(x)= 1.08604e-09
# differential_evolution step 232: f(x)= 1.08604e-09
# differential_evolution step 233: f(x)= 1.08604e-09
# differential_evolution step 234: f(x)= 5.45626e-10
# differential_evolution step 235: f(x)= 5.45626e-10
# differential_evolution step 236: f(x)= 5.45626e-10
# differential_evolution step 237: f(x)= 5.45626e-10
# differential_evolution step 238: f(x)= 5.4096e-10
# differential_evolution step 239: f(x)= 5.4096e-10
# differential_evolution step 240: f(x)= 4.56626e-10
# differential_evolution step 241: f(x)= 4.56626e-10
# differential_evolution step 242: f(x)= 1.92678e-10
# differential_evolution step 243: f(x)= 1.92678e-10
# differential_evolution step 244: f(x)= 1.92678e-10
# differential_evolution step 245: f(x)= 1.92678e-10
# differential_evolution step 246: f(x)= 1.33655e-10
# differential_evolution step 247: f(x)= 1.33655e-10
# differential_evolution step 248: f(x)= 1.33655e-10
# differential_evolution step 249: f(x)= 1.33655e-10
# ...
# differential_evolution step 409: f(x)= 8.30609e-22
# differential_evolution step 410: f(x)= 5.26994e-22
# differential_evolution step 411: f(x)= 5.26994e-22
# differential_evolution step 412: f(x)= 5.26994e-22
# differential_evolution step 413: f(x)= 5.26994e-22
# differential_evolution step 414: f(x)= 3.41465e-22
# differential_evolution step 415: f(x)= 3.41465e-22
# differential_evolution step 416: f(x)= 3.41465e-22
# differential_evolution step 417: f(x)= 3.36904e-22
# differential_evolution step 418: f(x)= 2.83957e-22
# differential_evolution step 419: f(x)= 2.31255e-22
# differential_evolution step 420: f(x)= 2.31255e-22
# differential_evolution step 421: f(x)= 2.31255e-22
# differential_evolution step 422: f(x)= 2.31255e-22
# differential_evolution step 423: f(x)= 2.08726e-22
# differential_evolution step 424: f(x)= 2.08726e-22
# differential_evolution step 425: f(x)= 1.61569e-22
# differential_evolution step 426: f(x)= 1.38401e-22
# differential_evolution step 427: f(x)= 9.77982e-23
# differential_evolution step 428: f(x)= 7.54141e-23
# differential_evolution step 429: f(x)= 7.54141e-23
# differential_evolution step 430: f(x)= 7.54141e-23
# differential_evolution step 431: f(x)= 7.54141e-23
# differential_evolution step 432: f(x)= 6.80554e-23
# differential_evolution step 433: f(x)= 6.45121e-23
# differential_evolution step 434: f(x)= 5.82779e-23
# differential_evolution step 435: f(x)= 5.82779e-23
# differential_evolution step 436: f(x)= 5.18199e-23
# differential_evolution step 437: f(x)= 2.86438e-23
# differential_evolution step 438: f(x)= 2.86438e-23
# differential_evolution step 439: f(x)= 2.86438e-23
# differential_evolution step 440: f(x)= 2.86438e-23
# differential_evolution step 441: f(x)= 2.68659e-23
# differential_evolution step 442: f(x)= 2.15337e-23
# differential_evolution step 443: f(x)= 2.14238e-23
# differential_evolution step 444: f(x)= 1.33274e-23
# differential_evolution step 445: f(x)= 1.33274e-23
# differential_evolution step 446: f(x)= 1.33274e-23
# differential_evolution step 447: f(x)= 1.33274e-23
# differential_evolution step 448: f(x)= 1.15899e-23
# differential_evolution step 449: f(x)= 1.15899e-23
# differential_evolution step 450: f(x)= 1.00735e-23
# differential_evolution step 451: f(x)= 9.85891e-24
# differential_evolution step 452: f(x)= 4.54391e-24
# differential_evolution step 453: f(x)= 4.54391e-24
# differential_evolution step 454: f(x)= 4.54391e-24
# differential_evolution step 455: f(x)= 4.54391e-24
# differential_evolution step 456: f(x)= 4.54391e-24
# differential_evolution step 457: f(x)= 4.54391e-24
# differential_evolution step 458: f(x)= 3.9403e-24
# differential_evolution step 459: f(x)= 3.66564e-24
# differential_evolution step 460: f(x)= 2.22444e-24
# differential_evolution step 461: f(x)= 2.22444e-24
# differential_evolution step 462: f(x)= 1.34257e-24
# differential_evolution step 463: f(x)= 1.34257e-24
# differential_evolution step 464: f(x)= 1.34257e-24
# differential_evolution step 465: f(x)= 1.34257e-24
# differential_evolution step 466: f(x)= 1.34257e-24
# differential_evolution step 467: f(x)= 9.23191e-25
# differential_evolution step 468: f(x)= 9.23191e-25
# differential_evolution step 469: f(x)= 9.23191e-25
# differential_evolution step 470: f(x)= 9.23191e-25
# differential_evolution step 471: f(x)= 6.90345e-25
# differential_evolution step 472: f(x)= 6.90345e-25
# differential_evolution step 473: f(x)= 6.90345e-25
# differential_evolution step 474: f(x)= 6.23919e-25
# differential_evolution step 475: f(x)= 6.23919e-25
# differential_evolution step 476: f(x)= 6.07293e-25
# differential_evolution step 477: f(x)= 6.07293e-25
# differential_evolution step 478: f(x)= 3.58737e-25
# differential_evolution step 479: f(x)= 3.58737e-25
# differential_evolution step 480: f(x)= 2.95483e-25
# differential_evolution step 481: f(x)= 2.2468e-25
# differential_evolution step 482: f(x)= 1.46889e-25
# differential_evolution step 483: f(x)= 1.46889e-25
# differential_evolution step 484: f(x)= 1.25713e-25
# differential_evolution step 485: f(x)= 1.25713e-25
# differential_evolution step 486: f(x)= 1.25713e-25
# differential_evolution step 487: f(x)= 1.23946e-25
# differential_evolution step 488: f(x)= 1.23946e-25
# differential_evolution step 489: f(x)= 1.22202e-25
# differential_evolution step 490: f(x)= 1.07411e-25
# differential_evolution step 491: f(x)= 8.74225e-26
# differential_evolution step 492: f(x)= 8.28743e-26
# differential_evolution step 493: f(x)= 4.40597e-26
# differential_evolution step 494: f(x)= 4.40597e-26
# differential_evolution step 495: f(x)= 4.40597e-26
# differential_evolution step 496: f(x)= 4.40597e-26
# differential_evolution step 497: f(x)= 4.40597e-26
# differential_evolution step 498: f(x)= 2.32557e-26
# differential_evolution step 499: f(x)= 2.32557e-26
# differential_evolution step 500: f(x)= 2.32557e-26
# differential_evolution step 501: f(x)= 1.73462e-26
# differential_evolution step 502: f(x)= 1.73462e-26
# differential_evolution step 503: f(x)= 1.73462e-26
# differential_evolution step 504: f(x)= 1.73462e-26
# differential_evolution step 505: f(x)= 1.73462e-26
# differential_evolution step 506: f(x)= 7.0065e-27
# differential_evolution step 507: f(x)= 5.68451e-27
# differential_evolution step 508: f(x)= 5.68451e-27
# differential_evolution step 509: f(x)= 5.68451e-27
# differential_evolution step 510: f(x)= 5.68451e-27
# differential_evolution step 511: f(x)= 5.68451e-27
# differential_evolution step 512: f(x)= 4.39014e-27
# differential_evolution step 513: f(x)= 4.39014e-27
# differential_evolution step 514: f(x)= 4.39014e-27
# differential_evolution step 515: f(x)= 3.73085e-27
# differential_evolution step 516: f(x)= 3.62784e-27
# differential_evolution step 517: f(x)= 3.35001e-27
# differential_evolution step 518: f(x)= 3.25257e-27
# differential_evolution step 519: f(x)= 3.16441e-27
# differential_evolution step 520: f(x)= 2.08679e-27
# differential_evolution step 521: f(x)= 2.08679e-27
# differential_evolution step 522: f(x)= 1.83138e-27
# differential_evolution step 523: f(x)= 1.83138e-27
# differential_evolution step 524: f(x)= 1.67774e-27
# differential_evolution step 525: f(x)= 1.50392e-27
# differential_evolution step 526: f(x)= 8.96559e-28
# differential_evolution step 527: f(x)= 8.96559e-28
# differential_evolution step 528: f(x)= 5.45233e-28
# differential_evolution step 529: f(x)= 4.9508e-28
# differential_evolution step 530: f(x)= 4.9508e-28
# differential_evolution step 531: f(x)= 4.9508e-28
# differential_evolution step 532: f(x)= 4.9508e-28
# differential_evolution step 533: f(x)= 4.9508e-28
# differential_evolution step 534: f(x)= 3.76955e-28
# differential_evolution step 535: f(x)= 3.76955e-28
# differential_evolution step 536: f(x)= 3.76955e-28
# differential_evolution step 537: f(x)= 2.121e-28
# differential_evolution step 538: f(x)= 2.121e-28
# differential_evolution step 539: f(x)= 2.121e-28
# differential_evolution step 540: f(x)= 1.67324e-28
# differential_evolution step 541: f(x)= 1.67324e-28
# differential_evolution step 542: f(x)= 1.67324e-28
# differential_evolution step 543: f(x)= 1.67324e-28
# differential_evolution step 544: f(x)= 1.35168e-28
# differential_evolution step 545: f(x)= 1.00819e-28
# differential_evolution step 546: f(x)= 9.52995e-29
# differential_evolution step 547: f(x)= 6.22892e-29
# differential_evolution step 548: f(x)= 4.02317e-29
# differential_evolution step 549: f(x)= 4.02317e-29
# differential_evolution step 550: f(x)= 4.02317e-29
# differential_evolution step 551: f(x)= 4.02317e-29
# differential_evolution step 552: f(x)= 3.54685e-29
# differential_evolution step 553: f(x)= 3.54685e-29
# differential_evolution step 554: f(x)= 2.67916e-29
# differential_evolution step 555: f(x)= 2.67916e-29
# differential_evolution step 556: f(x)= 2.59636e-29
# differential_evolution step 557: f(x)= 2.59636e-29
# differential_evolution step 558: f(x)= 2.59325e-29
# differential_evolution step 559: f(x)= 2.51868e-29
# differential_evolution step 560: f(x)= 1.77135e-29
# differential_evolution step 561: f(x)= 1.77135e-29
# differential_evolution step 562: f(x)= 1.77135e-29
# differential_evolution step 563: f(x)= 1.42865e-29
# differential_evolution step 564: f(x)= 1.42865e-29
# differential_evolution step 565: f(x)= 1.42865e-29
# differential_evolution step 566: f(x)= 8.8654e-30
# differential_evolution step 567: f(x)= 7.41584e-30
# differential_evolution step 568: f(x)= 7.41584e-30
# differential_evolution step 569: f(x)= 7.41584e-30
# differential_evolution step 570: f(x)= 7.41584e-30
# differential_evolution step 571: f(x)= 5.06917e-30
# differential_evolution step 572: f(x)= 5.06917e-30
# differential_evolution step 573: f(x)= 5.06917e-30
# differential_evolution step 574: f(x)= 3.54378e-30
# differential_evolution step 575: f(x)= 3.54378e-30
# differential_evolution step 576: f(x)= 2.53137e-30
# differential_evolution step 577: f(x)= 2.53137e-30
# differential_evolution step 578: f(x)= 2.53137e-30
# differential_evolution step 579: f(x)= 2.29255e-30
# differential_evolution step 580: f(x)= 1.74388e-30
# differential_evolution step 581: f(x)= 1.48898e-30
# differential_evolution step 582: f(x)= 1.28764e-30
# differential_evolution step 583: f(x)= 1.28764e-30
# differential_evolution step 584: f(x)= 9.09789e-31
# differential_evolution step 585: f(x)= 9.09789e-31
# differential_evolution step 586: f(x)= 9.09789e-31
# differential_evolution step 587: f(x)= 6.61039e-31
# differential_evolution step 588: f(x)= 4.65732e-31
# differential_evolution step 589: f(x)= 4.65732e-31
# differential_evolution step 590: f(x)= 4.65732e-31
# differential_evolution step 591: f(x)= 4.65732e-31
# differential_evolution step 592: f(x)= 3.97609e-31
# differential_evolution step 593: f(x)= 3.97609e-31
# differential_evolution step 594: f(x)= 3.97609e-31
# differential_evolution step 595: f(x)= 3.97609e-31
# differential_evolution step 596: f(x)= 2.78809e-31
# differential_evolution step 597: f(x)= 2.78809e-31
# differential_evolution step 598: f(x)= 2.52695e-31
# differential_evolution step 599: f(x)= 2.52695e-31
# differential_evolution step 600: f(x)= 1.61981e-31
# differential_evolution step 601: f(x)= 1.35394e-31
# differential_evolution step 602: f(x)= 1.35394e-31
# differential_evolution step 603: f(x)= 1.35394e-31
# differential_evolution step 604: f(x)= 1.35394e-31
# differential_evolution step 605: f(x)= 4.53399e-32
# differential_evolution step 606: f(x)= 4.53399e-32
# differential_evolution step 607: f(x)= 4.53399e-32
# differential_evolution step 608: f(x)= 4.53399e-32
# differential_evolution step 609: f(x)= 4.53399e-32
# differential_evolution step 610: f(x)= 4.53399e-32
# differential_evolution step 611: f(x)= 3.96865e-32
# differential_evolution step 612: f(x)= 2.73603e-32
# differential_evolution step 613: f(x)= 2.73603e-32
# differential_evolution step 614: f(x)= 2.62016e-32
# differential_evolution step 615: f(x)= 1.54434e-32
# differential_evolution step 616: f(x)= 1.54434e-32
# differential_evolution step 617: f(x)= 1.54434e-32
# differential_evolution step 618: f(x)= 1.46811e-32
# differential_evolution step 619: f(x)= 1.3787e-32
# differential_evolution step 620: f(x)= 1.3787e-32
# differential_evolution step 621: f(x)= 1.37117e-32
# differential_evolution step 622: f(x)= 1.37117e-32
# differential_evolution step 623: f(x)= 1.28924e-32
# differential_evolution step 624: f(x)= 7.69348e-33
# differential_evolution step 625: f(x)= 7.69348e-33
# differential_evolution step 626: f(x)= 7.69348e-33
# differential_evolution step 627: f(x)= 7.69348e-33
# differential_evolution step 628: f(x)= 6.06945e-33
# differential_evolution step 629: f(x)= 6.06945e-33
# differential_evolution step 630: f(x)= 6.06945e-33
# differential_evolution step 631: f(x)= 5.58624e-33
# differential_evolution step 632: f(x)= 4.33146e-33
# differential_evolution step 633: f(x)= 4.33146e-33
# differential_evolution step 634: f(x)= 3.7463e-33
# differential_evolution step 635: f(x)= 3.7463e-33
# differential_evolution step 636: f(x)= 3.32615e-33
# differential_evolution step 637: f(x)= 3.32615e-33
# differential_evolution step 638: f(x)= 2.07331e-33
# differential_evolution step 639: f(x)= 1.49318e-33
# differential_evolution step 640: f(x)= 1.1865e-33
# differential_evolution step 641: f(x)= 1.1865e-33
# differential_evolution step 642: f(x)= 9.27792e-34
# differential_evolution step 643: f(x)= 9.27792e-34
# differential_evolution step 644: f(x)= 9.27792e-34
# differential_evolution step 645: f(x)= 9.27792e-34
# differential_evolution step 646: f(x)= 9.27792e-34
# differential_evolution step 647: f(x)= 9.27792e-34
# differential_evolution step 648: f(x)= 9.27792e-34
# differential_evolution step 649: f(x)= 8.9829e-34
# differential_evolution step 650: f(x)= 7.47054e-34
# differential_evolution step 651: f(x)= 7.47054e-34
# differential_evolution step 652: f(x)= 6.24836e-34
# differential_evolution step 653: f(x)= 6.24836e-34
# differential_evolution step 654: f(x)= 5.60319e-34
# differential_evolution step 655: f(x)= 5.60319e-34
# differential_evolution step 656: f(x)= 5.60319e-34
# differential_evolution step 657: f(x)= 5.60319e-34
# differential_evolution step 658: f(x)= 5.60319e-34
# differential_evolution step 659: f(x)= 5.60319e-34
# differential_evolution step 660: f(x)= 5.60319e-34
# differential_evolution step 661: f(x)= 4.88351e-34
# differential_evolution step 662: f(x)= 4.88351e-34
# differential_evolution step 663: f(x)= 4.88351e-34
# differential_evolution step 664: f(x)= 2.92378e-34
# differential_evolution step 665: f(x)= 2.92378e-34
# differential_evolution step 666: f(x)= 2.92378e-34
# differential_evolution step 667: f(x)= 2.92378e-34
# differential_evolution step 668: f(x)= 2.92378e-34
# differential_evolution step 669: f(x)= 2.92378e-34
# differential_evolution step 670: f(x)= 2.92378e-34
# differential_evolution step 671: f(x)= 2.62875e-34
# differential_evolution step 672: f(x)= 1.85395e-34
# differential_evolution step 673: f(x)= 1.85395e-34
# differential_evolution step 674: f(x)= 1.85395e-34
# differential_evolution step 675: f(x)= 1.85395e-34
# differential_evolution step 676: f(x)= 1.85395e-34
# differential_evolution step 677: f(x)= 1.85395e-34
# differential_evolution step 678: f(x)= 1.55893e-34
# differential_evolution step 679: f(x)= 1.55893e-34
# differential_evolution step 680: f(x)= 1.17152e-34
# differential_evolution step 681: f(x)= 1.17152e-34
# differential_evolution step 682: f(x)= 1.17152e-34
# differential_evolution step 683: f(x)= 1.17152e-34
# differential_evolution step 684: f(x)= 1.17152e-34
# differential_evolution step 685: f(x)= 1.17152e-34
# differential_evolution step 686: f(x)= 1.17152e-34
# differential_evolution step 687: f(x)= 4.89099e-35
# differential_evolution step 688: f(x)= 4.89099e-35
# differential_evolution step 689: f(x)= 4.89099e-35
# differential_evolution step 690: f(x)= 4.89099e-35
# differential_evolution step 691: f(x)= 4.89099e-35
# differential_evolution step 692: f(x)= 4.89099e-35
# differential_evolution step 693: f(x)= 4.89099e-35
# differential_evolution step 694: f(x)= 4.89099e-35
# differential_evolution step 695: f(x)= 1.01696e-35
# differential_evolution step 696: f(x)= 1.01696e-35
# differential_evolution step 697: f(x)= 1.01696e-35
# differential_evolution step 698: f(x)= 1.01696e-35
# differential_evolution step 699: f(x)= 1.01696e-35
# differential_evolution step 700: f(x)= 1.01696e-35
# differential_evolution step 701: f(x)= 1.01696e-35
# differential_evolution step 702: f(x)= 1.01696e-35
# differential_evolution step 703: f(x)= 1.01696e-35
# differential_evolution step 704: f(x)= 1.01696e-35
# differential_evolution step 705: f(x)= 1.01696e-35
# differential_evolution step 706: f(x)= 1.01696e-35
# differential_evolution step 707: f(x)= 1.01696e-35
# differential_evolution step 708: f(x)= 1.01696e-35
# differential_evolution step 709: f(x)= 1.01696e-35
# differential_evolution step 710: f(x)= 1.01696e-35
# differential_evolution step 711: f(x)= 1.01696e-35
# differential_evolution step 712: f(x)= 1.01696e-35
# differential_evolution step 713: f(x)= 1.01696e-35
# differential_evolution step 714: f(x)= 1.01696e-35
# differential_evolution step 715: f(x)= 1.01696e-35
#  ->  214811  ->  True  ->  1.0169626070716247e-35
#      fun: 1.0169626070716247e-35
#  message: 'Optimization terminated successfully.'
#     nfev: 214811
#      nit: 715
#  success: True
#        x: array([-3.14159265,  3.14159265, -3.14159265,  3.14159265, -3.14159265,
#        -3.14159265, -3.14159265,  3.14159265, -3.14159265,  3.14159265])

# %% [markdown]
# **Strategy best1bin ---- CR = 1 & F = 0.7**

# %%
CR = 1
F = 0.7

for i in range(5):
  result = differential_evolution(xinSheYangN4, bounds, init = "random", mutation = F, recombination = CR, popsize=30, maxiter = 1200, strategy = "best1bin", disp=True)
  print( " -> " , result.nfev, " -> " , result.success, " -> " , result.fun)
  # summarize the result
  print(result)
# Out:
# differential_evolution step 1: f(x)= 0.0011497
# differential_evolution step 2: f(x)= 0.000730924
# differential_evolution step 3: f(x)= 0.000730924
# differential_evolution step 4: f(x)= 0.000480177
# differential_evolution step 5: f(x)= 0.000480177
# differential_evolution step 6: f(x)= 0.000480177
# differential_evolution step 7: f(x)= 0.000355815
# differential_evolution step 8: f(x)= 0.000355815
# differential_evolution step 9: f(x)= 0.000355815
# differential_evolution step 10: f(x)= 0.000355815
# differential_evolution step 11: f(x)= 0.000355815
# differential_evolution step 12: f(x)= 0.000355815
# differential_evolution step 13: f(x)= 0.000355815
# differential_evolution step 14: f(x)= 0.000355815
# differential_evolution step 15: f(x)= 0.000269618
# differential_evolution step 16: f(x)= 0.000269618
# differential_evolution step 17: f(x)= 0.000269618
# differential_evolution step 18: f(x)= 0.000269618
# differential_evolution step 19: f(x)= 0.000269618
# differential_evolution step 20: f(x)= 0.000269618
# differential_evolution step 21: f(x)= 0.000269618
# differential_evolution step 22: f(x)= 0.000269618
# differential_evolution step 23: f(x)= 0.000262977
# differential_evolution step 24: f(x)= 0.000201878
# differential_evolution step 25: f(x)= 0.000198607
# differential_evolution step 26: f(x)= 0.000198607
# differential_evolution step 27: f(x)= 0.000131211
# differential_evolution step 28: f(x)= 0.000131211
# differential_evolution step 29: f(x)= 0.000131211
# differential_evolution step 30: f(x)= 0.000131211
# differential_evolution step 31: f(x)= 9.79709e-05
# differential_evolution step 32: f(x)= 9.79709e-05
# differential_evolution step 33: f(x)= 9.79709e-05
# differential_evolution step 34: f(x)= 6.64765e-05
# differential_evolution step 35: f(x)= 6.64765e-05
# differential_evolution step 36: f(x)= 6.64765e-05
# differential_evolution step 37: f(x)= 4.35271e-05
# differential_evolution step 38: f(x)= 4.35271e-05
# differential_evolution step 39: f(x)= 3.21602e-05
# differential_evolution step 40: f(x)= 2.453e-05
# differential_evolution step 41: f(x)= 2.453e-05
# differential_evolution step 42: f(x)= 1.14694e-05
# differential_evolution step 43: f(x)= 1.06e-05
# differential_evolution step 44: f(x)= 1.06e-05
# differential_evolution step 45: f(x)= 9.35722e-06
# differential_evolution step 46: f(x)= 4.73571e-06
# differential_evolution step 47: f(x)= 4.73571e-06
# differential_evolution step 48: f(x)= 2.54053e-06
# differential_evolution step 49: f(x)= 2.54053e-06
# differential_evolution step 50: f(x)= 2.12013e-06
# differential_evolution step 51: f(x)= 1.39647e-06
# differential_evolution step 52: f(x)= 1.39647e-06
# differential_evolution step 53: f(x)= 8.00124e-07
# differential_evolution step 54: f(x)= 8.00124e-07
# differential_evolution step 55: f(x)= 4.71838e-07
# differential_evolution step 56: f(x)= 4.71838e-07
# differential_evolution step 57: f(x)= 4.5916e-07
# differential_evolution step 58: f(x)= 2.62761e-07
# differential_evolution step 59: f(x)= 1.77994e-07
# differential_evolution step 60: f(x)= 1.25479e-07
# differential_evolution step 61: f(x)= 6.39867e-08
# differential_evolution step 62: f(x)= 6.39867e-08
# differential_evolution step 63: f(x)= 6.39867e-08
# differential_evolution step 64: f(x)= 5.86743e-08
# differential_evolution step 65: f(x)= 3.48658e-08
# differential_evolution step 66: f(x)= 3.48658e-08
# differential_evolution step 67: f(x)= 1.3858e-08
# differential_evolution step 68: f(x)= 1.36281e-08
# differential_evolution step 69: f(x)= 1.36281e-08
# differential_evolution step 70: f(x)= 1.16505e-08
# differential_evolution step 71: f(x)= 8.57636e-09
# differential_evolution step 72: f(x)= 8.55115e-09
# differential_evolution step 73: f(x)= 2.66162e-09
# differential_evolution step 74: f(x)= 2.66162e-09
# differential_evolution step 75: f(x)= 2.06269e-09
# differential_evolution step 76: f(x)= 1.94584e-09
# differential_evolution step 77: f(x)= 1.45964e-09
# differential_evolution step 78: f(x)= 1.39345e-09
# differential_evolution step 79: f(x)= 1.38571e-09
# differential_evolution step 80: f(x)= 9.42427e-10
# differential_evolution step 81: f(x)= 8.22632e-10
# differential_evolution step 82: f(x)= 4.16779e-10
# differential_evolution step 83: f(x)= 4.16779e-10
# differential_evolution step 84: f(x)= 3.01312e-10
# differential_evolution step 85: f(x)= 2.62907e-10
# differential_evolution step 86: f(x)= 2.62907e-10
# differential_evolution step 87: f(x)= 1.23425e-10
# differential_evolution step 88: f(x)= 1.00316e-10
# differential_evolution step 89: f(x)= 6.45978e-11
# differential_evolution step 90: f(x)= 4.44904e-11
# differential_evolution step 91: f(x)= 4.44904e-11
# differential_evolution step 92: f(x)= 3.08853e-11
# differential_evolution step 93: f(x)= 3.08853e-11
# differential_evolution step 94: f(x)= 1.66291e-11
# differential_evolution step 95: f(x)= 9.51893e-12
# differential_evolution step 96: f(x)= 9.51893e-12
# differential_evolution step 97: f(x)= 9.51893e-12
# differential_evolution step 98: f(x)= 4.43793e-12
# differential_evolution step 99: f(x)= 4.43793e-12
# differential_evolution step 100: f(x)= 4.43793e-12
# differential_evolution step 101: f(x)= 3.01677e-12
# differential_evolution step 102: f(x)= 3.01677e-12
# differential_evolution step 103: f(x)= 2.50306e-12
# differential_evolution step 104: f(x)= 2.50306e-12
# differential_evolution step 105: f(x)= 8.36304e-13
# differential_evolution step 106: f(x)= 8.36304e-13
# differential_evolution step 107: f(x)= 8.36304e-13
# differential_evolution step 108: f(x)= 5.61815e-13
# differential_evolution step 109: f(x)= 5.42065e-13
# differential_evolution step 110: f(x)= 4.11815e-13
# differential_evolution step 111: f(x)= 2.23795e-13
# differential_evolution step 112: f(x)= 1.91494e-13
# differential_evolution step 113: f(x)= 1.3011e-13
# differential_evolution step 114: f(x)= 1.3011e-13
# differential_evolution step 115: f(x)= 1.24716e-13
# differential_evolution step 116: f(x)= 3.37197e-14
# differential_evolution step 117: f(x)= 3.37197e-14
# differential_evolution step 118: f(x)= 3.37197e-14
# differential_evolution step 119: f(x)= 3.17138e-14
# differential_evolution step 120: f(x)= 1.34421e-14
# differential_evolution step 121: f(x)= 1.24279e-14
# differential_evolution step 122: f(x)= 9.81373e-15
# differential_evolution step 123: f(x)= 8.59406e-15
# differential_evolution step 124: f(x)= 8.59406e-15
# differential_evolution step 125: f(x)= 4.2668e-15
# differential_evolution step 126: f(x)= 4.2668e-15
# differential_evolution step 127: f(x)= 4.2668e-15
# differential_evolution step 128: f(x)= 3.18117e-15
# differential_evolution step 129: f(x)= 6.69042e-16
# differential_evolution step 130: f(x)= 6.69042e-16
# differential_evolution step 131: f(x)= 6.69042e-16
# differential_evolution step 132: f(x)= 6.69042e-16
# differential_evolution step 133: f(x)= 5.00225e-16
# differential_evolution step 134: f(x)= 5.00225e-16
# differential_evolution step 135: f(x)= 2.12815e-16
# differential_evolution step 136: f(x)= 2.12815e-16
# differential_evolution step 137: f(x)= 1.75391e-16
# differential_evolution step 138: f(x)= 1.64942e-16
# differential_evolution step 139: f(x)= 1.63654e-16
# differential_evolution step 140: f(x)= 7.8976e-17
# differential_evolution step 141: f(x)= 7.8976e-17
# differential_evolution step 142: f(x)= 7.8976e-17
# differential_evolution step 143: f(x)= 3.8522e-17
# differential_evolution step 144: f(x)= 3.8522e-17
# differential_evolution step 145: f(x)= 3.54386e-17
# differential_evolution step 146: f(x)= 2.92272e-17
# differential_evolution step 147: f(x)= 2.13335e-17
# differential_evolution step 148: f(x)= 1.42595e-17
# differential_evolution step 149: f(x)= 1.25711e-17
# differential_evolution step 150: f(x)= 8.33057e-18
# differential_evolution step 151: f(x)= 4.63375e-18
# differential_evolution step 152: f(x)= 4.63375e-18
# differential_evolution step 153: f(x)= 3.29865e-18
# differential_evolution step 154: f(x)= 3.29865e-18
# differential_evolution step 155: f(x)= 2.02826e-18
# differential_evolution step 156: f(x)= 1.27181e-18
# differential_evolution step 157: f(x)= 1.27181e-18
# differential_evolution step 158: f(x)= 1.26849e-18
# differential_evolution step 159: f(x)= 7.21379e-19
# differential_evolution step 160: f(x)= 6.61962e-19
# differential_evolution step 161: f(x)= 5.82379e-19
# differential_evolution step 162: f(x)= 3.69066e-19
# differential_evolution step 163: f(x)= 2.55596e-19
# differential_evolution step 164: f(x)= 2.08889e-19
# differential_evolution step 165: f(x)= 1.53232e-19
# differential_evolution step 166: f(x)= 6.64885e-20
# differential_evolution step 167: f(x)= 6.64885e-20
# differential_evolution step 168: f(x)= 6.64885e-20
# differential_evolution step 169: f(x)= 4.84014e-20
# differential_evolution step 170: f(x)= 2.43236e-20
# differential_evolution step 171: f(x)= 1.61546e-20
# differential_evolution step 172: f(x)= 1.52408e-20
# differential_evolution step 173: f(x)= 1.32923e-20
# differential_evolution step 174: f(x)= 1.1802e-20
# differential_evolution step 175: f(x)= 1.04835e-20
# differential_evolution step 176: f(x)= 7.16447e-21
# differential_evolution step 177: f(x)= 2.82989e-21
# differential_evolution step 178: f(x)= 2.82989e-21
# differential_evolution step 179: f(x)= 2.64107e-21
# differential_evolution step 180: f(x)= 1.89684e-21
# differential_evolution step 181: f(x)= 1.89684e-21
# differential_evolution step 182: f(x)= 9.51923e-22
# differential_evolution step 183: f(x)= 7.02624e-22
# differential_evolution step 184: f(x)= 7.02624e-22
# differential_evolution step 185: f(x)= 5.68675e-22
# differential_evolution step 186: f(x)= 3.44838e-22
# differential_evolution step 187: f(x)= 3.44838e-22
# differential_evolution step 188: f(x)= 2.33392e-22
# differential_evolution step 189: f(x)= 1.95434e-22
# differential_evolution step 190: f(x)= 9.61744e-23
# differential_evolution step 191: f(x)= 9.30015e-23
# differential_evolution step 192: f(x)= 6.83358e-23
# differential_evolution step 193: f(x)= 6.4754e-23
# differential_evolution step 194: f(x)= 4.77612e-23
# differential_evolution step 195: f(x)= 2.1963e-23
# differential_evolution step 196: f(x)= 2.1963e-23
# differential_evolution step 197: f(x)= 2.1963e-23
# differential_evolution step 198: f(x)= 1.35731e-23
# differential_evolution step 199: f(x)= 1.1334e-23
# differential_evolution step 200: f(x)= 5.36433e-24
# differential_evolution step 201: f(x)= 5.36433e-24
# differential_evolution step 202: f(x)= 5.36433e-24
# differential_evolution step 203: f(x)= 3.17398e-24
# differential_evolution step 204: f(x)= 3.17398e-24
# differential_evolution step 205: f(x)= 1.8411e-24
# differential_evolution step 206: f(x)= 1.00941e-24
# differential_evolution step 207: f(x)= 1.00941e-24
# differential_evolution step 208: f(x)= 8.20957e-25
# differential_evolution step 209: f(x)= 3.97818e-25
# differential_evolution step 210: f(x)= 2.18951e-25
# differential_evolution step 211: f(x)= 2.18951e-25
# differential_evolution step 212: f(x)= 1.84772e-25
# differential_evolution step 213: f(x)= 1.80061e-25
# differential_evolution step 214: f(x)= 1.50742e-25
# differential_evolution step 215: f(x)= 9.32377e-26
# differential_evolution step 216: f(x)= 3.80538e-26
# differential_evolution step 217: f(x)= 3.80538e-26
# differential_evolution step 218: f(x)= 3.80538e-26
# differential_evolution step 219: f(x)= 3.30158e-26
# differential_evolution step 220: f(x)= 1.22975e-26
# differential_evolution step 221: f(x)= 1.22975e-26
# differential_evolution step 222: f(x)= 1.22975e-26
# differential_evolution step 223: f(x)= 1.18712e-26
# differential_evolution step 224: f(x)= 5.8925e-27
# differential_evolution step 225: f(x)= 5.8925e-27
# differential_evolution step 226: f(x)= 5.8925e-27
# differential_evolution step 227: f(x)= 3.24953e-27
# differential_evolution step 228: f(x)= 2.74544e-27
# differential_evolution step 229: f(x)= 1.62269e-27
# differential_evolution step 230: f(x)= 1.03773e-27
# differential_evolution step 231: f(x)= 1.03773e-27
# differential_evolution step 232: f(x)= 8.5915e-28
# differential_evolution step 233: f(x)= 7.34502e-28
# differential_evolution step 234: f(x)= 3.58409e-28
# differential_evolution step 235: f(x)= 3.26779e-28
# differential_evolution step 236: f(x)= 3.06709e-28
# differential_evolution step 237: f(x)= 2.41929e-28
# differential_evolution step 238: f(x)= 1.52766e-28
# differential_evolution step 239: f(x)= 9.98183e-29
# differential_evolution step 240: f(x)= 9.98183e-29
# differential_evolution step 241: f(x)= 7.81293e-29
# differential_evolution step 242: f(x)= 5.02469e-29
# differential_evolution step 243: f(x)= 5.02469e-29
# differential_evolution step 244: f(x)= 2.95854e-29
# differential_evolution step 245: f(x)= 1.63505e-29
# differential_evolution step 246: f(x)= 1.63505e-29
# differential_evolution step 247: f(x)= 1.63505e-29
# differential_evolution step 248: f(x)= 1.05398e-29
# differential_evolution step 249: f(x)= 9.06805e-30
# differential_evolution step 250: f(x)= 2.34716e-30
# differential_evolution step 251: f(x)= 2.34716e-30
# differential_evolution step 252: f(x)= 1.85015e-30
# differential_evolution step 253: f(x)= 1.68732e-30
# differential_evolution step 254: f(x)= 1.36004e-30
# differential_evolution step 255: f(x)= 1.36004e-30
# differential_evolution step 256: f(x)= 1.28831e-30
# differential_evolution step 257: f(x)= 5.7386e-31
# differential_evolution step 258: f(x)= 5.09314e-31
# differential_evolution step 259: f(x)= 1.52112e-31
# differential_evolution step 260: f(x)= 1.52112e-31
# differential_evolution step 261: f(x)= 1.52112e-31
# differential_evolution step 262: f(x)= 9.34222e-32
# differential_evolution step 263: f(x)= 7.68992e-32
# differential_evolution step 264: f(x)= 3.47765e-32
# differential_evolution step 265: f(x)= 3.47765e-32
# differential_evolution step 266: f(x)= 3.47765e-32
# differential_evolution step 267: f(x)= 2.32841e-32
# differential_evolution step 268: f(x)= 2.32841e-32
# differential_evolution step 269: f(x)= 1.95922e-32
# differential_evolution step 270: f(x)= 1.40448e-32
# differential_evolution step 271: f(x)= 1.40448e-32
# differential_evolution step 272: f(x)= 1.0696e-32
# differential_evolution step 273: f(x)= 1.05313e-32
# differential_evolution step 274: f(x)= 5.23012e-33
# differential_evolution step 275: f(x)= 5.23012e-33
# differential_evolution step 276: f(x)= 2.73223e-33
# differential_evolution step 277: f(x)= 2.73223e-33
# differential_evolution step 278: f(x)= 1.46367e-33
# differential_evolution step 279: f(x)= 1.30693e-33
# differential_evolution step 280: f(x)= 1.07772e-33
# differential_evolution step 281: f(x)= 8.24535e-34
# differential_evolution step 282: f(x)= 7.95033e-34
# differential_evolution step 283: f(x)= 7.95033e-34
# differential_evolution step 284: f(x)= 7.85794e-34
# differential_evolution step 285: f(x)= 6.73299e-34
# differential_evolution step 286: f(x)= 2.53637e-34
# differential_evolution step 287: f(x)= 1.55893e-34
# differential_evolution step 288: f(x)= 1.55893e-34
# differential_evolution step 289: f(x)= 1.17152e-34
# differential_evolution step 290: f(x)= 1.17152e-34
# differential_evolution step 291: f(x)= 1.17152e-34
# differential_evolution step 292: f(x)= 1.17152e-34
# differential_evolution step 293: f(x)= 1.17152e-34
# differential_evolution step 294: f(x)= 7.84121e-35
# differential_evolution step 295: f(x)= 7.84121e-35
# differential_evolution step 296: f(x)= 7.84121e-35
# differential_evolution step 297: f(x)= 7.84121e-35
# differential_evolution step 298: f(x)= 7.84121e-35
# differential_evolution step 299: f(x)= 4.89099e-35
# differential_evolution step 300: f(x)= 4.89099e-35
# differential_evolution step 301: f(x)= 4.89099e-35
# differential_evolution step 302: f(x)= 4.89099e-35
# differential_evolution step 303: f(x)= 1.01696e-35
# differential_evolution step 304: f(x)= 1.01696e-35
# differential_evolution step 305: f(x)= 1.01696e-35
# differential_evolution step 306: f(x)= 1.01696e-35
# differential_evolution step 307: f(x)= 1.01696e-35
# differential_evolution step 308: f(x)= 1.01696e-35
# differential_evolution step 309: f(x)= 1.01696e-35
# differential_evolution step 310: f(x)= 1.01696e-35
# differential_evolution step 311: f(x)= 1.01696e-35
# differential_evolution step 312: f(x)= 1.01696e-35
# differential_evolution step 313: f(x)= 1.01696e-35
# differential_evolution step 314: f(x)= 1.01696e-35
# differential_evolution step 315: f(x)= 1.01696e-35
# differential_evolution step 316: f(x)= 1.01696e-35
# differential_evolution step 317: f(x)= 1.01696e-35
# differential_evolution step 318: f(x)= 1.01696e-35
# differential_evolution step 319: f(x)= 1.01696e-35
#  ->  96011  ->  True  ->  1.0169626070716247e-35
#      fun: 1.0169626070716247e-35
#  message: 'Optimization terminated successfully.'
#     nfev: 96011
#      nit: 319
#  success: True
#        x: array([ 3.14159265,  3.14159265, -3.14159265,  3.14159265, -3.14159265,
#        -3.14159265, -3.14159265,  3.14159265, -3.14159265,  3.14159265])
# differential_evolution step 1: f(x)= 0.000964818
# differential_evolution step 2: f(x)= 0.000480952
# differential_evolution step 3: f(x)= 0.000405058
# differential_evolution step 4: f(x)= 0.000405058
# differential_evolution step 5: f(x)= 0.000405058
# differential_evolution step 6: f(x)= 0.000405058
# differential_evolution step 7: f(x)= 0.000378363
# differential_evolution step 8: f(x)= 0.000378363
# differential_evolution step 9: f(x)= 0.000378363
# differential_evolution step 10: f(x)= 0.000330164
# differential_evolution step 11: f(x)= 0.000330164
# differential_evolution step 12: f(x)= 0.000330164
# differential_evolution step 13: f(x)= 0.000164413
# differential_evolution step 14: f(x)= 0.000164413
# differential_evolution step 15: f(x)= 0.000164413
# differential_evolution step 16: f(x)= 0.000164413
# differential_evolution step 17: f(x)= 0.000164413
# differential_evolution step 18: f(x)= 0.000164413
# differential_evolution step 19: f(x)= 0.000164413
# differential_evolution step 20: f(x)= 0.000164413
# differential_evolution step 21: f(x)= 0.000139342
# differential_evolution step 22: f(x)= 0.000106313
# differential_evolution step 23: f(x)= 0.000106313
# differential_evolution step 24: f(x)= 0.000106313
# differential_evolution step 25: f(x)= 0.000106313
# differential_evolution step 26: f(x)= 9.38846e-05
# differential_evolution step 27: f(x)= 7.79234e-05
# differential_evolution step 28: f(x)= 7.39216e-05
# differential_evolution step 29: f(x)= 6.9314e-05
# differential_evolution step 30: f(x)= 5.35386e-05
# differential_evolution step 31: f(x)= 4.22375e-05
# differential_evolution step 32: f(x)= 4.1279e-05
# differential_evolution step 33: f(x)= 4.1279e-05
# differential_evolution step 34: f(x)= 1.78449e-05
# differential_evolution step 35: f(x)= 1.78449e-05
# differential_evolution step 36: f(x)= 1.17647e-05
# differential_evolution step 37: f(x)= 1.17647e-05
# differential_evolution step 38: f(x)= 5.88162e-06
# differential_evolution step 39: f(x)= 4.63944e-06
# differential_evolution step 40: f(x)= 4.02874e-06
# differential_evolution step 41: f(x)= 3.61832e-06
# differential_evolution step 42: f(x)= 2.85001e-06
# differential_evolution step 43: f(x)= 1.22675e-06
# differential_evolution step 44: f(x)= 8.07796e-07
# differential_evolution step 45: f(x)= 8.07796e-07
# differential_evolution step 46: f(x)= 3.978e-07
# differential_evolution step 47: f(x)= 3.978e-07
# differential_evolution step 48: f(x)= 3.978e-07
# differential_evolution step 49: f(x)= 3.978e-07
# differential_evolution step 50: f(x)= 2.05962e-07
# differential_evolution step 51: f(x)= 1.83346e-07
# differential_evolution step 52: f(x)= 5.58453e-08
# differential_evolution step 53: f(x)= 5.58453e-08
# differential_evolution step 54: f(x)= 5.58453e-08
# differential_evolution step 55: f(x)= 5.43804e-08
# differential_evolution step 56: f(x)= 3.2981e-08
# differential_evolution step 57: f(x)= 2.47909e-08
# differential_evolution step 58: f(x)= 2.14235e-08
# differential_evolution step 59: f(x)= 1.4968e-08
# differential_evolution step 60: f(x)= 1.46922e-08
# differential_evolution step 61: f(x)= 1.23661e-08
# differential_evolution step 62: f(x)= 7.89504e-09
# differential_evolution step 63: f(x)= 6.28285e-09
# differential_evolution step 64: f(x)= 2.82399e-09
# differential_evolution step 65: f(x)= 2.18319e-09
# differential_evolution step 66: f(x)= 2.04837e-09
# differential_evolution step 67: f(x)= 1.91509e-09
# differential_evolution step 68: f(x)= 1.91509e-09
# differential_evolution step 69: f(x)= 1.50096e-09
# differential_evolution step 70: f(x)= 5.18855e-10
# differential_evolution step 71: f(x)= 5.18855e-10
# differential_evolution step 72: f(x)= 5.10691e-10
# differential_evolution step 73: f(x)= 5.1021e-10
# differential_evolution step 74: f(x)= 2.66431e-10
# differential_evolution step 75: f(x)= 2.66431e-10
# differential_evolution step 76: f(x)= 2.66431e-10
# differential_evolution step 77: f(x)= 1.28009e-10
# differential_evolution step 78: f(x)= 1.28009e-10
# differential_evolution step 79: f(x)= 4.14392e-11
# differential_evolution step 80: f(x)= 4.14392e-11
# differential_evolution step 81: f(x)= 3.85709e-11
# differential_evolution step 82: f(x)= 3.48295e-11
# differential_evolution step 83: f(x)= 2.99145e-11
# differential_evolution step 84: f(x)= 1.77158e-11
# differential_evolution step 85: f(x)= 1.77158e-11
# differential_evolution step 86: f(x)= 1.28238e-11
# differential_evolution step 87: f(x)= 6.49541e-12
# differential_evolution step 88: f(x)= 6.49541e-12
# differential_evolution step 89: f(x)= 6.49541e-12
# differential_evolution step 90: f(x)= 4.42186e-12
# differential_evolution step 91: f(x)= 2.99091e-12
# differential_evolution step 92: f(x)= 2.62291e-12
# differential_evolution step 93: f(x)= 2.62291e-12
# differential_evolution step 94: f(x)= 1.68711e-12
# differential_evolution step 95: f(x)= 1.68711e-12
# differential_evolution step 96: f(x)= 1.29936e-12
# differential_evolution step 97: f(x)= 6.83914e-13
# differential_evolution step 98: f(x)= 6.83914e-13
# differential_evolution step 99: f(x)= 4.29246e-13
# differential_evolution step 100: f(x)= 4.29246e-13
# differential_evolution step 101: f(x)= 4.29246e-13
# differential_evolution step 102: f(x)= 1.54644e-13
# differential_evolution step 103: f(x)= 1.50314e-13
# differential_evolution step 104: f(x)= 1.50314e-13
# differential_evolution step 105: f(x)= 1.28777e-13
# differential_evolution step 106: f(x)= 3.36605e-14
# differential_evolution step 107: f(x)= 3.36605e-14
# differential_evolution step 108: f(x)= 3.36605e-14
# differential_evolution step 109: f(x)= 2.37521e-14
# differential_evolution step 110: f(x)= 1.08191e-14
# differential_evolution step 111: f(x)= 1.08191e-14
# differential_evolution step 112: f(x)= 9.47503e-15
# differential_evolution step 113: f(x)= 9.47503e-15
# differential_evolution step 114: f(x)= 6.81115e-15
# differential_evolution step 115: f(x)= 5.5771e-15
# differential_evolution step 116: f(x)= 3.83808e-15
# differential_evolution step 117: f(x)= 3.83808e-15
# differential_evolution step 118: f(x)= 1.3374e-15
# differential_evolution step 119: f(x)= 1.3374e-15
# differential_evolution step 120: f(x)= 1.3374e-15
# differential_evolution step 121: f(x)= 1.3374e-15
# differential_evolution step 122: f(x)= 1.3374e-15
# differential_evolution step 123: f(x)= 8.73541e-16
# differential_evolution step 124: f(x)= 8.1768e-16
# differential_evolution step 125: f(x)= 2.80741e-16
# differential_evolution step 126: f(x)= 1.01622e-16
# differential_evolution step 127: f(x)= 1.01622e-16
# differential_evolution step 128: f(x)= 1.01622e-16
# differential_evolution step 129: f(x)= 1.01622e-16
# differential_evolution step 130: f(x)= 1.01622e-16
# differential_evolution step 131: f(x)= 6.25429e-17
# differential_evolution step 132: f(x)= 4.84563e-17
# differential_evolution step 133: f(x)= 3.03197e-17
# differential_evolution step 134: f(x)= 3.02329e-17
# differential_evolution step 135: f(x)= 2.73365e-17
# differential_evolution step 136: f(x)= 1.88786e-17
# differential_evolution step 137: f(x)= 1.88786e-17
# differential_evolution step 138: f(x)= 8.41879e-18
# differential_evolution step 139: f(x)= 3.80255e-18
# differential_evolution step 140: f(x)= 3.47982e-18
# differential_evolution step 141: f(x)= 3.47982e-18
# differential_evolution step 142: f(x)= 3.47982e-18
# differential_evolution step 143: f(x)= 3.37569e-18
# differential_evolution step 144: f(x)= 1.31455e-18
# differential_evolution step 145: f(x)= 1.19477e-18
# differential_evolution step 146: f(x)= 1.19477e-18
# differential_evolution step 147: f(x)= 1.12071e-18
# differential_evolution step 148: f(x)= 6.47137e-19
# differential_evolution step 149: f(x)= 6.47137e-19
# differential_evolution step 150: f(x)= 2.18286e-19
# differential_evolution step 151: f(x)= 2.18286e-19
# differential_evolution step 152: f(x)= 2.18286e-19
# differential_evolution step 153: f(x)= 1.47487e-19
# differential_evolution step 154: f(x)= 7.57473e-20
# differential_evolution step 155: f(x)= 7.57473e-20
# differential_evolution step 156: f(x)= 3.66454e-20
# differential_evolution step 157: f(x)= 3.66454e-20
# differential_evolution step 158: f(x)= 3.12325e-20
# differential_evolution step 159: f(x)= 3.12325e-20
# differential_evolution step 160: f(x)= 2.85212e-20
# differential_evolution step 161: f(x)= 1.19707e-20
# differential_evolution step 162: f(x)= 1.19707e-20
# differential_evolution step 163: f(x)= 1.19707e-20
# differential_evolution step 164: f(x)= 4.64382e-21
# differential_evolution step 165: f(x)= 3.06354e-21
# differential_evolution step 166: f(x)= 2.06485e-21
# differential_evolution step 167: f(x)= 2.06485e-21
# differential_evolution step 168: f(x)= 2.06485e-21
# differential_evolution step 169: f(x)= 1.94854e-21
# differential_evolution step 170: f(x)= 1.62026e-21
# differential_evolution step 171: f(x)= 1.62026e-21
# differential_evolution step 172: f(x)= 1.25189e-21
# differential_evolution step 173: f(x)= 8.51536e-22
# differential_evolution step 174: f(x)= 3.21697e-22
# differential_evolution step 175: f(x)= 2.03346e-22
# differential_evolution step 176: f(x)= 2.03346e-22
# differential_evolution step 177: f(x)= 1.44639e-22
# differential_evolution step 178: f(x)= 1.44639e-22
# differential_evolution step 179: f(x)= 1.26483e-22
# differential_evolution step 180: f(x)= 1.26483e-22
# differential_evolution step 181: f(x)= 1.19899e-22
# differential_evolution step 182: f(x)= 4.28511e-23
# differential_evolution step 183: f(x)= 4.28511e-23
# differential_evolution step 184: f(x)= 3.6138e-23
# differential_evolution step 185: f(x)= 3.6138e-23
# differential_evolution step 186: f(x)= 2.3879e-23
# differential_evolution step 187: f(x)= 5.61214e-24
# differential_evolution step 188: f(x)= 5.61214e-24
# differential_evolution step 189: f(x)= 5.61214e-24
# differential_evolution step 190: f(x)= 5.61214e-24
# differential_evolution step 191: f(x)= 5.25692e-24
# differential_evolution step 192: f(x)= 3.5245e-24
# differential_evolution step 193: f(x)= 1.88875e-24
# differential_evolution step 194: f(x)= 1.88875e-24
# differential_evolution step 195: f(x)= 1.21622e-24
# differential_evolution step 196: f(x)= 6.64696e-25
# differential_evolution step 197: f(x)= 6.64696e-25
# differential_evolution step 198: f(x)= 4.87031e-25
# differential_evolution step 199: f(x)= 1.77844e-25
# differential_evolution step 200: f(x)= 1.77844e-25
# differential_evolution step 201: f(x)= 1.77844e-25
# differential_evolution step 202: f(x)= 1.77844e-25
# differential_evolution step 203: f(x)= 1.77844e-25
# differential_evolution step 204: f(x)= 1.4501e-25
# differential_evolution step 205: f(x)= 9.4238e-26
# differential_evolution step 206: f(x)= 4.51969e-26
# differential_evolution step 207: f(x)= 4.03599e-26
# differential_evolution step 208: f(x)= 2.34775e-26
# differential_evolution step 209: f(x)= 2.34775e-26
# differential_evolution step 210: f(x)= 1.51656e-26
# differential_evolution step 211: f(x)= 6.40897e-27
# differential_evolution step 212: f(x)= 6.18573e-27
# differential_evolution step 213: f(x)= 6.18573e-27
# differential_evolution step 214: f(x)= 6.18573e-27
# differential_evolution step 215: f(x)= 4.94468e-27
# differential_evolution step 216: f(x)= 4.94468e-27
# differential_evolution step 217: f(x)= 1.94561e-27
# differential_evolution step 218: f(x)= 1.94561e-27
# differential_evolution step 219: f(x)= 1.43848e-27
# differential_evolution step 220: f(x)= 1.43848e-27
# differential_evolution step 221: f(x)= 1.29238e-27
# differential_evolution step 222: f(x)= 1.21736e-27
# differential_evolution step 223: f(x)= 6.3529e-28
# differential_evolution step 224: f(x)= 4.93408e-28
# differential_evolution step 225: f(x)= 4.68356e-28
# differential_evolution step 226: f(x)= 3.66248e-28
# differential_evolution step 227: f(x)= 2.59818e-28
# differential_evolution step 228: f(x)= 1.67149e-28
# differential_evolution step 229: f(x)= 1.67149e-28
# differential_evolution step 230: f(x)= 1.33299e-28
# differential_evolution step 231: f(x)= 8.21601e-29
# differential_evolution step 232: f(x)= 7.02414e-29
# differential_evolution step 233: f(x)= 6.3836e-29
# differential_evolution step 234: f(x)= 4.4564e-29
# differential_evolution step 235: f(x)= 2.51647e-29
# differential_evolution step 236: f(x)= 2.30711e-29
# differential_evolution step 237: f(x)= 1.82862e-29
# differential_evolution step 238: f(x)= 1.25186e-29
# differential_evolution step 239: f(x)= 9.46878e-30
# differential_evolution step 240: f(x)= 8.01356e-30
# differential_evolution step 241: f(x)= 8.01356e-30
# differential_evolution step 242: f(x)= 6.03088e-30
# differential_evolution step 243: f(x)= 3.53716e-30
# differential_evolution step 244: f(x)= 3.53716e-30
# differential_evolution step 245: f(x)= 1.4342e-30
# differential_evolution step 246: f(x)= 1.18363e-30
# differential_evolution step 247: f(x)= 1.18363e-30
# differential_evolution step 248: f(x)= 1.18363e-30
# differential_evolution step 249: f(x)= 3.22045e-31
# differential_evolution step 250: f(x)= 3.22045e-31
# differential_evolution step 251: f(x)= 2.48186e-31
# differential_evolution step 252: f(x)= 2.48186e-31
# differential_evolution step 253: f(x)= 2.17092e-31
# differential_evolution step 254: f(x)= 1.3179e-31
# differential_evolution step 255: f(x)= 1.0537e-31
# differential_evolution step 256: f(x)= 1.0537e-31
# differential_evolution step 257: f(x)= 6.79621e-32
# differential_evolution step 258: f(x)= 6.262e-32
# differential_evolution step 259: f(x)= 6.18402e-32
# differential_evolution step 260: f(x)= 2.74681e-32
# differential_evolution step 261: f(x)= 2.71279e-32
# differential_evolution step 262: f(x)= 2.00368e-32
# differential_evolution step 263: f(x)= 2.00368e-32
# differential_evolution step 264: f(x)= 1.18272e-32
# differential_evolution step 265: f(x)= 9.42238e-33
# differential_evolution step 266: f(x)= 8.25887e-33
# differential_evolution step 267: f(x)= 7.12046e-33
# differential_evolution step 268: f(x)= 4.98584e-33
# differential_evolution step 269: f(x)= 4.98584e-33
# differential_evolution step 270: f(x)= 2.66544e-33
# differential_evolution step 271: f(x)= 1.92435e-33
# differential_evolution step 272: f(x)= 1.19573e-33
# differential_evolution step 273: f(x)= 1.12198e-33
# differential_evolution step 274: f(x)= 1.03898e-33
# differential_evolution step 275: f(x)= 3.6062e-34
# differential_evolution step 276: f(x)= 3.07613e-34
# differential_evolution step 277: f(x)= 3.07613e-34
# differential_evolution step 278: f(x)= 1.55893e-34
# differential_evolution step 279: f(x)= 1.17152e-34
# differential_evolution step 280: f(x)= 1.17152e-34
# differential_evolution step 281: f(x)= 1.17152e-34
# differential_evolution step 282: f(x)= 1.17152e-34
# differential_evolution step 283: f(x)= 1.17152e-34
# differential_evolution step 284: f(x)= 7.84121e-35
# differential_evolution step 285: f(x)= 4.89099e-35
# differential_evolution step 286: f(x)= 4.89099e-35
# differential_evolution step 287: f(x)= 4.89099e-35
# differential_evolution step 288: f(x)= 4.89099e-35
# differential_evolution step 289: f(x)= 1.01696e-35
# differential_evolution step 290: f(x)= 1.01696e-35
# differential_evolution step 291: f(x)= 1.01696e-35
# differential_evolution step 292: f(x)= 1.01696e-35
# differential_evolution step 293: f(x)= 1.01696e-35
# differential_evolution step 294: f(x)= 1.01696e-35
# differential_evolution step 295: f(x)= 1.01696e-35
# differential_evolution step 296: f(x)= 1.01696e-35
# differential_evolution step 297: f(x)= 1.01696e-35
# differential_evolution step 298: f(x)= 1.01696e-35
# differential_evolution step 299: f(x)= 1.01696e-35
# differential_evolution step 300: f(x)= 1.01696e-35
# differential_evolution step 301: f(x)= 1.01696e-35
# differential_evolution step 302: f(x)= 1.01696e-35
# differential_evolution step 303: f(x)= 1.01696e-35
# differential_evolution step 304: f(x)= 1.01696e-35
# differential_evolution step 305: f(x)= 1.01696e-35
# differential_evolution step 306: f(x)= 1.01696e-35
# differential_evolution step 307: f(x)= 1.01696e-35
# differential_evolution step 308: f(x)= 1.01696e-35
#  ->  92711  ->  True  ->  1.0169626070716247e-35
#      fun: 1.0169626070716247e-35
#  message: 'Optimization terminated successfully.'
#     nfev: 92711
#      nit: 308
#  success: True
#        x: array([-3.14159265,  3.14159265, -3.14159265,  3.14159265,  3.14159265,
#        -3.14159265, -3.14159265, -3.14159265,  3.14159265, -3.14159265])
# differential_evolution step 1: f(x)= 0.000643929
# differential_evolution step 2: f(x)= 0.000643929
# differential_evolution step 3: f(x)= 0.000643929
# differential_evolution step 4: f(x)= 0.000643929
# differential_evolution step 5: f(x)= 0.000484939
# differential_evolution step 6: f(x)= 0.000392254
# differential_evolution step 7: f(x)= 0.000392254
# differential_evolution step 8: f(x)= 0.000392254
# differential_evolution step 9: f(x)= 0.000392254
# differential_evolution step 10: f(x)= 0.000392254
# differential_evolution step 11: f(x)= 0.000392254
# differential_evolution step 12: f(x)= 0.000392254
# differential_evolution step 13: f(x)= 0.000392254
# differential_evolution step 14: f(x)= 0.000392254
# differential_evolution step 15: f(x)= 0.000346221
# differential_evolution step 16: f(x)= 0.00031474
# differential_evolution step 17: f(x)= 0.00031474
# differential_evolution step 18: f(x)= 0.000285605
# differential_evolution step 19: f(x)= 0.000248868
# differential_evolution step 20: f(x)= 0.000226921
# differential_evolution step 21: f(x)= 0.000199061
# differential_evolution step 22: f(x)= 0.000199061
# differential_evolution step 23: f(x)= 0.000138688
# differential_evolution step 24: f(x)= 0.000138688
# differential_evolution step 25: f(x)= 0.000138688
# differential_evolution step 26: f(x)= 0.000134438
# differential_evolution step 27: f(x)= 0.000134438
# differential_evolution step 28: f(x)= 0.000130118
# differential_evolution step 29: f(x)= 8.77543e-05
# differential_evolution step 30: f(x)= 8.77543e-05
# differential_evolution step 31: f(x)= 8.77543e-05
# differential_evolution step 32: f(x)= 8.1754e-05
# differential_evolution step 33: f(x)= 6.13676e-05
# differential_evolution step 34: f(x)= 5.75414e-05
# differential_evolution step 35: f(x)= 5.75414e-05
# differential_evolution step 36: f(x)= 5.24671e-05
# differential_evolution step 37: f(x)= 4.9195e-05
# differential_evolution step 38: f(x)= 4.9195e-05
# differential_evolution step 39: f(x)= 4.58498e-05
# differential_evolution step 40: f(x)= 4.04951e-05
# differential_evolution step 41: f(x)= 2.30445e-05
# differential_evolution step 42: f(x)= 1.84975e-05
# differential_evolution step 43: f(x)= 1.84975e-05
# differential_evolution step 44: f(x)= 1.19047e-05
# differential_evolution step 45: f(x)= 1.19047e-05
# differential_evolution step 46: f(x)= 1.12331e-05
# differential_evolution step 47: f(x)= 5.698e-06
# differential_evolution step 48: f(x)= 4.04446e-06
# differential_evolution step 49: f(x)= 4.04446e-06
# differential_evolution step 50: f(x)= 2.58404e-06
# differential_evolution step 51: f(x)= 2.58404e-06
# differential_evolution step 52: f(x)= 1.60378e-06
# differential_evolution step 53: f(x)= 1.12434e-06
# differential_evolution step 54: f(x)= 9.22427e-07
# differential_evolution step 55: f(x)= 6.57479e-07
# differential_evolution step 56: f(x)= 5.63921e-07
# differential_evolution step 57: f(x)= 5.54501e-07
# differential_evolution step 58: f(x)= 3.59755e-07
# differential_evolution step 59: f(x)= 2.46944e-07
# differential_evolution step 60: f(x)= 2.34925e-07
# differential_evolution step 61: f(x)= 1.31418e-07
# differential_evolution step 62: f(x)= 1.23209e-07
# differential_evolution step 63: f(x)= 1.05437e-07
# differential_evolution step 64: f(x)= 6.37549e-08
# differential_evolution step 65: f(x)= 6.00562e-08
# differential_evolution step 66: f(x)= 2.61458e-08
# differential_evolution step 67: f(x)= 2.61458e-08
# differential_evolution step 68: f(x)= 2.61458e-08
# differential_evolution step 69: f(x)= 2.34897e-08
# differential_evolution step 70: f(x)= 5.17083e-09
# differential_evolution step 71: f(x)= 5.17083e-09
# differential_evolution step 72: f(x)= 5.17083e-09
# differential_evolution step 73: f(x)= 4.70092e-09
# differential_evolution step 74: f(x)= 4.39589e-09
# differential_evolution step 75: f(x)= 3.38667e-09
# differential_evolution step 76: f(x)= 1.98838e-09
# differential_evolution step 77: f(x)= 1.32388e-09
# differential_evolution step 78: f(x)= 1.32388e-09
# differential_evolution step 79: f(x)= 1.32388e-09
# differential_evolution step 80: f(x)= 1.01228e-09
# differential_evolution step 81: f(x)= 7.30634e-10
# differential_evolution step 82: f(x)= 7.30634e-10
# differential_evolution step 83: f(x)= 3.49534e-10
# differential_evolution step 84: f(x)= 2.12886e-10
# differential_evolution step 85: f(x)= 1.97515e-10
# differential_evolution step 86: f(x)= 1.97515e-10
# differential_evolution step 87: f(x)= 8.07846e-11
# differential_evolution step 88: f(x)= 8.07846e-11
# differential_evolution step 89: f(x)= 3.69213e-11
# differential_evolution step 90: f(x)= 3.69213e-11
# differential_evolution step 91: f(x)= 3.10414e-11
# differential_evolution step 92: f(x)= 2.80039e-11
# differential_evolution step 93: f(x)= 1.70053e-11
# differential_evolution step 94: f(x)= 3.04508e-12
# differential_evolution step 95: f(x)= 3.04508e-12
# differential_evolution step 96: f(x)= 3.04508e-12
# differential_evolution step 97: f(x)= 3.04508e-12
# differential_evolution step 98: f(x)= 3.04508e-12
# differential_evolution step 99: f(x)= 2.407e-12
# differential_evolution step 100: f(x)= 1.80652e-12
# differential_evolution step 101: f(x)= 1.80652e-12
# differential_evolution step 102: f(x)= 1.33907e-12
# differential_evolution step 103: f(x)= 1.07052e-12
# differential_evolution step 104: f(x)= 1.07052e-12
# differential_evolution step 105: f(x)= 6.75638e-13
# differential_evolution step 106: f(x)= 3.75748e-13
# differential_evolution step 107: f(x)= 3.75748e-13
# differential_evolution step 108: f(x)= 1.38543e-13
# differential_evolution step 109: f(x)= 1.38543e-13
# differential_evolution step 110: f(x)= 8.67094e-14
# differential_evolution step 111: f(x)= 7.64526e-14
# differential_evolution step 112: f(x)= 7.64526e-14
# differential_evolution step 113: f(x)= 4.1213e-14
# differential_evolution step 114: f(x)= 3.43581e-14
# differential_evolution step 115: f(x)= 2.23212e-14
# differential_evolution step 116: f(x)= 1.63677e-14
# differential_evolution step 117: f(x)= 1.63677e-14
# differential_evolution step 118: f(x)= 7.48344e-15
# differential_evolution step 119: f(x)= 6.67459e-15
# differential_evolution step 120: f(x)= 5.11544e-15
# differential_evolution step 121: f(x)= 5.11544e-15
# differential_evolution step 122: f(x)= 5.11544e-15
# differential_evolution step 123: f(x)= 3.65708e-15
# differential_evolution step 124: f(x)= 3.45351e-15
# differential_evolution step 125: f(x)= 2.24117e-15
# differential_evolution step 126: f(x)= 1.86829e-15
# differential_evolution step 127: f(x)= 8.43752e-16
# differential_evolution step 128: f(x)= 6.98048e-16
# differential_evolution step 129: f(x)= 4.76631e-16
# differential_evolution step 130: f(x)= 4.11942e-16
# differential_evolution step 131: f(x)= 4.11942e-16
# differential_evolution step 132: f(x)= 3.44881e-16
# differential_evolution step 133: f(x)= 2.35618e-16
# differential_evolution step 134: f(x)= 2.35618e-16
# differential_evolution step 135: f(x)= 1.67469e-16
# differential_evolution step 136: f(x)= 1.40469e-16
# differential_evolution step 137: f(x)= 3.95884e-17
# differential_evolution step 138: f(x)= 3.80425e-17
# differential_evolution step 139: f(x)= 2.83504e-17
# differential_evolution step 140: f(x)= 2.39712e-17
# differential_evolution step 141: f(x)= 9.47429e-18
# differential_evolution step 142: f(x)= 9.47429e-18
# differential_evolution step 143: f(x)= 9.47429e-18
# differential_evolution step 144: f(x)= 9.47429e-18
# differential_evolution step 145: f(x)= 7.05125e-18
# differential_evolution step 146: f(x)= 6.35141e-18
# differential_evolution step 147: f(x)= 3.99966e-18
# differential_evolution step 148: f(x)= 1.87609e-18
# differential_evolution step 149: f(x)= 1.87609e-18
# differential_evolution step 150: f(x)= 1.13228e-18
# differential_evolution step 151: f(x)= 3.29616e-19
# differential_evolution step 152: f(x)= 3.29616e-19
# differential_evolution step 153: f(x)= 3.29616e-19
# differential_evolution step 154: f(x)= 3.29616e-19
# differential_evolution step 155: f(x)= 2.85281e-19
# differential_evolution step 156: f(x)= 2.01261e-19
# differential_evolution step 157: f(x)= 2.01261e-19
# differential_evolution step 158: f(x)= 1.70708e-19
# differential_evolution step 159: f(x)= 1.62772e-19
# differential_evolution step 160: f(x)= 8.95221e-20
# differential_evolution step 161: f(x)= 8.95221e-20
# differential_evolution step 162: f(x)= 7.7721e-20
# differential_evolution step 163: f(x)= 7.7721e-20
# differential_evolution step 164: f(x)= 5.39538e-20
# differential_evolution step 165: f(x)= 3.6324e-20
# differential_evolution step 166: f(x)= 2.96552e-20
# differential_evolution step 167: f(x)= 1.31247e-20
# differential_evolution step 168: f(x)= 1.31247e-20
# differential_evolution step 169: f(x)= 1.31247e-20
# differential_evolution step 170: f(x)= 5.94986e-21
# differential_evolution step 171: f(x)= 4.54206e-21
# differential_evolution step 172: f(x)= 4.29001e-21
# differential_evolution step 173: f(x)= 4.15733e-21
# differential_evolution step 174: f(x)= 2.74835e-21
# differential_evolution step 175: f(x)= 1.9518e-21
# differential_evolution step 176: f(x)= 9.81089e-22
# differential_evolution step 177: f(x)= 9.81089e-22
# differential_evolution step 178: f(x)= 9.81089e-22
# differential_evolution step 179: f(x)= 8.49384e-22
# differential_evolution step 180: f(x)= 5.69488e-22
# differential_evolution step 181: f(x)= 4.05351e-22
# differential_evolution step 182: f(x)= 2.38167e-22
# differential_evolution step 183: f(x)= 2.38167e-22
# differential_evolution step 184: f(x)= 2.38167e-22
# differential_evolution step 185: f(x)= 1.2855e-22
# differential_evolution step 186: f(x)= 1.17897e-22
# differential_evolution step 187: f(x)= 5.42125e-23
# differential_evolution step 188: f(x)= 5.42125e-23
# differential_evolution step 189: f(x)= 3.03751e-23
# differential_evolution step 190: f(x)= 3.03751e-23
# differential_evolution step 191: f(x)= 2.03911e-23
# differential_evolution step 192: f(x)= 2.03911e-23
# differential_evolution step 193: f(x)= 2.03911e-23
# differential_evolution step 194: f(x)= 9.23845e-24
# differential_evolution step 195: f(x)= 9.23845e-24
# differential_evolution step 196: f(x)= 5.67786e-24
# differential_evolution step 197: f(x)= 3.9793e-24
# differential_evolution step 198: f(x)= 1.78973e-24
# differential_evolution step 199: f(x)= 1.78973e-24
# differential_evolution step 200: f(x)= 1.78973e-24
# differential_evolution step 201: f(x)= 1.01835e-24
# differential_evolution step 202: f(x)= 6.97365e-25
# differential_evolution step 203: f(x)= 5.55028e-25
# differential_evolution step 204: f(x)= 5.55028e-25
# differential_evolution step 205: f(x)= 5.55028e-25
# differential_evolution step 206: f(x)= 2.96933e-25
# differential_evolution step 207: f(x)= 2.16506e-25
# differential_evolution step 208: f(x)= 2.16506e-25
# differential_evolution step 209: f(x)= 1.45591e-25
# differential_evolution step 210: f(x)= 1.07292e-25
# differential_evolution step 211: f(x)= 8.79714e-26
# differential_evolution step 212: f(x)= 5.23903e-26
# differential_evolution step 213: f(x)= 3.57493e-26
# differential_evolution step 214: f(x)= 2.89403e-26
# differential_evolution step 215: f(x)= 2.89403e-26
# differential_evolution step 216: f(x)= 2.65193e-26
# differential_evolution step 217: f(x)= 2.44778e-26
# differential_evolution step 218: f(x)= 2.07118e-26
# differential_evolution step 219: f(x)= 1.28086e-26
# differential_evolution step 220: f(x)= 7.59287e-27
# differential_evolution step 221: f(x)= 7.59287e-27
# differential_evolution step 222: f(x)= 3.75675e-27
# differential_evolution step 223: f(x)= 3.75675e-27
# differential_evolution step 224: f(x)= 3.75675e-27
# differential_evolution step 225: f(x)= 3.23526e-27
# differential_evolution step 226: f(x)= 1.63123e-27
# differential_evolution step 227: f(x)= 1.63123e-27
# differential_evolution step 228: f(x)= 1.42592e-27
# differential_evolution step 229: f(x)= 1.12605e-27
# differential_evolution step 230: f(x)= 8.58345e-28
# differential_evolution step 231: f(x)= 3.11948e-28
# differential_evolution step 232: f(x)= 3.11948e-28
# differential_evolution step 233: f(x)= 2.7601e-28
# differential_evolution step 234: f(x)= 2.50667e-28
# differential_evolution step 235: f(x)= 1.24362e-28
# differential_evolution step 236: f(x)= 1.24362e-28
# differential_evolution step 237: f(x)= 1.13672e-28
# differential_evolution step 238: f(x)= 1.09471e-28
# differential_evolution step 239: f(x)= 5.57491e-29
# differential_evolution step 240: f(x)= 5.30051e-29
# differential_evolution step 241: f(x)= 2.52754e-29
# differential_evolution step 242: f(x)= 2.52754e-29
# differential_evolution step 243: f(x)= 2.43067e-29
# differential_evolution step 244: f(x)= 1.45509e-29
# differential_evolution step 245: f(x)= 1.45509e-29
# differential_evolution step 246: f(x)= 8.90417e-30
# differential_evolution step 247: f(x)= 8.90417e-30
# differential_evolution step 248: f(x)= 7.33241e-30
# differential_evolution step 249: f(x)= 5.7678e-30
# differential_evolution step 250: f(x)= 2.2064e-30
# differential_evolution step 251: f(x)= 2.2064e-30
# differential_evolution step 252: f(x)= 2.2064e-30
# differential_evolution step 253: f(x)= 1.88702e-30
# differential_evolution step 254: f(x)= 1.36207e-30
# differential_evolution step 255: f(x)= 7.11457e-31
# differential_evolution step 256: f(x)= 5.89595e-31
# differential_evolution step 257: f(x)= 5.89595e-31
# differential_evolution step 258: f(x)= 5.83548e-31
# differential_evolution step 259: f(x)= 4.34346e-31
# differential_evolution step 260: f(x)= 2.89263e-31
# differential_evolution step 261: f(x)= 2.46066e-31
# differential_evolution step 262: f(x)= 1.9264e-31
# differential_evolution step 263: f(x)= 1.13594e-31
# differential_evolution step 264: f(x)= 1.13594e-31
# differential_evolution step 265: f(x)= 6.9925e-32
# differential_evolution step 266: f(x)= 6.9925e-32
# differential_evolution step 267: f(x)= 4.02543e-32
# differential_evolution step 268: f(x)= 2.05369e-32
# differential_evolution step 269: f(x)= 2.05369e-32
# differential_evolution step 270: f(x)= 2.05369e-32
# differential_evolution step 271: f(x)= 1.42131e-32
# differential_evolution step 272: f(x)= 1.20057e-32
# differential_evolution step 273: f(x)= 8.90449e-33
# differential_evolution step 274: f(x)= 8.90449e-33
# differential_evolution step 275: f(x)= 8.28837e-33
# differential_evolution step 276: f(x)= 3.90532e-33
# differential_evolution step 277: f(x)= 2.88671e-33
# differential_evolution step 278: f(x)= 2.61098e-33
# differential_evolution step 279: f(x)= 2.25129e-33
# differential_evolution step 280: f(x)= 9.76255e-34
# differential_evolution step 281: f(x)= 9.76255e-34
# differential_evolution step 282: f(x)= 9.76255e-34
# differential_evolution step 283: f(x)= 4.53336e-34
# differential_evolution step 284: f(x)= 4.53336e-34
# differential_evolution step 285: f(x)= 4.53336e-34
# differential_evolution step 286: f(x)= 4.53336e-34
# differential_evolution step 287: f(x)= 4.53336e-34
# differential_evolution step 288: f(x)= 3.46353e-34
# differential_evolution step 289: f(x)= 3.46353e-34
# differential_evolution step 290: f(x)= 3.46353e-34
# differential_evolution step 291: f(x)= 3.46353e-34
# differential_evolution step 292: f(x)= 8.76502e-35
# differential_evolution step 293: f(x)= 8.76502e-35
# differential_evolution step 294: f(x)= 8.76502e-35
# differential_evolution step 295: f(x)= 8.76502e-35
# differential_evolution step 296: f(x)= 8.76502e-35
# differential_evolution step 297: f(x)= 8.76502e-35
# differential_evolution step 298: f(x)= 8.76502e-35
# differential_evolution step 299: f(x)= 8.76502e-35
# differential_evolution step 300: f(x)= 8.76502e-35
# differential_evolution step 301: f(x)= 8.76502e-35
# differential_evolution step 302: f(x)= 1.01696e-35
# differential_evolution step 303: f(x)= 1.01696e-35
# differential_evolution step 304: f(x)= 1.01696e-35
# differential_evolution step 305: f(x)= 1.01696e-35
# differential_evolution step 306: f(x)= 1.01696e-35
# differential_evolution step 307: f(x)= 1.01696e-35
# differential_evolution step 308: f(x)= 1.01696e-35
# differential_evolution step 309: f(x)= 1.01696e-35
# ...
# differential_evolution step 14: f(x)= 0.000227917
# differential_evolution step 15: f(x)= 0.000227917
# differential_evolution step 16: f(x)= 0.000189381
# differential_evolution step 17: f(x)= 0.000189381
# differential_evolution step 18: f(x)= 0.000189381
# differential_evolution step 19: f(x)= 0.000189381
# differential_evolution step 20: f(x)= 0.000189381
# differential_evolution step 21: f(x)= 0.000189381
# differential_evolution step 22: f(x)= 0.000189381
# differential_evolution step 23: f(x)= 0.000189381
# differential_evolution step 24: f(x)= 0.000154289
# differential_evolution step 25: f(x)= 0.000154289
# differential_evolution step 26: f(x)= 0.00015064
# differential_evolution step 27: f(x)= 0.00015064
# differential_evolution step 28: f(x)= 0.000148678
# differential_evolution step 29: f(x)= 9.3972e-05
# differential_evolution step 30: f(x)= 8.48281e-05
# differential_evolution step 31: f(x)= 8.48281e-05
# differential_evolution step 32: f(x)= 6.08316e-05
# differential_evolution step 33: f(x)= 2.76545e-05
# differential_evolution step 34: f(x)= 2.76545e-05
# differential_evolution step 35: f(x)= 1.83706e-05
# differential_evolution step 36: f(x)= 1.83706e-05
# differential_evolution step 37: f(x)= 1.83706e-05
# differential_evolution step 38: f(x)= 1.83706e-05
# differential_evolution step 39: f(x)= 1.60584e-05
# differential_evolution step 40: f(x)= 1.40228e-05
# differential_evolution step 41: f(x)= 1.12689e-05
# differential_evolution step 42: f(x)= 5.46135e-06
# differential_evolution step 43: f(x)= 5.46135e-06
# differential_evolution step 44: f(x)= 4.13454e-06
# differential_evolution step 45: f(x)= 2.32657e-06
# differential_evolution step 46: f(x)= 2.32657e-06
# differential_evolution step 47: f(x)= 2.32657e-06
# differential_evolution step 48: f(x)= 2.25307e-06
# differential_evolution step 49: f(x)= 9.42837e-07
# differential_evolution step 50: f(x)= 9.42837e-07
# differential_evolution step 51: f(x)= 3.23991e-07
# differential_evolution step 52: f(x)= 3.23991e-07
# differential_evolution step 53: f(x)= 2.72705e-07
# differential_evolution step 54: f(x)= 1.99774e-07
# differential_evolution step 55: f(x)= 1.5934e-07
# differential_evolution step 56: f(x)= 1.5934e-07
# differential_evolution step 57: f(x)= 1.38723e-07
# differential_evolution step 58: f(x)= 1.0156e-07
# differential_evolution step 59: f(x)= 6.9342e-08
# differential_evolution step 60: f(x)= 5.42542e-08
# differential_evolution step 61: f(x)= 2.64334e-08
# differential_evolution step 62: f(x)= 2.01772e-08
# differential_evolution step 63: f(x)= 1.56721e-08
# differential_evolution step 64: f(x)= 1.56721e-08
# differential_evolution step 65: f(x)= 9.83171e-09
# differential_evolution step 66: f(x)= 9.83171e-09
# differential_evolution step 67: f(x)= 7.1032e-09
# differential_evolution step 68: f(x)= 6.81896e-09
# differential_evolution step 69: f(x)= 4.42616e-09
# differential_evolution step 70: f(x)= 2.21642e-09
# differential_evolution step 71: f(x)= 2.21642e-09
# differential_evolution step 72: f(x)= 2.06056e-09
# differential_evolution step 73: f(x)= 1.95722e-09
# differential_evolution step 74: f(x)= 1.38121e-09
# differential_evolution step 75: f(x)= 1.01661e-09
# differential_evolution step 76: f(x)= 5.65488e-10
# differential_evolution step 77: f(x)= 5.65488e-10
# differential_evolution step 78: f(x)= 3.91825e-10
# differential_evolution step 79: f(x)= 2.78915e-10
# differential_evolution step 80: f(x)= 2.77209e-10
# differential_evolution step 81: f(x)= 2.43728e-10
# differential_evolution step 82: f(x)= 2.18655e-10
# differential_evolution step 83: f(x)= 1.44375e-10
# differential_evolution step 84: f(x)= 1.44375e-10
# differential_evolution step 85: f(x)= 1.00076e-10
# differential_evolution step 86: f(x)= 8.8475e-11
# differential_evolution step 87: f(x)= 5.61656e-11
# differential_evolution step 88: f(x)= 4.57098e-11
# differential_evolution step 89: f(x)= 4.13804e-11
# differential_evolution step 90: f(x)= 4.12868e-11
# differential_evolution step 91: f(x)= 2.54569e-11
# differential_evolution step 92: f(x)= 2.25813e-11
# differential_evolution step 93: f(x)= 2.01594e-11
# differential_evolution step 94: f(x)= 1.01656e-11
# differential_evolution step 95: f(x)= 6.85272e-12
# differential_evolution step 96: f(x)= 6.85272e-12
# differential_evolution step 97: f(x)= 3.99768e-12
# differential_evolution step 98: f(x)= 3.24491e-12
# differential_evolution step 99: f(x)= 2.45651e-12
# differential_evolution step 100: f(x)= 2.17876e-12
# differential_evolution step 101: f(x)= 1.42247e-12
# differential_evolution step 102: f(x)= 1.26941e-12
# differential_evolution step 103: f(x)= 7.29872e-13
# differential_evolution step 104: f(x)= 7.29872e-13
# differential_evolution step 105: f(x)= 5.24156e-13
# differential_evolution step 106: f(x)= 3.54472e-13
# differential_evolution step 107: f(x)= 3.54472e-13
# differential_evolution step 108: f(x)= 3.37439e-13
# differential_evolution step 109: f(x)= 3.13178e-13
# differential_evolution step 110: f(x)= 2.49302e-13
# differential_evolution step 111: f(x)= 1.98526e-13
# differential_evolution step 112: f(x)= 5.12627e-14
# differential_evolution step 113: f(x)= 5.12627e-14
# differential_evolution step 114: f(x)= 5.12627e-14
# differential_evolution step 115: f(x)= 4.75303e-14
# differential_evolution step 116: f(x)= 4.08922e-14
# differential_evolution step 117: f(x)= 1.94485e-14
# differential_evolution step 118: f(x)= 1.94485e-14
# differential_evolution step 119: f(x)= 1.72356e-14
# differential_evolution step 120: f(x)= 1.49304e-14
# differential_evolution step 121: f(x)= 1.49304e-14
# differential_evolution step 122: f(x)= 9.3682e-15
# differential_evolution step 123: f(x)= 7.82046e-15
# differential_evolution step 124: f(x)= 7.04852e-15
# differential_evolution step 125: f(x)= 6.14325e-15
# differential_evolution step 126: f(x)= 5.53442e-15
# differential_evolution step 127: f(x)= 3.49525e-15
# differential_evolution step 128: f(x)= 2.84056e-15
# differential_evolution step 129: f(x)= 1.79839e-15
# differential_evolution step 130: f(x)= 1.79839e-15
# differential_evolution step 131: f(x)= 7.95277e-16
# differential_evolution step 132: f(x)= 7.95277e-16
# differential_evolution step 133: f(x)= 7.54671e-16
# differential_evolution step 134: f(x)= 6.43619e-16
# differential_evolution step 135: f(x)= 2.91341e-16
# differential_evolution step 136: f(x)= 2.91341e-16
# differential_evolution step 137: f(x)= 2.91341e-16
# differential_evolution step 138: f(x)= 2.03978e-16
# differential_evolution step 139: f(x)= 1.85996e-16
# differential_evolution step 140: f(x)= 1.85996e-16
# differential_evolution step 141: f(x)= 9.89576e-17
# differential_evolution step 142: f(x)= 7.01554e-17
# differential_evolution step 143: f(x)= 5.24785e-17
# differential_evolution step 144: f(x)= 2.93549e-17
# differential_evolution step 145: f(x)= 2.93549e-17
# differential_evolution step 146: f(x)= 9.55138e-18
# differential_evolution step 147: f(x)= 9.55138e-18
# differential_evolution step 148: f(x)= 9.55138e-18
# differential_evolution step 149: f(x)= 9.55138e-18
# differential_evolution step 150: f(x)= 8.33746e-18
# differential_evolution step 151: f(x)= 8.33746e-18
# differential_evolution step 152: f(x)= 7.05518e-18
# differential_evolution step 153: f(x)= 4.08751e-18
# differential_evolution step 154: f(x)= 2.19935e-18
# differential_evolution step 155: f(x)= 7.4954e-19
# differential_evolution step 156: f(x)= 7.03907e-19
# differential_evolution step 157: f(x)= 7.03907e-19
# differential_evolution step 158: f(x)= 5.24674e-19
# differential_evolution step 159: f(x)= 5.24674e-19
# differential_evolution step 160: f(x)= 5.14672e-19
# differential_evolution step 161: f(x)= 4.92314e-19
# differential_evolution step 162: f(x)= 3.76333e-19
# differential_evolution step 163: f(x)= 1.807e-19
# differential_evolution step 164: f(x)= 1.23175e-19
# differential_evolution step 165: f(x)= 1.23175e-19
# differential_evolution step 166: f(x)= 8.91565e-20
# differential_evolution step 167: f(x)= 8.0974e-20
# differential_evolution step 168: f(x)= 6.79924e-20
# differential_evolution step 169: f(x)= 3.15859e-20
# differential_evolution step 170: f(x)= 3.15859e-20
# differential_evolution step 171: f(x)= 2.21543e-20
# differential_evolution step 172: f(x)= 9.67594e-21
# differential_evolution step 173: f(x)= 9.67594e-21
# differential_evolution step 174: f(x)= 4.68443e-21
# differential_evolution step 175: f(x)= 4.68443e-21
# differential_evolution step 176: f(x)= 4.52065e-21
# differential_evolution step 177: f(x)= 3.92818e-21
# differential_evolution step 178: f(x)= 2.75235e-21
# differential_evolution step 179: f(x)= 2.75235e-21
# differential_evolution step 180: f(x)= 1.65174e-21
# differential_evolution step 181: f(x)= 1.55425e-21
# differential_evolution step 182: f(x)= 9.70771e-22
# differential_evolution step 183: f(x)= 5.23838e-22
# differential_evolution step 184: f(x)= 1.86823e-22
# differential_evolution step 185: f(x)= 1.86823e-22
# differential_evolution step 186: f(x)= 1.86823e-22
# differential_evolution step 187: f(x)= 1.86823e-22
# differential_evolution step 188: f(x)= 9.60614e-23
# differential_evolution step 189: f(x)= 9.55715e-23
# differential_evolution step 190: f(x)= 9.55715e-23
# differential_evolution step 191: f(x)= 3.13877e-23
# differential_evolution step 192: f(x)= 3.13877e-23
# differential_evolution step 193: f(x)= 3.13877e-23
# differential_evolution step 194: f(x)= 2.99227e-23
# differential_evolution step 195: f(x)= 2.68405e-23
# differential_evolution step 196: f(x)= 1.75643e-23
# differential_evolution step 197: f(x)= 1.38071e-23
# differential_evolution step 198: f(x)= 1.01633e-23
# differential_evolution step 199: f(x)= 8.19979e-24
# differential_evolution step 200: f(x)= 5.60647e-24
# differential_evolution step 201: f(x)= 4.72879e-24
# differential_evolution step 202: f(x)= 4.72879e-24
# differential_evolution step 203: f(x)= 2.1437e-24
# differential_evolution step 204: f(x)= 2.1437e-24
# differential_evolution step 205: f(x)= 2.1437e-24
# differential_evolution step 206: f(x)= 1.11241e-24
# differential_evolution step 207: f(x)= 8.13751e-25
# differential_evolution step 208: f(x)= 5.89183e-25
# differential_evolution step 209: f(x)= 5.89183e-25
# differential_evolution step 210: f(x)= 5.51291e-25
# differential_evolution step 211: f(x)= 2.54108e-25
# differential_evolution step 212: f(x)= 2.12665e-25
# differential_evolution step 213: f(x)= 2.07396e-25
# differential_evolution step 214: f(x)= 1.5256e-25
# differential_evolution step 215: f(x)= 1.16137e-25
# differential_evolution step 216: f(x)= 1.06177e-25
# differential_evolution step 217: f(x)= 7.17366e-26
# differential_evolution step 218: f(x)= 3.54968e-26
# differential_evolution step 219: f(x)= 3.54968e-26
# differential_evolution step 220: f(x)= 2.51867e-26
# differential_evolution step 221: f(x)= 2.51867e-26
# differential_evolution step 222: f(x)= 1.7954e-26
# differential_evolution step 223: f(x)= 1.7954e-26
# differential_evolution step 224: f(x)= 1.12698e-26
# differential_evolution step 225: f(x)= 9.00222e-27
# differential_evolution step 226: f(x)= 7.57346e-27
# differential_evolution step 227: f(x)= 4.95221e-27
# differential_evolution step 228: f(x)= 3.04459e-27
# differential_evolution step 229: f(x)= 2.76047e-27
# differential_evolution step 230: f(x)= 2.0163e-27
# differential_evolution step 231: f(x)= 1.8471e-27
# differential_evolution step 232: f(x)= 1.8471e-27
# differential_evolution step 233: f(x)= 1.05496e-27
# differential_evolution step 234: f(x)= 1.05496e-27
# differential_evolution step 235: f(x)= 9.04708e-28
# differential_evolution step 236: f(x)= 8.1226e-28
# differential_evolution step 237: f(x)= 4.91687e-28
# differential_evolution step 238: f(x)= 4.21034e-28
# differential_evolution step 239: f(x)= 1.61326e-28
# differential_evolution step 240: f(x)= 1.61326e-28
# differential_evolution step 241: f(x)= 1.61326e-28
# differential_evolution step 242: f(x)= 1.03106e-28
# differential_evolution step 243: f(x)= 9.27886e-29
# differential_evolution step 244: f(x)= 7.49607e-29
# differential_evolution step 245: f(x)= 4.82921e-29
# differential_evolution step 246: f(x)= 4.38698e-29
# differential_evolution step 247: f(x)= 2.82399e-29
# differential_evolution step 248: f(x)= 1.96765e-29
# differential_evolution step 249: f(x)= 1.56659e-29
# differential_evolution step 250: f(x)= 1.56659e-29
# differential_evolution step 251: f(x)= 1.37016e-29
# differential_evolution step 252: f(x)= 1.27698e-29
# differential_evolution step 253: f(x)= 6.27387e-30
# differential_evolution step 254: f(x)= 6.27387e-30
# differential_evolution step 255: f(x)= 6.12867e-30
# differential_evolution step 256: f(x)= 4.3341e-30
# differential_evolution step 257: f(x)= 2.31613e-30
# differential_evolution step 258: f(x)= 1.93008e-30
# differential_evolution step 259: f(x)= 1.50519e-30
# differential_evolution step 260: f(x)= 3.43827e-31
# differential_evolution step 261: f(x)= 3.43827e-31
# differential_evolution step 262: f(x)= 3.43827e-31
# differential_evolution step 263: f(x)= 3.43827e-31
# differential_evolution step 264: f(x)= 3.43827e-31
# differential_evolution step 265: f(x)= 1.2571e-31
# differential_evolution step 266: f(x)= 1.2571e-31
# differential_evolution step 267: f(x)= 1.04851e-31
# differential_evolution step 268: f(x)= 8.45961e-32
# differential_evolution step 269: f(x)= 6.36548e-32
# differential_evolution step 270: f(x)= 4.50032e-32
# differential_evolution step 271: f(x)= 3.72838e-32
# differential_evolution step 272: f(x)= 3.72838e-32
# differential_evolution step 273: f(x)= 2.28122e-32
# differential_evolution step 274: f(x)= 1.69937e-32
# differential_evolution step 275: f(x)= 1.05425e-32
# differential_evolution step 276: f(x)= 1.05425e-32
# differential_evolution step 277: f(x)= 9.77883e-33
# differential_evolution step 278: f(x)= 6.08923e-33
# differential_evolution step 279: f(x)= 6.08923e-33
# differential_evolution step 280: f(x)= 4.19173e-33
# differential_evolution step 281: f(x)= 4.19173e-33
# differential_evolution step 282: f(x)= 3.87354e-33
# differential_evolution step 283: f(x)= 2.77794e-33
# differential_evolution step 284: f(x)= 1.05374e-33
# differential_evolution step 285: f(x)= 1.05374e-33
# differential_evolution step 286: f(x)= 1.05374e-33
# differential_evolution step 287: f(x)= 9.4124e-34
# differential_evolution step 288: f(x)= 7.12039e-34
# differential_evolution step 289: f(x)= 7.12039e-34
# differential_evolution step 290: f(x)= 7.12039e-34
# differential_evolution step 291: f(x)= 1.17152e-34
# differential_evolution step 292: f(x)= 1.17152e-34
# differential_evolution step 293: f(x)= 1.17152e-34
# differential_evolution step 294: f(x)= 1.17152e-34
# differential_evolution step 295: f(x)= 1.17152e-34
# differential_evolution step 296: f(x)= 1.17152e-34
# differential_evolution step 297: f(x)= 1.17152e-34
# differential_evolution step 298: f(x)= 7.84121e-35
# differential_evolution step 299: f(x)= 7.84121e-35
# differential_evolution step 300: f(x)= 7.84121e-35
# differential_evolution step 301: f(x)= 7.84121e-35
# differential_evolution step 302: f(x)= 4.89099e-35
# differential_evolution step 303: f(x)= 4.89099e-35
# differential_evolution step 304: f(x)= 1.01696e-35
# differential_evolution step 305: f(x)= 1.01696e-35
# differential_evolution step 306: f(x)= 1.01696e-35
# differential_evolution step 307: f(x)= 1.01696e-35
# differential_evolution step 308: f(x)= 1.01696e-35
# differential_evolution step 309: f(x)= 1.01696e-35
# differential_evolution step 310: f(x)= 1.01696e-35
# differential_evolution step 311: f(x)= 1.01696e-35
# differential_evolution step 312: f(x)= 1.01696e-35
# differential_evolution step 313: f(x)= 1.01696e-35
# differential_evolution step 314: f(x)= 1.01696e-35
# differential_evolution step 315: f(x)= 1.01696e-35
# differential_evolution step 316: f(x)= 1.01696e-35
# differential_evolution step 317: f(x)= 1.01696e-35
# differential_evolution step 318: f(x)= 1.01696e-35
# differential_evolution step 319: f(x)= 1.01696e-35
# differential_evolution step 320: f(x)= 1.01696e-35
# differential_evolution step 321: f(x)= 1.01696e-35
# differential_evolution step 322: f(x)= 1.01696e-35
#  ->  96911  ->  True  ->  1.0169626070716247e-35
#      fun: 1.0169626070716247e-35
#  message: 'Optimization terminated successfully.'
#     nfev: 96911
#      nit: 322
#  success: True
#        x: array([-3.14159265, -3.14159265,  3.14159265, -3.14159265,  3.14159265,
#         3.14159265, -3.14159265, -3.14159265,  3.14159265,  3.14159265])

# %% [markdown]
# ---

# %% [markdown]
# **Strategy rand1bin ---- CR = 0.9 & F = 0.8**

# %%
CR = 0.9
F = 0.8

for i in range(5):
  result = differential_evolution(xinSheYangN4, bounds, init = "random", mutation = F, recombination = CR, popsize=30, maxiter = 1200, strategy = "rand1bin", disp=True)
  print( " -> " , result.nfev, " -> " , result.success, " -> " , result.fun)
  # summarize the result
  print(result)
# Out:
# differential_evolution step 1: f(x)= 0.000829769
# differential_evolution step 2: f(x)= 0.000829769
# differential_evolution step 3: f(x)= 0.000829769
# differential_evolution step 4: f(x)= 0.000829769
# differential_evolution step 5: f(x)= 0.000669265
# differential_evolution step 6: f(x)= 0.000669265
# differential_evolution step 7: f(x)= 0.000669265
# differential_evolution step 8: f(x)= 0.000618848
# differential_evolution step 9: f(x)= 0.000246374
# differential_evolution step 10: f(x)= 0.000246374
# differential_evolution step 11: f(x)= 0.000246374
# differential_evolution step 12: f(x)= 0.000246374
# differential_evolution step 13: f(x)= 0.000246374
# differential_evolution step 14: f(x)= 0.000246374
# differential_evolution step 15: f(x)= 0.000246374
# differential_evolution step 16: f(x)= 0.000246374
# differential_evolution step 17: f(x)= 0.000246374
# differential_evolution step 18: f(x)= 0.000246374
# differential_evolution step 19: f(x)= 0.000246374
# differential_evolution step 20: f(x)= 0.000246374
# differential_evolution step 21: f(x)= 0.000246374
# differential_evolution step 22: f(x)= 0.000246374
# differential_evolution step 23: f(x)= 0.000246374
# differential_evolution step 24: f(x)= 0.000246374
# differential_evolution step 25: f(x)= 0.000246374
# differential_evolution step 26: f(x)= 0.000246374
# differential_evolution step 27: f(x)= 0.000246374
# differential_evolution step 28: f(x)= 0.000246374
# differential_evolution step 29: f(x)= 0.000246374
# differential_evolution step 30: f(x)= 0.000246374
# differential_evolution step 31: f(x)= 0.000246374
# differential_evolution step 32: f(x)= 0.000246374
# differential_evolution step 33: f(x)= 0.000246374
# differential_evolution step 34: f(x)= 0.000237145
# differential_evolution step 35: f(x)= 0.000237145
# differential_evolution step 36: f(x)= 0.000237145
# differential_evolution step 37: f(x)= 0.000237145
# differential_evolution step 38: f(x)= 0.000237145
# differential_evolution step 39: f(x)= 0.000237145
# differential_evolution step 40: f(x)= 0.000237145
# differential_evolution step 41: f(x)= 0.000237145
# differential_evolution step 42: f(x)= 0.000237145
# differential_evolution step 43: f(x)= 0.000237145
# differential_evolution step 44: f(x)= 0.000237145
# differential_evolution step 45: f(x)= 0.000237145
# differential_evolution step 46: f(x)= 0.000237145
# differential_evolution step 47: f(x)= 0.000237145
# differential_evolution step 48: f(x)= 0.000237145
# differential_evolution step 49: f(x)= 0.000237145
# differential_evolution step 50: f(x)= 0.000237145
# differential_evolution step 51: f(x)= 0.000237145
# differential_evolution step 52: f(x)= 0.000237145
# differential_evolution step 53: f(x)= 0.000237145
# differential_evolution step 54: f(x)= 0.000237145
# differential_evolution step 55: f(x)= 0.000237145
# differential_evolution step 56: f(x)= 0.000237145
# differential_evolution step 57: f(x)= 0.000237145
# differential_evolution step 58: f(x)= 0.000237145
# differential_evolution step 59: f(x)= 0.000237145
# differential_evolution step 60: f(x)= 0.000237145
# differential_evolution step 61: f(x)= 0.000237145
# differential_evolution step 62: f(x)= 0.000237145
# differential_evolution step 63: f(x)= 0.000237145
# differential_evolution step 64: f(x)= 0.000237145
# differential_evolution step 65: f(x)= 0.000237145
# differential_evolution step 66: f(x)= 0.000237145
# differential_evolution step 67: f(x)= 0.000237145
# differential_evolution step 68: f(x)= 0.000237145
# differential_evolution step 69: f(x)= 0.000237145
# differential_evolution step 70: f(x)= 0.000237145
# differential_evolution step 71: f(x)= 0.000237145
# differential_evolution step 72: f(x)= 0.000237145
# differential_evolution step 73: f(x)= 0.000237145
# differential_evolution step 74: f(x)= 0.000237145
# differential_evolution step 75: f(x)= 0.000237145
# differential_evolution step 76: f(x)= 0.000237145
# differential_evolution step 77: f(x)= 0.000237145
# differential_evolution step 78: f(x)= 0.000237145
# differential_evolution step 79: f(x)= 0.000165636
# differential_evolution step 80: f(x)= 0.000165636
# differential_evolution step 81: f(x)= 0.000165636
# differential_evolution step 82: f(x)= 0.000165636
# differential_evolution step 83: f(x)= 0.000165636
# differential_evolution step 84: f(x)= 0.000165636
# differential_evolution step 85: f(x)= 0.000165636
# differential_evolution step 86: f(x)= 0.000165636
# differential_evolution step 87: f(x)= 0.000165636
# differential_evolution step 88: f(x)= 0.000165636
# differential_evolution step 89: f(x)= 0.000165636
# differential_evolution step 90: f(x)= 0.000165636
# differential_evolution step 91: f(x)= 0.000165636
# differential_evolution step 92: f(x)= 0.000165636
# differential_evolution step 93: f(x)= 0.000165636
# differential_evolution step 94: f(x)= 0.000165636
# differential_evolution step 95: f(x)= 0.000165636
# differential_evolution step 96: f(x)= 0.000165636
# differential_evolution step 97: f(x)= 0.000165636
# differential_evolution step 98: f(x)= 0.000165636
# differential_evolution step 99: f(x)= 0.000165636
# differential_evolution step 100: f(x)= 0.000165636
# differential_evolution step 101: f(x)= 0.000165636
# differential_evolution step 102: f(x)= 0.000165636
# differential_evolution step 103: f(x)= 0.000165636
# differential_evolution step 104: f(x)= 0.000165636
# differential_evolution step 105: f(x)= 0.000165636
# differential_evolution step 106: f(x)= 0.000165636
# differential_evolution step 107: f(x)= 0.000165636
# differential_evolution step 108: f(x)= 0.000165636
# differential_evolution step 109: f(x)= 0.000165636
# differential_evolution step 110: f(x)= 0.000165636
# differential_evolution step 111: f(x)= 0.000165636
# differential_evolution step 112: f(x)= 0.000165636
# differential_evolution step 113: f(x)= 0.000165636
# differential_evolution step 114: f(x)= 0.000165636
# differential_evolution step 115: f(x)= 0.000165636
# differential_evolution step 116: f(x)= 0.000165636
# differential_evolution step 117: f(x)= 0.000165636
# differential_evolution step 118: f(x)= 0.000165636
# differential_evolution step 119: f(x)= 0.000165636
# differential_evolution step 120: f(x)= 0.000165636
# differential_evolution step 121: f(x)= 0.000165636
# differential_evolution step 122: f(x)= 0.000165636
# differential_evolution step 123: f(x)= 0.000165636
# differential_evolution step 124: f(x)= 0.000165636
# differential_evolution step 125: f(x)= 0.000165636
# differential_evolution step 126: f(x)= 0.000165636
# differential_evolution step 127: f(x)= 0.000165636
# differential_evolution step 128: f(x)= 0.000165636
# differential_evolution step 129: f(x)= 0.000165636
# differential_evolution step 130: f(x)= 0.000165636
# differential_evolution step 131: f(x)= 0.000165636
# differential_evolution step 132: f(x)= 0.000165636
# differential_evolution step 133: f(x)= 0.000165636
# differential_evolution step 134: f(x)= 0.000165636
# differential_evolution step 135: f(x)= 0.000165636
# differential_evolution step 136: f(x)= 0.000165636
# differential_evolution step 137: f(x)= 0.000165636
# differential_evolution step 138: f(x)= 0.000158315
# differential_evolution step 139: f(x)= 0.000158315
# differential_evolution step 140: f(x)= 0.000158315
# differential_evolution step 141: f(x)= 0.000158315
# differential_evolution step 142: f(x)= 0.000158315
# differential_evolution step 143: f(x)= 0.000158315
# differential_evolution step 144: f(x)= 0.000158315
# differential_evolution step 145: f(x)= 0.000158315
# differential_evolution step 146: f(x)= 0.000158315
# differential_evolution step 147: f(x)= 0.000158315
# differential_evolution step 148: f(x)= 0.000158315
# differential_evolution step 149: f(x)= 0.000158315
# differential_evolution step 150: f(x)= 0.000158315
# differential_evolution step 151: f(x)= 0.000158315
# differential_evolution step 152: f(x)= 0.000158315
# differential_evolution step 153: f(x)= 0.000158315
# differential_evolution step 154: f(x)= 0.000158315
# differential_evolution step 155: f(x)= 0.000158315
# differential_evolution step 156: f(x)= 0.000158315
# differential_evolution step 157: f(x)= 0.000158315
# differential_evolution step 158: f(x)= 0.000158315
# differential_evolution step 159: f(x)= 0.000158315
# differential_evolution step 160: f(x)= 0.000158315
# differential_evolution step 161: f(x)= 0.000158315
# differential_evolution step 162: f(x)= 0.000158315
# differential_evolution step 163: f(x)= 0.000158315
# differential_evolution step 164: f(x)= 0.000158315
# differential_evolution step 165: f(x)= 0.000158315
# differential_evolution step 166: f(x)= 0.000158315
# differential_evolution step 167: f(x)= 0.000158315
# differential_evolution step 168: f(x)= 0.000158315
# differential_evolution step 169: f(x)= 0.000158315
# differential_evolution step 170: f(x)= 0.000158315
# differential_evolution step 171: f(x)= 0.000158315
# differential_evolution step 172: f(x)= 0.000158315
# differential_evolution step 173: f(x)= 0.000158315
# differential_evolution step 174: f(x)= 0.000158315
# differential_evolution step 175: f(x)= 0.000158315
# differential_evolution step 176: f(x)= 0.000158315
# differential_evolution step 177: f(x)= 0.000158315
# differential_evolution step 178: f(x)= 0.000158315
# differential_evolution step 179: f(x)= 0.000158315
# differential_evolution step 180: f(x)= 0.000158315
# differential_evolution step 181: f(x)= 0.000158315
# differential_evolution step 182: f(x)= 0.000158315
# differential_evolution step 183: f(x)= 0.000158315
# differential_evolution step 184: f(x)= 0.000158315
# differential_evolution step 185: f(x)= 0.000158315
# differential_evolution step 186: f(x)= 0.000158315
# differential_evolution step 187: f(x)= 0.000158315
# differential_evolution step 188: f(x)= 0.000158315
# differential_evolution step 189: f(x)= 0.000158315
# differential_evolution step 190: f(x)= 0.000158315
# differential_evolution step 191: f(x)= 0.000158315
# differential_evolution step 192: f(x)= 0.000158315
# differential_evolution step 193: f(x)= 0.000158315
# differential_evolution step 194: f(x)= 0.000158315
# differential_evolution step 195: f(x)= 0.000158315
# differential_evolution step 196: f(x)= 0.000158315
# differential_evolution step 197: f(x)= 0.000158315
# differential_evolution step 198: f(x)= 0.000158315
# differential_evolution step 199: f(x)= 0.000158315
# differential_evolution step 200: f(x)= 0.000158315
# differential_evolution step 201: f(x)= 0.000158315
# differential_evolution step 202: f(x)= 0.000158315
# differential_evolution step 203: f(x)= 0.000158315
# differential_evolution step 204: f(x)= 0.000158315
# differential_evolution step 205: f(x)= 0.000158315
# differential_evolution step 206: f(x)= 0.000158315
# differential_evolution step 207: f(x)= 0.000158315
# differential_evolution step 208: f(x)= 0.000158315
# differential_evolution step 209: f(x)= 0.000158315
# differential_evolution step 210: f(x)= 0.000158315
# differential_evolution step 211: f(x)= 0.000158315
# differential_evolution step 212: f(x)= 0.000158315
# differential_evolution step 213: f(x)= 0.000158315
# differential_evolution step 214: f(x)= 0.000158315
# differential_evolution step 215: f(x)= 0.000158315
# differential_evolution step 216: f(x)= 0.000158315
# differential_evolution step 217: f(x)= 0.000158315
# differential_evolution step 218: f(x)= 0.000158315
# differential_evolution step 219: f(x)= 0.000158315
# differential_evolution step 220: f(x)= 0.000158315
# differential_evolution step 221: f(x)= 0.000158315
# differential_evolution step 222: f(x)= 0.000158315
# differential_evolution step 223: f(x)= 0.000158315
# differential_evolution step 224: f(x)= 0.000158315
# differential_evolution step 225: f(x)= 0.000158315
# differential_evolution step 226: f(x)= 0.000158315
# differential_evolution step 227: f(x)= 0.000158315
# differential_evolution step 228: f(x)= 0.000158315
# differential_evolution step 229: f(x)= 0.000158315
# differential_evolution step 230: f(x)= 0.000158315
# differential_evolution step 231: f(x)= 0.000158315
# differential_evolution step 232: f(x)= 0.000158315
# differential_evolution step 233: f(x)= 0.000158315
# differential_evolution step 234: f(x)= 0.000158315
# differential_evolution step 235: f(x)= 0.000158315
# differential_evolution step 236: f(x)= 0.000158315
# differential_evolution step 237: f(x)= 0.000158315
# differential_evolution step 238: f(x)= 0.000158315
# differential_evolution step 239: f(x)= 0.000158315
# differential_evolution step 240: f(x)= 0.000158315
# differential_evolution step 241: f(x)= 0.000158315
# differential_evolution step 242: f(x)= 0.000158315
# differential_evolution step 243: f(x)= 0.000158315
# differential_evolution step 244: f(x)= 0.000158315
# differential_evolution step 245: f(x)= 0.000158315
# differential_evolution step 246: f(x)= 0.000158315
# differential_evolution step 247: f(x)= 0.000158315
# differential_evolution step 248: f(x)= 0.000158315
# differential_evolution step 249: f(x)= 0.000158315
# differential_evolution step 250: f(x)= 0.000158315
# differential_evolution step 251: f(x)= 0.000158315
# differential_evolution step 252: f(x)= 0.000158315
# differential_evolution step 253: f(x)= 0.000158315
# differential_evolution step 254: f(x)= 0.000158315
# differential_evolution step 255: f(x)= 0.000158315
# differential_evolution step 256: f(x)= 0.000158315
# differential_evolution step 257: f(x)= 0.000158315
# differential_evolution step 258: f(x)= 0.000158315
# differential_evolution step 259: f(x)= 0.000158315
# differential_evolution step 260: f(x)= 0.000158315
# differential_evolution step 261: f(x)= 0.000158315
# differential_evolution step 262: f(x)= 0.000158315
# differential_evolution step 263: f(x)= 0.000158315
# differential_evolution step 264: f(x)= 0.000158315
# differential_evolution step 265: f(x)= 0.000158315
# differential_evolution step 266: f(x)= 0.000158315
# differential_evolution step 267: f(x)= 0.000158315
# differential_evolution step 268: f(x)= 0.000158315
# differential_evolution step 269: f(x)= 0.000158315
# differential_evolution step 270: f(x)= 0.000158315
# differential_evolution step 271: f(x)= 0.000158315
# differential_evolution step 272: f(x)= 0.000158315
# differential_evolution step 273: f(x)= 0.000105329
# differential_evolution step 274: f(x)= 0.000105329
# differential_evolution step 275: f(x)= 0.000105329
# differential_evolution step 276: f(x)= 0.000105329
# differential_evolution step 277: f(x)= 0.000105329
# differential_evolution step 278: f(x)= 0.000105329
# differential_evolution step 279: f(x)= 0.000105329
# differential_evolution step 280: f(x)= 0.000105329
# differential_evolution step 281: f(x)= 0.000105329
# differential_evolution step 282: f(x)= 0.000105329
# differential_evolution step 283: f(x)= 0.000105329
# differential_evolution step 284: f(x)= 0.000105329
# differential_evolution step 285: f(x)= 0.000105329
# differential_evolution step 286: f(x)= 0.000105329
# differential_evolution step 287: f(x)= 0.000105329
# differential_evolution step 288: f(x)= 0.000105329
# differential_evolution step 289: f(x)= 0.000105329
# differential_evolution step 290: f(x)= 0.000105329
# differential_evolution step 291: f(x)= 0.000105329
# differential_evolution step 292: f(x)= 0.000105329
# differential_evolution step 293: f(x)= 0.000105329
# differential_evolution step 294: f(x)= 0.000105329
# differential_evolution step 295: f(x)= 0.000105329
# differential_evolution step 296: f(x)= 0.000105329
# differential_evolution step 297: f(x)= 0.000105329
# differential_evolution step 298: f(x)= 0.000105329
# differential_evolution step 299: f(x)= 0.000105329
# differential_evolution step 300: f(x)= 0.000105329
# differential_evolution step 301: f(x)= 0.000105329
# differential_evolution step 302: f(x)= 0.000105329
# differential_evolution step 303: f(x)= 0.000105329
# differential_evolution step 304: f(x)= 0.000105329
# differential_evolution step 305: f(x)= 0.000105329
# differential_evolution step 306: f(x)= 0.000105329
# differential_evolution step 307: f(x)= 0.000105329
# differential_evolution step 308: f(x)= 0.000105329
# differential_evolution step 309: f(x)= 0.000105329
# differential_evolution step 310: f(x)= 0.000105329
# differential_evolution step 311: f(x)= 0.000105329
# differential_evolution step 312: f(x)= 0.000105329
# differential_evolution step 313: f(x)= 0.000105329
# differential_evolution step 314: f(x)= 0.000105329
# differential_evolution step 315: f(x)= 0.000105329
# differential_evolution step 316: f(x)= 0.000105329
# differential_evolution step 317: f(x)= 0.000105329
# differential_evolution step 318: f(x)= 0.000105329
# differential_evolution step 319: f(x)= 0.000105329
# differential_evolution step 320: f(x)= 0.000105329
# differential_evolution step 321: f(x)= 0.000105329
# differential_evolution step 322: f(x)= 0.000105329
# differential_evolution step 323: f(x)= 0.000105329
# differential_evolution step 324: f(x)= 0.000105329
# differential_evolution step 325: f(x)= 0.000105329
# differential_evolution step 326: f(x)= 0.000105329
# differential_evolution step 327: f(x)= 0.000105329
# differential_evolution step 328: f(x)= 0.000105329
# differential_evolution step 329: f(x)= 0.000105329
# differential_evolution step 330: f(x)= 0.000105329
# differential_evolution step 331: f(x)= 0.000105329
# differential_evolution step 332: f(x)= 0.000105329
# differential_evolution step 333: f(x)= 0.000105329
# differential_evolution step 334: f(x)= 0.000105329
# differential_evolution step 335: f(x)= 0.000105329
# differential_evolution step 336: f(x)= 0.000105329
# differential_evolution step 337: f(x)= 0.000105329
# differential_evolution step 338: f(x)= 0.000105329
# differential_evolution step 339: f(x)= 0.000105329
# differential_evolution step 340: f(x)= 0.000105329
# differential_evolution step 341: f(x)= 0.000105329
# differential_evolution step 342: f(x)= 0.000105329
# differential_evolution step 343: f(x)= 0.000105329
# differential_evolution step 344: f(x)= 0.000105329
# differential_evolution step 345: f(x)= 0.000105329
# differential_evolution step 346: f(x)= 0.000105329
# differential_evolution step 347: f(x)= 0.000105329
# differential_evolution step 348: f(x)= 0.000105329
# differential_evolution step 349: f(x)= 0.000105329
# differential_evolution step 350: f(x)= 0.000105329
# differential_evolution step 351: f(x)= 0.000105329
# differential_evolution step 352: f(x)= 0.000105329
# differential_evolution step 353: f(x)= 0.000105329
# differential_evolution step 354: f(x)= 0.000105329
# differential_evolution step 355: f(x)= 0.000105329
# differential_evolution step 356: f(x)= 0.000105329
# differential_evolution step 357: f(x)= 0.000105329
# differential_evolution step 358: f(x)= 0.000105329
# differential_evolution step 359: f(x)= 0.000105329
# differential_evolution step 360: f(x)= 0.000105329
# differential_evolution step 361: f(x)= 0.000105329
# differential_evolution step 362: f(x)= 0.000105329
# differential_evolution step 363: f(x)= 0.000105329
# differential_evolution step 364: f(x)= 0.000105329
# differential_evolution step 365: f(x)= 0.000105329
# differential_evolution step 366: f(x)= 0.000105329
# differential_evolution step 367: f(x)= 0.000105329
# differential_evolution step 368: f(x)= 0.000105329
# differential_evolution step 369: f(x)= 0.000105329
# differential_evolution step 370: f(x)= 0.000105329
# differential_evolution step 371: f(x)= 0.000105329
# differential_evolution step 372: f(x)= 0.000105329
# differential_evolution step 373: f(x)= 0.000105329
# differential_evolution step 374: f(x)= 0.000105329
# differential_evolution step 375: f(x)= 0.000105329
# differential_evolution step 376: f(x)= 0.000105329
# differential_evolution step 377: f(x)= 0.000105329
# differential_evolution step 378: f(x)= 0.000105329
# differential_evolution step 379: f(x)= 0.000105329
# differential_evolution step 380: f(x)= 0.000105329
# differential_evolution step 381: f(x)= 0.000105329
# differential_evolution step 382: f(x)= 0.000105329
# differential_evolution step 383: f(x)= 0.000105329
# differential_evolution step 384: f(x)= 0.000105329
# differential_evolution step 385: f(x)= 0.000105329
# differential_evolution step 386: f(x)= 0.000105329
# differential_evolution step 387: f(x)= 0.000105329
# differential_evolution step 388: f(x)= 0.000105329
# differential_evolution step 389: f(x)= 0.000105329
# differential_evolution step 390: f(x)= 0.000105329
# differential_evolution step 391: f(x)= 0.000105329
# differential_evolution step 392: f(x)= 0.000105329
# differential_evolution step 393: f(x)= 0.000105329
# differential_evolution step 394: f(x)= 0.000105329
# differential_evolution step 395: f(x)= 0.000105329
# differential_evolution step 396: f(x)= 0.000105329
# differential_evolution step 397: f(x)= 0.000105329
# differential_evolution step 398: f(x)= 0.000105329
# differential_evolution step 399: f(x)= 0.000105329
# differential_evolution step 400: f(x)= 0.000105329
# differential_evolution step 401: f(x)= 0.000105329
# differential_evolution step 402: f(x)= 0.000105329
# differential_evolution step 403: f(x)= 0.000105329
# differential_evolution step 404: f(x)= 0.000105329
# differential_evolution step 405: f(x)= 0.000105329
# differential_evolution step 406: f(x)= 0.000105329
# differential_evolution step 407: f(x)= 0.000105329
# differential_evolution step 408: f(x)= 0.000105329
# differential_evolution step 409: f(x)= 0.000105329
# differential_evolution step 410: f(x)= 0.000105329
# differential_evolution step 411: f(x)= 0.000105329
# differential_evolution step 412: f(x)= 0.000105329
# differential_evolution step 413: f(x)= 0.000105329
# differential_evolution step 414: f(x)= 0.000105329
# differential_evolution step 415: f(x)= 0.000105329
# differential_evolution step 416: f(x)= 0.000105329
# differential_evolution step 417: f(x)= 0.000105329
# differential_evolution step 418: f(x)= 0.000105329
# differential_evolution step 419: f(x)= 0.000105329
# differential_evolution step 420: f(x)= 0.000105329
# differential_evolution step 421: f(x)= 0.000105329
# differential_evolution step 422: f(x)= 0.000105329
# differential_evolution step 423: f(x)= 0.000105329
# differential_evolution step 424: f(x)= 0.000105329
# differential_evolution step 425: f(x)= 0.000105329
# differential_evolution step 426: f(x)= 0.000105329
# differential_evolution step 427: f(x)= 0.000105329
# differential_evolution step 428: f(x)= 0.000105329
# differential_evolution step 429: f(x)= 0.000105329
# differential_evolution step 430: f(x)= 0.000105329
# differential_evolution step 431: f(x)= 0.000105329
# differential_evolution step 432: f(x)= 0.000105329
# differential_evolution step 433: f(x)= 0.000105329
# differential_evolution step 434: f(x)= 0.000105329
# differential_evolution step 435: f(x)= 0.000105329
# differential_evolution step 436: f(x)= 0.000105329
# differential_evolution step 437: f(x)= 0.000105329
# differential_evolution step 438: f(x)= 0.000105329
# differential_evolution step 439: f(x)= 0.000105329
# differential_evolution step 440: f(x)= 0.000105329
# differential_evolution step 441: f(x)= 0.000105329
# differential_evolution step 442: f(x)= 0.000105329
# differential_evolution step 443: f(x)= 0.000105329
# differential_evolution step 444: f(x)= 0.000105329
# differential_evolution step 445: f(x)= 0.000105329
# differential_evolution step 446: f(x)= 0.000105329
# differential_evolution step 447: f(x)= 0.000105329
# differential_evolution step 448: f(x)= 0.000105329
# differential_evolution step 449: f(x)= 0.000105329
# differential_evolution step 450: f(x)= 0.000105329
# differential_evolution step 451: f(x)= 0.000105329
# differential_evolution step 452: f(x)= 0.000105329
# differential_evolution step 453: f(x)= 0.000105329
# differential_evolution step 454: f(x)= 0.000105329
# differential_evolution step 455: f(x)= 0.000105329
# differential_evolution step 456: f(x)= 0.000105329
# differential_evolution step 457: f(x)= 0.000105329
# differential_evolution step 458: f(x)= 0.000105329
# differential_evolution step 459: f(x)= 0.000105329
# differential_evolution step 460: f(x)= 0.000105329
# differential_evolution step 461: f(x)= 0.000105329
# differential_evolution step 462: f(x)= 0.000105329
# differential_evolution step 463: f(x)= 0.000105329
# differential_evolution step 464: f(x)= 0.000105329
# differential_evolution step 465: f(x)= 0.000105329
# differential_evolution step 466: f(x)= 0.000105329
# differential_evolution step 467: f(x)= 0.000105329
# differential_evolution step 468: f(x)= 0.000105329
# differential_evolution step 469: f(x)= 0.000105329
# differential_evolution step 470: f(x)= 0.000105329
# differential_evolution step 471: f(x)= 0.000105329
# differential_evolution step 472: f(x)= 0.000105329
# differential_evolution step 473: f(x)= 0.000105329
# differential_evolution step 474: f(x)= 0.000105329
# differential_evolution step 475: f(x)= 0.000105329
# differential_evolution step 476: f(x)= 0.000105329
# differential_evolution step 477: f(x)= 0.000105329
# differential_evolution step 478: f(x)= 0.000105329
# differential_evolution step 479: f(x)= 0.000105329
# differential_evolution step 480: f(x)= 0.000105329
# differential_evolution step 481: f(x)= 0.000105329
# differential_evolution step 482: f(x)= 0.000105329
# differential_evolution step 483: f(x)= 0.000105329
# differential_evolution step 484: f(x)= 0.000105329
# differential_evolution step 485: f(x)= 0.000105329
# differential_evolution step 486: f(x)= 0.000105329
# differential_evolution step 487: f(x)= 0.000105329
# differential_evolution step 488: f(x)= 0.000105329
# differential_evolution step 489: f(x)= 0.000105329
# differential_evolution step 490: f(x)= 0.000105329
# differential_evolution step 491: f(x)= 0.000105329
# differential_evolution step 492: f(x)= 0.000105329
# differential_evolution step 493: f(x)= 0.000105329
# differential_evolution step 494: f(x)= 0.000105329
# differential_evolution step 495: f(x)= 0.000105329
# differential_evolution step 496: f(x)= 0.000105329
# differential_evolution step 497: f(x)= 0.000105329
# differential_evolution step 498: f(x)= 0.000105329
# differential_evolution step 499: f(x)= 0.000105329
# differential_evolution step 500: f(x)= 0.000105329
# differential_evolution step 501: f(x)= 0.000105329
# differential_evolution step 502: f(x)= 0.000105329
# differential_evolution step 503: f(x)= 0.000105329
# differential_evolution step 504: f(x)= 0.000105329
# differential_evolution step 505: f(x)= 0.000105329
# differential_evolution step 506: f(x)= 0.000105329
# differential_evolution step 507: f(x)= 0.000105329
# differential_evolution step 508: f(x)= 0.000105329
# differential_evolution step 509: f(x)= 0.000105329
# differential_evolution step 510: f(x)= 0.000105329
# differential_evolution step 511: f(x)= 0.000105329
# differential_evolution step 512: f(x)= 0.000105329
# differential_evolution step 513: f(x)= 0.000105329
# differential_evolution step 514: f(x)= 0.000105329
# differential_evolution step 515: f(x)= 0.000105329
# differential_evolution step 516: f(x)= 0.000105329
# differential_evolution step 517: f(x)= 0.000105329
# differential_evolution step 518: f(x)= 0.000105329
# differential_evolution step 519: f(x)= 0.000105329
# differential_evolution step 520: f(x)= 0.000105329
# differential_evolution step 521: f(x)= 0.000105329
# differential_evolution step 522: f(x)= 0.000105329
# differential_evolution step 523: f(x)= 0.000105329
# differential_evolution step 524: f(x)= 0.000105329
# differential_evolution step 525: f(x)= 0.000105329
# differential_evolution step 526: f(x)= 0.000105329
# differential_evolution step 527: f(x)= 0.000105329
# differential_evolution step 528: f(x)= 0.000105329
# differential_evolution step 529: f(x)= 0.000105329
# differential_evolution step 530: f(x)= 0.000105329
# differential_evolution step 531: f(x)= 0.000105329
# differential_evolution step 532: f(x)= 0.000105329
# differential_evolution step 533: f(x)= 0.000105329
# differential_evolution step 534: f(x)= 0.000105329
# differential_evolution step 535: f(x)= 0.000105329
# differential_evolution step 536: f(x)= 0.000105329
# differential_evolution step 537: f(x)= 0.000105329
# differential_evolution step 538: f(x)= 0.000105329
# differential_evolution step 539: f(x)= 0.000105329
# differential_evolution step 540: f(x)= 0.000105329
# differential_evolution step 541: f(x)= 0.000105329
# differential_evolution step 542: f(x)= 0.000105329
# differential_evolution step 543: f(x)= 0.000105329
# differential_evolution step 544: f(x)= 0.000105329
# differential_evolution step 545: f(x)= 0.000105329
# differential_evolution step 546: f(x)= 0.000105329
# differential_evolution step 547: f(x)= 0.000105329
# differential_evolution step 548: f(x)= 0.000105329
# differential_evolution step 549: f(x)= 0.000105329
# differential_evolution step 550: f(x)= 0.000105329
# differential_evolution step 551: f(x)= 0.000105329
# differential_evolution step 552: f(x)= 0.000105329
# differential_evolution step 553: f(x)= 0.000105329
# differential_evolution step 554: f(x)= 0.000105329
# differential_evolution step 555: f(x)= 0.000105329
# differential_evolution step 556: f(x)= 0.000105329
# differential_evolution step 557: f(x)= 0.000105329
# differential_evolution step 558: f(x)= 0.000105329
# differential_evolution step 559: f(x)= 0.000105329
# differential_evolution step 560: f(x)= 0.000105329
# differential_evolution step 561: f(x)= 0.000105329
# differential_evolution step 562: f(x)= 0.000105329
# differential_evolution step 563: f(x)= 0.000105329
# differential_evolution step 564: f(x)= 0.000105329
# differential_evolution step 565: f(x)= 0.000105329
# differential_evolution step 566: f(x)= 0.000105329
# differential_evolution step 567: f(x)= 0.000105329
# differential_evolution step 568: f(x)= 0.000105329
# differential_evolution step 569: f(x)= 0.000105329
# differential_evolution step 570: f(x)= 0.000105329
# differential_evolution step 571: f(x)= 0.000105329
# differential_evolution step 572: f(x)= 0.000105329
# differential_evolution step 573: f(x)= 0.000105329
# differential_evolution step 574: f(x)= 0.000105329
# differential_evolution step 575: f(x)= 0.000105329
# differential_evolution step 576: f(x)= 0.000105329
# differential_evolution step 577: f(x)= 0.000105329
# differential_evolution step 578: f(x)= 0.000105329
# differential_evolution step 579: f(x)= 0.000105329
# differential_evolution step 580: f(x)= 0.000105329
# differential_evolution step 581: f(x)= 0.000105329
# differential_evolution step 582: f(x)= 0.000105329
# differential_evolution step 583: f(x)= 0.000105329
# differential_evolution step 584: f(x)= 0.000105329
# differential_evolution step 585: f(x)= 0.000105329
# differential_evolution step 586: f(x)= 0.000105329
# differential_evolution step 587: f(x)= 0.000105329
# differential_evolution step 588: f(x)= 0.000105329
# differential_evolution step 589: f(x)= 0.000105329
# differential_evolution step 590: f(x)= 0.000105329
# differential_evolution step 591: f(x)= 0.000105329
# differential_evolution step 592: f(x)= 0.000105329
# differential_evolution step 593: f(x)= 0.000105329
# differential_evolution step 594: f(x)= 0.000105329
# differential_evolution step 595: f(x)= 0.000105329
# differential_evolution step 596: f(x)= 0.000105329
# differential_evolution step 597: f(x)= 0.000105329
# differential_evolution step 598: f(x)= 0.000105329
# differential_evolution step 599: f(x)= 0.000105329
# differential_evolution step 600: f(x)= 0.000105329
# differential_evolution step 601: f(x)= 0.000105329
# differential_evolution step 602: f(x)= 0.000105329
# differential_evolution step 603: f(x)= 0.000105329
# differential_evolution step 604: f(x)= 0.000105329
# differential_evolution step 605: f(x)= 0.000105329
# differential_evolution step 606: f(x)= 0.000105329
# differential_evolution step 607: f(x)= 0.000105329
# differential_evolution step 608: f(x)= 0.000105329
# differential_evolution step 609: f(x)= 0.000105329
# differential_evolution step 610: f(x)= 0.000105329
# differential_evolution step 611: f(x)= 0.000105329
# differential_evolution step 612: f(x)= 0.000105329
# differential_evolution step 613: f(x)= 0.000105329
# differential_evolution step 614: f(x)= 0.000105329
# differential_evolution step 615: f(x)= 0.000105329
# differential_evolution step 616: f(x)= 0.000105329
# differential_evolution step 617: f(x)= 0.000105329
# differential_evolution step 618: f(x)= 0.000105329
# differential_evolution step 619: f(x)= 0.000105329
# differential_evolution step 620: f(x)= 0.000105329
# differential_evolution step 621: f(x)= 0.000105329
# differential_evolution step 622: f(x)= 0.000105329
# differential_evolution step 623: f(x)= 0.000105329
# differential_evolution step 624: f(x)= 0.000105329
# differential_evolution step 625: f(x)= 0.000105329
# differential_evolution step 626: f(x)= 0.000105329
# differential_evolution step 627: f(x)= 0.000105329
# differential_evolution step 628: f(x)= 0.000105329
# differential_evolution step 629: f(x)= 0.000105329
# differential_evolution step 630: f(x)= 0.000105329
# differential_evolution step 631: f(x)= 0.000105329
# differential_evolution step 632: f(x)= 0.000105329
# differential_evolution step 633: f(x)= 0.000105329
# differential_evolution step 634: f(x)= 0.000105329
# differential_evolution step 635: f(x)= 0.000105329
# differential_evolution step 636: f(x)= 0.000105329
# differential_evolution step 637: f(x)= 0.000105329
# differential_evolution step 638: f(x)= 0.000105329
# differential_evolution step 639: f(x)= 0.000105329
# differential_evolution step 640: f(x)= 0.000105329
# differential_evolution step 641: f(x)= 0.000105329
# differential_evolution step 642: f(x)= 0.000105329
# differential_evolution step 643: f(x)= 0.000105329
# differential_evolution step 644: f(x)= 0.000105329
# differential_evolution step 645: f(x)= 0.000105329
# differential_evolution step 646: f(x)= 0.000105329
# differential_evolution step 647: f(x)= 0.000105329
# differential_evolution step 648: f(x)= 0.000105329
# differential_evolution step 649: f(x)= 0.000105329
# differential_evolution step 650: f(x)= 0.000105329
# differential_evolution step 651: f(x)= 0.000105329
# differential_evolution step 652: f(x)= 9.68613e-05
# differential_evolution step 653: f(x)= 9.68613e-05
# differential_evolution step 654: f(x)= 9.68613e-05
# differential_evolution step 655: f(x)= 9.68613e-05
# differential_evolution step 656: f(x)= 9.68613e-05
# differential_evolution step 657: f(x)= 9.68613e-05
# differential_evolution step 658: f(x)= 9.68613e-05
# differential_evolution step 659: f(x)= 9.68613e-05
# differential_evolution step 660: f(x)= 9.68613e-05
# differential_evolution step 661: f(x)= 9.68613e-05
# differential_evolution step 662: f(x)= 9.68613e-05
# differential_evolution step 663: f(x)= 9.68613e-05
# differential_evolution step 664: f(x)= 9.68613e-05
# differential_evolution step 665: f(x)= 9.68613e-05
# differential_evolution step 666: f(x)= 9.68613e-05
# differential_evolution step 667: f(x)= 9.68613e-05
# differential_evolution step 668: f(x)= 9.68613e-05
# differential_evolution step 669: f(x)= 9.68613e-05
# differential_evolution step 670: f(x)= 9.68613e-05
# differential_evolution step 671: f(x)= 9.68613e-05
# differential_evolution step 672: f(x)= 9.68613e-05
# differential_evolution step 673: f(x)= 9.68613e-05
# differential_evolution step 674: f(x)= 9.68613e-05
# differential_evolution step 675: f(x)= 9.68613e-05
# differential_evolution step 676: f(x)= 9.68613e-05
# differential_evolution step 677: f(x)= 9.68613e-05
# differential_evolution step 678: f(x)= 9.68613e-05
# differential_evolution step 679: f(x)= 9.68613e-05
# differential_evolution step 680: f(x)= 9.68613e-05
# differential_evolution step 681: f(x)= 9.68613e-05
# differential_evolution step 682: f(x)= 9.68613e-05
# differential_evolution step 683: f(x)= 9.68613e-05
# differential_evolution step 684: f(x)= 9.68613e-05
# differential_evolution step 685: f(x)= 9.68613e-05
# differential_evolution step 686: f(x)= 9.68613e-05
# differential_evolution step 687: f(x)= 9.68613e-05
# differential_evolution step 688: f(x)= 9.68613e-05
# differential_evolution step 689: f(x)= 9.68613e-05
# differential_evolution step 690: f(x)= 9.68613e-05
# differential_evolution step 691: f(x)= 9.68613e-05
# differential_evolution step 692: f(x)= 9.68613e-05
# differential_evolution step 693: f(x)= 9.68613e-05
# differential_evolution step 694: f(x)= 9.68613e-05
# differential_evolution step 695: f(x)= 9.68613e-05
# differential_evolution step 696: f(x)= 9.68613e-05
# differential_evolution step 697: f(x)= 9.68613e-05
# differential_evolution step 698: f(x)= 9.68613e-05
# differential_evolution step 699: f(x)= 9.68613e-05
# differential_evolution step 700: f(x)= 9.68613e-05
# differential_evolution step 701: f(x)= 9.68613e-05
# differential_evolution step 702: f(x)= 9.68613e-05
# differential_evolution step 703: f(x)= 9.68613e-05
# differential_evolution step 704: f(x)= 9.68613e-05
# differential_evolution step 705: f(x)= 9.68613e-05
# differential_evolution step 706: f(x)= 9.68613e-05
# differential_evolution step 707: f(x)= 9.68613e-05
# differential_evolution step 708: f(x)= 9.68613e-05
# differential_evolution step 709: f(x)= 9.68613e-05
# differential_evolution step 710: f(x)= 9.68613e-05
# differential_evolution step 711: f(x)= 9.68613e-05
# differential_evolution step 712: f(x)= 9.68613e-05
# differential_evolution step 713: f(x)= 9.68613e-05
# differential_evolution step 714: f(x)= 9.68613e-05
# differential_evolution step 715: f(x)= 9.68613e-05
# differential_evolution step 716: f(x)= 9.68613e-05
# differential_evolution step 717: f(x)= 9.68613e-05
# differential_evolution step 718: f(x)= 9.68613e-05
# differential_evolution step 719: f(x)= 9.68613e-05
# differential_evolution step 720: f(x)= 9.68613e-05
# differential_evolution step 721: f(x)= 9.68613e-05
# differential_evolution step 722: f(x)= 9.68613e-05
# differential_evolution step 723: f(x)= 9.68613e-05
# differential_evolution step 724: f(x)= 9.68613e-05
# differential_evolution step 725: f(x)= 9.68613e-05
# differential_evolution step 726: f(x)= 9.68613e-05
# differential_evolution step 727: f(x)= 9.68613e-05
# differential_evolution step 728: f(x)= 9.68613e-05
# differential_evolution step 729: f(x)= 9.68613e-05
# differential_evolution step 730: f(x)= 9.68613e-05
# differential_evolution step 731: f(x)= 9.68613e-05
# differential_evolution step 732: f(x)= 9.68613e-05
# differential_evolution step 733: f(x)= 9.68613e-05
# differential_evolution step 734: f(x)= 9.68613e-05
# differential_evolution step 735: f(x)= 9.68613e-05
# differential_evolution step 736: f(x)= 9.68613e-05
# differential_evolution step 737: f(x)= 9.68613e-05
# differential_evolution step 738: f(x)= 9.68613e-05
# differential_evolution step 739: f(x)= 9.68613e-05
# differential_evolution step 740: f(x)= 9.68613e-05
# differential_evolution step 741: f(x)= 9.68613e-05
# differential_evolution step 742: f(x)= 9.68613e-05
# differential_evolution step 743: f(x)= 9.68613e-05
# differential_evolution step 744: f(x)= 9.68613e-05
# differential_evolution step 745: f(x)= 9.68613e-05
# differential_evolution step 746: f(x)= 9.68613e-05
# differential_evolution step 747: f(x)= 9.68613e-05
# differential_evolution step 748: f(x)= 9.68613e-05
# differential_evolution step 749: f(x)= 9.68613e-05
# differential_evolution step 750: f(x)= 9.68613e-05
# differential_evolution step 751: f(x)= 9.68613e-05
# differential_evolution step 752: f(x)= 9.68613e-05
# differential_evolution step 753: f(x)= 9.68613e-05
# differential_evolution step 754: f(x)= 9.68613e-05
# differential_evolution step 755: f(x)= 9.68613e-05
# differential_evolution step 756: f(x)= 9.68613e-05
# differential_evolution step 757: f(x)= 9.68613e-05
# differential_evolution step 758: f(x)= 9.68613e-05
# differential_evolution step 759: f(x)= 9.68613e-05
# differential_evolution step 760: f(x)= 9.68613e-05
# differential_evolution step 761: f(x)= 9.68613e-05
# differential_evolution step 762: f(x)= 9.68613e-05
# differential_evolution step 763: f(x)= 9.68613e-05
# differential_evolution step 764: f(x)= 9.68613e-05
# differential_evolution step 765: f(x)= 9.68613e-05
# differential_evolution step 766: f(x)= 9.68613e-05
# differential_evolution step 767: f(x)= 9.68613e-05
# differential_evolution step 768: f(x)= 9.68613e-05
# differential_evolution step 769: f(x)= 9.68613e-05
# differential_evolution step 770: f(x)= 9.68613e-05
# differential_evolution step 771: f(x)= 9.68613e-05
# differential_evolution step 772: f(x)= 9.68613e-05
# differential_evolution step 773: f(x)= 9.68613e-05
# differential_evolution step 774: f(x)= 9.68613e-05
# differential_evolution step 775: f(x)= 9.68613e-05
# differential_evolution step 776: f(x)= 9.68613e-05
# differential_evolution step 777: f(x)= 9.68613e-05
# differential_evolution step 778: f(x)= 9.68613e-05
# differential_evolution step 779: f(x)= 9.68613e-05
# differential_evolution step 780: f(x)= 9.68613e-05
# differential_evolution step 781: f(x)= 9.68613e-05
# differential_evolution step 782: f(x)= 9.68613e-05
# differential_evolution step 783: f(x)= 9.68613e-05
# differential_evolution step 784: f(x)= 9.68613e-05
# differential_evolution step 785: f(x)= 9.68613e-05
# differential_evolution step 786: f(x)= 9.68613e-05
# differential_evolution step 787: f(x)= 9.68613e-05
# differential_evolution step 788: f(x)= 9.68613e-05
# differential_evolution step 789: f(x)= 9.68613e-05
# differential_evolution step 790: f(x)= 9.68613e-05
# differential_evolution step 791: f(x)= 9.68613e-05
# differential_evolution step 792: f(x)= 9.68613e-05
# differential_evolution step 793: f(x)= 9.68613e-05
# differential_evolution step 794: f(x)= 9.68613e-05
# differential_evolution step 795: f(x)= 9.68613e-05
# differential_evolution step 796: f(x)= 9.68613e-05
# differential_evolution step 797: f(x)= 9.68613e-05
# differential_evolution step 798: f(x)= 9.68613e-05
# differential_evolution step 799: f(x)= 9.68613e-05
# differential_evolution step 800: f(x)= 9.68613e-05
# differential_evolution step 801: f(x)= 9.68613e-05
# differential_evolution step 802: f(x)= 9.68613e-05
# differential_evolution step 803: f(x)= 9.68613e-05
# differential_evolution step 804: f(x)= 9.68613e-05
# differential_evolution step 805: f(x)= 9.68613e-05
# differential_evolution step 806: f(x)= 9.68613e-05
# differential_evolution step 807: f(x)= 9.68613e-05
# differential_evolution step 808: f(x)= 9.68613e-05
# differential_evolution step 809: f(x)= 9.68613e-05
# differential_evolution step 810: f(x)= 9.68613e-05
# differential_evolution step 811: f(x)= 9.68613e-05
# differential_evolution step 812: f(x)= 9.68613e-05
# differential_evolution step 813: f(x)= 9.68613e-05
# differential_evolution step 814: f(x)= 9.68613e-05
# differential_evolution step 815: f(x)= 9.68613e-05
# differential_evolution step 816: f(x)= 9.68613e-05
# differential_evolution step 817: f(x)= 9.68613e-05
# differential_evolution step 818: f(x)= 9.68613e-05
# differential_evolution step 819: f(x)= 9.68613e-05
# differential_evolution step 820: f(x)= 9.68613e-05
# differential_evolution step 821: f(x)= 9.68613e-05
# differential_evolution step 822: f(x)= 9.68613e-05
# differential_evolution step 823: f(x)= 9.68613e-05
# differential_evolution step 824: f(x)= 9.68613e-05
# differential_evolution step 825: f(x)= 9.68613e-05
# differential_evolution step 826: f(x)= 9.68613e-05
# differential_evolution step 827: f(x)= 9.68613e-05
# differential_evolution step 828: f(x)= 9.68613e-05
# differential_evolution step 829: f(x)= 9.68613e-05
# differential_evolution step 830: f(x)= 9.68613e-05
# differential_evolution step 831: f(x)= 9.68613e-05
# differential_evolution step 832: f(x)= 9.68613e-05
# differential_evolution step 833: f(x)= 9.68613e-05
# differential_evolution step 834: f(x)= 9.68613e-05
# differential_evolution step 835: f(x)= 9.68613e-05
# differential_evolution step 836: f(x)= 9.68613e-05
# differential_evolution step 837: f(x)= 9.68613e-05
# differential_evolution step 838: f(x)= 9.68613e-05
# differential_evolution step 839: f(x)= 9.68613e-05
# differential_evolution step 840: f(x)= 9.68613e-05
# differential_evolution step 841: f(x)= 9.68613e-05
# differential_evolution step 842: f(x)= 9.68613e-05
# differential_evolution step 843: f(x)= 9.68613e-05
# differential_evolution step 844: f(x)= 9.68613e-05
# differential_evolution step 845: f(x)= 9.68613e-05
# differential_evolution step 846: f(x)= 9.68613e-05
# differential_evolution step 847: f(x)= 9.68613e-05
# differential_evolution step 848: f(x)= 9.68613e-05
# differential_evolution step 849: f(x)= 9.68613e-05
# differential_evolution step 850: f(x)= 9.68613e-05
# differential_evolution step 851: f(x)= 9.68613e-05
# differential_evolution step 852: f(x)= 9.68613e-05
# differential_evolution step 853: f(x)= 9.68613e-05
# differential_evolution step 854: f(x)= 9.44164e-05
# differential_evolution step 855: f(x)= 9.44164e-05
# differential_evolution step 856: f(x)= 9.44164e-05
# differential_evolution step 857: f(x)= 9.44164e-05
# differential_evolution step 858: f(x)= 9.44164e-05
# differential_evolution step 859: f(x)= 9.44164e-05
# differential_evolution step 860: f(x)= 9.44164e-05
# differential_evolution step 861: f(x)= 9.44164e-05
# differential_evolution step 862: f(x)= 9.44164e-05
# differential_evolution step 863: f(x)= 9.44164e-05
# differential_evolution step 864: f(x)= 9.44164e-05
# differential_evolution step 865: f(x)= 9.44164e-05
# differential_evolution step 866: f(x)= 9.44164e-05
# differential_evolution step 867: f(x)= 9.44164e-05
# differential_evolution step 868: f(x)= 9.44164e-05
# differential_evolution step 869: f(x)= 9.44164e-05
# differential_evolution step 870: f(x)= 9.44164e-05
# differential_evolution step 871: f(x)= 9.44164e-05
# differential_evolution step 872: f(x)= 9.44164e-05
# differential_evolution step 873: f(x)= 9.44164e-05
# differential_evolution step 874: f(x)= 9.44164e-05
# differential_evolution step 875: f(x)= 9.44164e-05
# differential_evolution step 876: f(x)= 9.44164e-05
# differential_evolution step 877: f(x)= 9.44164e-05
# differential_evolution step 878: f(x)= 9.44164e-05
# differential_evolution step 879: f(x)= 9.44164e-05
# differential_evolution step 880: f(x)= 9.44164e-05
# differential_evolution step 881: f(x)= 9.44164e-05
# differential_evolution step 882: f(x)= 9.44164e-05
# differential_evolution step 883: f(x)= 9.44164e-05
# differential_evolution step 884: f(x)= 9.44164e-05
# differential_evolution step 885: f(x)= 9.44164e-05
# differential_evolution step 886: f(x)= 9.44164e-05
# differential_evolution step 887: f(x)= 9.44164e-05
# differential_evolution step 888: f(x)= 9.44164e-05
# differential_evolution step 889: f(x)= 9.44164e-05
# differential_evolution step 890: f(x)= 9.44164e-05
# differential_evolution step 891: f(x)= 9.44164e-05
# differential_evolution step 892: f(x)= 9.44164e-05
# differential_evolution step 893: f(x)= 9.44164e-05
# differential_evolution step 894: f(x)= 9.44164e-05
# differential_evolution step 895: f(x)= 9.44164e-05
# differential_evolution step 896: f(x)= 9.44164e-05
# differential_evolution step 897: f(x)= 9.44164e-05
# differential_evolution step 898: f(x)= 9.44164e-05
# differential_evolution step 899: f(x)= 9.44164e-05
# differential_evolution step 900: f(x)= 9.44164e-05
# differential_evolution step 901: f(x)= 9.44164e-05
# differential_evolution step 902: f(x)= 9.44164e-05
# differential_evolution step 903: f(x)= 9.44164e-05
# differential_evolution step 904: f(x)= 9.44164e-05
# differential_evolution step 905: f(x)= 9.44164e-05
# differential_evolution step 906: f(x)= 9.44164e-05
# differential_evolution step 907: f(x)= 9.44164e-05
# differential_evolution step 908: f(x)= 9.44164e-05
# differential_evolution step 909: f(x)= 9.44164e-05
# differential_evolution step 910: f(x)= 9.44164e-05
# differential_evolution step 911: f(x)= 9.44164e-05
# differential_evolution step 912: f(x)= 9.44164e-05
# differential_evolution step 913: f(x)= 9.44164e-05
# differential_evolution step 914: f(x)= 9.44164e-05
# differential_evolution step 915: f(x)= 9.44164e-05
# differential_evolution step 916: f(x)= 9.44164e-05
# differential_evolution step 917: f(x)= 9.44164e-05
# differential_evolution step 918: f(x)= 9.44164e-05
# differential_evolution step 919: f(x)= 9.44164e-05
# differential_evolution step 920: f(x)= 9.44164e-05
# differential_evolution step 921: f(x)= 9.44164e-05
# differential_evolution step 922: f(x)= 9.44164e-05
# differential_evolution step 923: f(x)= 9.44164e-05
# differential_evolution step 924: f(x)= 9.44164e-05
# differential_evolution step 925: f(x)= 9.44164e-05
# differential_evolution step 926: f(x)= 9.44164e-05
# differential_evolution step 927: f(x)= 9.44164e-05
# differential_evolution step 928: f(x)= 9.44164e-05
# differential_evolution step 929: f(x)= 9.44164e-05
# differential_evolution step 930: f(x)= 9.44164e-05
# differential_evolution step 931: f(x)= 9.44164e-05
# differential_evolution step 932: f(x)= 9.44164e-05
# differential_evolution step 933: f(x)= 9.44164e-05
# differential_evolution step 934: f(x)= 9.44164e-05
# differential_evolution step 935: f(x)= 9.44164e-05
# differential_evolution step 936: f(x)= 9.44164e-05
# differential_evolution step 937: f(x)= 9.44164e-05
# differential_evolution step 938: f(x)= 9.44164e-05
# differential_evolution step 939: f(x)= 9.44164e-05
# differential_evolution step 940: f(x)= 9.44164e-05
# differential_evolution step 941: f(x)= 9.44164e-05
# differential_evolution step 942: f(x)= 9.44164e-05
# differential_evolution step 943: f(x)= 9.44164e-05
# ...
# differential_evolution step 902: f(x)= 9.06093e-05
# differential_evolution step 903: f(x)= 9.06093e-05
# differential_evolution step 904: f(x)= 9.06093e-05
# differential_evolution step 905: f(x)= 9.06093e-05
# differential_evolution step 906: f(x)= 9.06093e-05
# differential_evolution step 907: f(x)= 9.06093e-05
# differential_evolution step 908: f(x)= 9.06093e-05
# differential_evolution step 909: f(x)= 9.06093e-05
# differential_evolution step 910: f(x)= 9.06093e-05
# differential_evolution step 911: f(x)= 9.06093e-05
# differential_evolution step 912: f(x)= 9.06093e-05
# differential_evolution step 913: f(x)= 9.06093e-05
# differential_evolution step 914: f(x)= 9.06093e-05
# differential_evolution step 915: f(x)= 9.06093e-05
# differential_evolution step 916: f(x)= 9.06093e-05
# differential_evolution step 917: f(x)= 9.06093e-05
# differential_evolution step 918: f(x)= 9.06093e-05
# differential_evolution step 919: f(x)= 9.06093e-05
# differential_evolution step 920: f(x)= 9.06093e-05
# differential_evolution step 921: f(x)= 9.06093e-05
# differential_evolution step 922: f(x)= 9.06093e-05
# differential_evolution step 923: f(x)= 9.06093e-05
# differential_evolution step 924: f(x)= 9.06093e-05
# differential_evolution step 925: f(x)= 9.06093e-05
# differential_evolution step 926: f(x)= 9.06093e-05
# differential_evolution step 927: f(x)= 9.06093e-05
# differential_evolution step 928: f(x)= 9.06093e-05
# differential_evolution step 929: f(x)= 9.06093e-05
# differential_evolution step 930: f(x)= 9.06093e-05
# differential_evolution step 931: f(x)= 9.06093e-05
# differential_evolution step 932: f(x)= 9.06093e-05
# differential_evolution step 933: f(x)= 9.06093e-05
# differential_evolution step 934: f(x)= 9.06093e-05
# differential_evolution step 935: f(x)= 9.06093e-05
# differential_evolution step 936: f(x)= 9.06093e-05
# differential_evolution step 937: f(x)= 9.06093e-05
# differential_evolution step 938: f(x)= 9.06093e-05
# differential_evolution step 939: f(x)= 9.06093e-05
# differential_evolution step 940: f(x)= 9.06093e-05
# differential_evolution step 941: f(x)= 9.06093e-05
# differential_evolution step 942: f(x)= 9.06093e-05
# differential_evolution step 943: f(x)= 9.06093e-05
# differential_evolution step 944: f(x)= 9.06093e-05
# differential_evolution step 945: f(x)= 9.06093e-05
# differential_evolution step 946: f(x)= 9.06093e-05
# differential_evolution step 947: f(x)= 9.06093e-05
# differential_evolution step 948: f(x)= 9.06093e-05
# differential_evolution step 949: f(x)= 9.06093e-05
# differential_evolution step 950: f(x)= 9.06093e-05
# differential_evolution step 951: f(x)= 9.06093e-05
# differential_evolution step 952: f(x)= 9.06093e-05
# differential_evolution step 953: f(x)= 9.06093e-05
# differential_evolution step 954: f(x)= 9.06093e-05
# differential_evolution step 955: f(x)= 9.06093e-05
# differential_evolution step 956: f(x)= 9.06093e-05
# differential_evolution step 957: f(x)= 9.06093e-05
# differential_evolution step 958: f(x)= 9.06093e-05
# differential_evolution step 959: f(x)= 9.06093e-05
# differential_evolution step 960: f(x)= 9.06093e-05
# differential_evolution step 961: f(x)= 9.06093e-05
# differential_evolution step 962: f(x)= 9.06093e-05
# differential_evolution step 963: f(x)= 9.06093e-05
# differential_evolution step 964: f(x)= 9.06093e-05
# differential_evolution step 965: f(x)= 9.06093e-05
# differential_evolution step 966: f(x)= 9.06093e-05
# differential_evolution step 967: f(x)= 9.06093e-05
# differential_evolution step 968: f(x)= 9.06093e-05
# differential_evolution step 969: f(x)= 9.06093e-05
# differential_evolution step 970: f(x)= 9.06093e-05
# differential_evolution step 971: f(x)= 9.06093e-05
# differential_evolution step 972: f(x)= 9.06093e-05
# differential_evolution step 973: f(x)= 9.06093e-05
# differential_evolution step 974: f(x)= 9.06093e-05
# differential_evolution step 975: f(x)= 9.06093e-05
# differential_evolution step 976: f(x)= 9.06093e-05
# differential_evolution step 977: f(x)= 9.06093e-05
# differential_evolution step 978: f(x)= 9.06093e-05
# differential_evolution step 979: f(x)= 9.06093e-05
# differential_evolution step 980: f(x)= 9.06093e-05
# differential_evolution step 981: f(x)= 9.06093e-05
# differential_evolution step 982: f(x)= 9.06093e-05
# differential_evolution step 983: f(x)= 9.06093e-05
# differential_evolution step 984: f(x)= 9.06093e-05
# differential_evolution step 985: f(x)= 9.06093e-05
# differential_evolution step 986: f(x)= 9.06093e-05
# differential_evolution step 987: f(x)= 9.06093e-05
# differential_evolution step 988: f(x)= 9.06093e-05
# differential_evolution step 989: f(x)= 9.06093e-05
# differential_evolution step 990: f(x)= 9.06093e-05
# differential_evolution step 991: f(x)= 9.06093e-05
# differential_evolution step 992: f(x)= 9.06093e-05
# differential_evolution step 993: f(x)= 9.06093e-05
# differential_evolution step 994: f(x)= 9.06093e-05
# differential_evolution step 995: f(x)= 9.06093e-05
# differential_evolution step 996: f(x)= 9.06093e-05
# differential_evolution step 997: f(x)= 9.06093e-05
# differential_evolution step 998: f(x)= 9.06093e-05
# differential_evolution step 999: f(x)= 9.06093e-05
# differential_evolution step 1000: f(x)= 9.06093e-05
# differential_evolution step 1001: f(x)= 9.06093e-05
# differential_evolution step 1002: f(x)= 9.06093e-05
# differential_evolution step 1003: f(x)= 9.06093e-05
# differential_evolution step 1004: f(x)= 9.06093e-05
# differential_evolution step 1005: f(x)= 9.06093e-05
# differential_evolution step 1006: f(x)= 9.06093e-05
# differential_evolution step 1007: f(x)= 9.06093e-05
# differential_evolution step 1008: f(x)= 9.06093e-05
# differential_evolution step 1009: f(x)= 9.06093e-05
# differential_evolution step 1010: f(x)= 9.06093e-05
# differential_evolution step 1011: f(x)= 9.06093e-05
# differential_evolution step 1012: f(x)= 9.06093e-05
# differential_evolution step 1013: f(x)= 9.06093e-05
# differential_evolution step 1014: f(x)= 9.06093e-05
# differential_evolution step 1015: f(x)= 9.06093e-05
# differential_evolution step 1016: f(x)= 9.06093e-05
# differential_evolution step 1017: f(x)= 9.06093e-05
# differential_evolution step 1018: f(x)= 9.06093e-05
# differential_evolution step 1019: f(x)= 9.06093e-05
# differential_evolution step 1020: f(x)= 9.06093e-05
# differential_evolution step 1021: f(x)= 9.06093e-05
# differential_evolution step 1022: f(x)= 9.06093e-05
# differential_evolution step 1023: f(x)= 9.06093e-05
# differential_evolution step 1024: f(x)= 9.06093e-05
# differential_evolution step 1025: f(x)= 9.06093e-05
# differential_evolution step 1026: f(x)= 9.06093e-05
# differential_evolution step 1027: f(x)= 9.06093e-05
# differential_evolution step 1028: f(x)= 9.06093e-05
# differential_evolution step 1029: f(x)= 9.06093e-05
# differential_evolution step 1030: f(x)= 9.06093e-05
# differential_evolution step 1031: f(x)= 9.06093e-05
# differential_evolution step 1032: f(x)= 9.06093e-05
# differential_evolution step 1033: f(x)= 9.06093e-05
# differential_evolution step 1034: f(x)= 9.06093e-05
# differential_evolution step 1035: f(x)= 9.06093e-05
# differential_evolution step 1036: f(x)= 9.06093e-05
# differential_evolution step 1037: f(x)= 9.06093e-05
# differential_evolution step 1038: f(x)= 9.06093e-05
# differential_evolution step 1039: f(x)= 9.06093e-05
# differential_evolution step 1040: f(x)= 9.06093e-05
# differential_evolution step 1041: f(x)= 9.06093e-05
# differential_evolution step 1042: f(x)= 9.06093e-05
# differential_evolution step 1043: f(x)= 9.06093e-05
# differential_evolution step 1044: f(x)= 9.06093e-05
# differential_evolution step 1045: f(x)= 9.06093e-05
# differential_evolution step 1046: f(x)= 9.06093e-05
# differential_evolution step 1047: f(x)= 9.06093e-05
# differential_evolution step 1048: f(x)= 9.06093e-05
# differential_evolution step 1049: f(x)= 9.06093e-05
# differential_evolution step 1050: f(x)= 9.06093e-05
# differential_evolution step 1051: f(x)= 9.06093e-05
# differential_evolution step 1052: f(x)= 9.06093e-05
# differential_evolution step 1053: f(x)= 9.06093e-05
# differential_evolution step 1054: f(x)= 9.06093e-05
# differential_evolution step 1055: f(x)= 9.06093e-05
# differential_evolution step 1056: f(x)= 9.06093e-05
# differential_evolution step 1057: f(x)= 9.06093e-05
# differential_evolution step 1058: f(x)= 9.06093e-05
# differential_evolution step 1059: f(x)= 9.06093e-05
# differential_evolution step 1060: f(x)= 9.06093e-05
# differential_evolution step 1061: f(x)= 9.06093e-05
# differential_evolution step 1062: f(x)= 9.06093e-05
# differential_evolution step 1063: f(x)= 9.06093e-05
# differential_evolution step 1064: f(x)= 9.06093e-05
# differential_evolution step 1065: f(x)= 9.06093e-05
# differential_evolution step 1066: f(x)= 9.06093e-05
# differential_evolution step 1067: f(x)= 9.06093e-05
# differential_evolution step 1068: f(x)= 9.06093e-05
# differential_evolution step 1069: f(x)= 9.06093e-05
# differential_evolution step 1070: f(x)= 9.06093e-05
# differential_evolution step 1071: f(x)= 9.06093e-05
# differential_evolution step 1072: f(x)= 9.06093e-05
# differential_evolution step 1073: f(x)= 9.06093e-05
# differential_evolution step 1074: f(x)= 9.06093e-05
# differential_evolution step 1075: f(x)= 9.06093e-05
# differential_evolution step 1076: f(x)= 9.06093e-05
# differential_evolution step 1077: f(x)= 9.06093e-05
# differential_evolution step 1078: f(x)= 9.06093e-05
# differential_evolution step 1079: f(x)= 9.06093e-05
# differential_evolution step 1080: f(x)= 9.06093e-05
# differential_evolution step 1081: f(x)= 9.06093e-05
# differential_evolution step 1082: f(x)= 9.06093e-05
# differential_evolution step 1083: f(x)= 9.06093e-05
# differential_evolution step 1084: f(x)= 9.06093e-05
# differential_evolution step 1085: f(x)= 9.06093e-05
# differential_evolution step 1086: f(x)= 9.06093e-05
# differential_evolution step 1087: f(x)= 9.06093e-05
# differential_evolution step 1088: f(x)= 9.06093e-05
# differential_evolution step 1089: f(x)= 9.06093e-05
# differential_evolution step 1090: f(x)= 9.06093e-05
# differential_evolution step 1091: f(x)= 9.06093e-05
# differential_evolution step 1092: f(x)= 9.06093e-05
# differential_evolution step 1093: f(x)= 9.06093e-05
# differential_evolution step 1094: f(x)= 9.06093e-05
# differential_evolution step 1095: f(x)= 9.06093e-05
# differential_evolution step 1096: f(x)= 9.06093e-05
# differential_evolution step 1097: f(x)= 9.06093e-05
# differential_evolution step 1098: f(x)= 9.06093e-05
# differential_evolution step 1099: f(x)= 9.06093e-05
# differential_evolution step 1100: f(x)= 9.06093e-05
# differential_evolution step 1101: f(x)= 9.06093e-05
# differential_evolution step 1102: f(x)= 9.06093e-05
# differential_evolution step 1103: f(x)= 9.06093e-05
# differential_evolution step 1104: f(x)= 9.06093e-05
# differential_evolution step 1105: f(x)= 9.06093e-05
# differential_evolution step 1106: f(x)= 9.06093e-05
# differential_evolution step 1107: f(x)= 9.06093e-05
# differential_evolution step 1108: f(x)= 9.06093e-05
# differential_evolution step 1109: f(x)= 9.06093e-05
# differential_evolution step 1110: f(x)= 9.06093e-05
# differential_evolution step 1111: f(x)= 9.06093e-05
# differential_evolution step 1112: f(x)= 9.06093e-05
# differential_evolution step 1113: f(x)= 9.06093e-05
# differential_evolution step 1114: f(x)= 9.06093e-05
# differential_evolution step 1115: f(x)= 9.06093e-05
# differential_evolution step 1116: f(x)= 9.06093e-05
# differential_evolution step 1117: f(x)= 9.06093e-05
# differential_evolution step 1118: f(x)= 9.06093e-05
# differential_evolution step 1119: f(x)= 9.06093e-05
# differential_evolution step 1120: f(x)= 9.06093e-05
# differential_evolution step 1121: f(x)= 9.06093e-05
# differential_evolution step 1122: f(x)= 9.06093e-05
# differential_evolution step 1123: f(x)= 9.06093e-05
# differential_evolution step 1124: f(x)= 9.06093e-05
# differential_evolution step 1125: f(x)= 9.06093e-05
# differential_evolution step 1126: f(x)= 9.06093e-05
# differential_evolution step 1127: f(x)= 9.06093e-05
# differential_evolution step 1128: f(x)= 9.06093e-05
# differential_evolution step 1129: f(x)= 9.06093e-05
# differential_evolution step 1130: f(x)= 9.06093e-05
# differential_evolution step 1131: f(x)= 9.06093e-05
# differential_evolution step 1132: f(x)= 9.06093e-05
# differential_evolution step 1133: f(x)= 9.06093e-05
# differential_evolution step 1134: f(x)= 9.06093e-05
# differential_evolution step 1135: f(x)= 9.06093e-05
# differential_evolution step 1136: f(x)= 9.06093e-05
# differential_evolution step 1137: f(x)= 9.06093e-05
# differential_evolution step 1138: f(x)= 9.06093e-05
# differential_evolution step 1139: f(x)= 9.06093e-05
# differential_evolution step 1140: f(x)= 9.06093e-05
# differential_evolution step 1141: f(x)= 9.06093e-05
# differential_evolution step 1142: f(x)= 9.06093e-05
# differential_evolution step 1143: f(x)= 9.06093e-05
# differential_evolution step 1144: f(x)= 9.06093e-05
# differential_evolution step 1145: f(x)= 9.06093e-05
# differential_evolution step 1146: f(x)= 9.06093e-05
# differential_evolution step 1147: f(x)= 9.06093e-05
# differential_evolution step 1148: f(x)= 9.06093e-05
# differential_evolution step 1149: f(x)= 9.06093e-05
# differential_evolution step 1150: f(x)= 9.06093e-05
# differential_evolution step 1151: f(x)= 9.06093e-05
# differential_evolution step 1152: f(x)= 9.06093e-05
# differential_evolution step 1153: f(x)= 9.06093e-05
# differential_evolution step 1154: f(x)= 9.06093e-05
# differential_evolution step 1155: f(x)= 9.06093e-05
# differential_evolution step 1156: f(x)= 9.06093e-05
# differential_evolution step 1157: f(x)= 9.06093e-05
# differential_evolution step 1158: f(x)= 9.06093e-05
# differential_evolution step 1159: f(x)= 9.06093e-05
# differential_evolution step 1160: f(x)= 9.06093e-05
# differential_evolution step 1161: f(x)= 9.06093e-05
# differential_evolution step 1162: f(x)= 9.06093e-05
# differential_evolution step 1163: f(x)= 9.06093e-05
# differential_evolution step 1164: f(x)= 9.06093e-05
# differential_evolution step 1165: f(x)= 9.06093e-05
# differential_evolution step 1166: f(x)= 9.06093e-05
# differential_evolution step 1167: f(x)= 9.06093e-05
# differential_evolution step 1168: f(x)= 9.06093e-05
# differential_evolution step 1169: f(x)= 9.06093e-05
# differential_evolution step 1170: f(x)= 9.06093e-05
# differential_evolution step 1171: f(x)= 9.06093e-05
# differential_evolution step 1172: f(x)= 9.06093e-05
# differential_evolution step 1173: f(x)= 9.06093e-05
# differential_evolution step 1174: f(x)= 9.06093e-05
# differential_evolution step 1175: f(x)= 9.06093e-05
# differential_evolution step 1176: f(x)= 9.06093e-05
# differential_evolution step 1177: f(x)= 9.06093e-05
# differential_evolution step 1178: f(x)= 9.06093e-05
# differential_evolution step 1179: f(x)= 9.06093e-05
# differential_evolution step 1180: f(x)= 9.06093e-05
# differential_evolution step 1181: f(x)= 9.06093e-05
# differential_evolution step 1182: f(x)= 9.06093e-05
# differential_evolution step 1183: f(x)= 9.06093e-05
# differential_evolution step 1184: f(x)= 9.06093e-05
# differential_evolution step 1185: f(x)= 9.06093e-05
# differential_evolution step 1186: f(x)= 9.06093e-05
# differential_evolution step 1187: f(x)= 9.06093e-05
# differential_evolution step 1188: f(x)= 9.06093e-05
# differential_evolution step 1189: f(x)= 9.06093e-05
# differential_evolution step 1190: f(x)= 9.06093e-05
# differential_evolution step 1191: f(x)= 9.06093e-05
# differential_evolution step 1192: f(x)= 9.06093e-05
# differential_evolution step 1193: f(x)= 9.06093e-05
# differential_evolution step 1194: f(x)= 9.06093e-05
# differential_evolution step 1195: f(x)= 9.06093e-05
# differential_evolution step 1196: f(x)= 9.06093e-05
# differential_evolution step 1197: f(x)= 9.06093e-05
# differential_evolution step 1198: f(x)= 9.06093e-05
# differential_evolution step 1199: f(x)= 9.06093e-05
# differential_evolution step 1200: f(x)= 9.06093e-05
#  ->  360344  ->  False  ->  2.401103484903836e-07
#      fun: 2.401103484903836e-07
#      jac: array([-1.17050278e-06, -3.57044993e-06, -1.61131172e-06,  1.49454836e-06,
#        -1.61712106e-06,  1.43131062e-06,  1.83476287e-06, -2.14823207e-06,
#         2.43674640e-06, -5.07268221e-06])
#  message: 'Maximum number of iterations has been exceeded.'
#     nfev: 360344
#      nit: 1200
#  success: False
#        x: array([-3.15014685,  3.11468256,  3.12934392, -3.13021728,  3.12930046,
#         3.15209741, -3.12767248,  3.12532741, -3.12316873,  3.10342547])

# %% [markdown]
# **Strategy rand1bin ---- CR = 1 & F = 0.7**

# %%
CR = 1
F = 0.7

for i in range(5):
  result = differential_evolution(xinSheYangN4, bounds, init = "random", mutation = F, recombination = CR, popsize=30, maxiter = 1200, strategy = "rand1bin", disp=True)
  print( " -> " , result.nfev, " -> " , result.success, " -> " , result.fun)
  # summarize the result
  print(result)
# Out:
# differential_evolution step 1: f(x)= 0.000841973
# differential_evolution step 2: f(x)= 0.000841973
# differential_evolution step 3: f(x)= 0.000623069
# differential_evolution step 4: f(x)= 0.000407999
# differential_evolution step 5: f(x)= 0.000407999
# differential_evolution step 6: f(x)= 0.000407999
# differential_evolution step 7: f(x)= 0.000407999
# differential_evolution step 8: f(x)= 0.000407999
# differential_evolution step 9: f(x)= 0.000407999
# differential_evolution step 10: f(x)= 0.000407999
# differential_evolution step 11: f(x)= 0.000407999
# differential_evolution step 12: f(x)= 0.000407999
# differential_evolution step 13: f(x)= 0.000407999
# differential_evolution step 14: f(x)= 0.000407999
# differential_evolution step 15: f(x)= 0.000407999
# differential_evolution step 16: f(x)= 0.000407999
# differential_evolution step 17: f(x)= 0.000407999
# differential_evolution step 18: f(x)= 0.000407999
# differential_evolution step 19: f(x)= 0.000407999
# differential_evolution step 20: f(x)= 0.000407999
# differential_evolution step 21: f(x)= 0.000407999
# differential_evolution step 22: f(x)= 0.00040462
# differential_evolution step 23: f(x)= 0.00040462
# differential_evolution step 24: f(x)= 0.00040462
# differential_evolution step 25: f(x)= 0.000267533
# differential_evolution step 26: f(x)= 0.000267533
# differential_evolution step 27: f(x)= 0.000267533
# differential_evolution step 28: f(x)= 0.000267533
# differential_evolution step 29: f(x)= 0.000267533
# differential_evolution step 30: f(x)= 0.000267533
# differential_evolution step 31: f(x)= 0.000267533
# differential_evolution step 32: f(x)= 0.000267533
# differential_evolution step 33: f(x)= 0.000267533
# differential_evolution step 34: f(x)= 0.000267533
# differential_evolution step 35: f(x)= 0.000267533
# differential_evolution step 36: f(x)= 0.000267533
# differential_evolution step 37: f(x)= 0.000267533
# differential_evolution step 38: f(x)= 0.000267533
# differential_evolution step 39: f(x)= 0.000267533
# differential_evolution step 40: f(x)= 0.000267533
# differential_evolution step 41: f(x)= 0.000267533
# differential_evolution step 42: f(x)= 0.000267533
# differential_evolution step 43: f(x)= 0.000267533
# differential_evolution step 44: f(x)= 0.000267533
# differential_evolution step 45: f(x)= 0.000267533
# differential_evolution step 46: f(x)= 0.000267533
# differential_evolution step 47: f(x)= 0.000267533
# differential_evolution step 48: f(x)= 0.000267533
# differential_evolution step 49: f(x)= 0.000267533
# differential_evolution step 50: f(x)= 0.000267533
# differential_evolution step 51: f(x)= 0.000267533
# differential_evolution step 52: f(x)= 0.000267533
# differential_evolution step 53: f(x)= 0.000267533
# differential_evolution step 54: f(x)= 0.000267533
# differential_evolution step 55: f(x)= 0.000267533
# differential_evolution step 56: f(x)= 0.000267533
# differential_evolution step 57: f(x)= 0.000267533
# differential_evolution step 58: f(x)= 0.000267533
# differential_evolution step 59: f(x)= 0.000267533
# differential_evolution step 60: f(x)= 0.000267533
# differential_evolution step 61: f(x)= 0.000267533
# differential_evolution step 62: f(x)= 0.000267533
# differential_evolution step 63: f(x)= 0.000267533
# differential_evolution step 64: f(x)= 0.000267533
# differential_evolution step 65: f(x)= 0.000267533
# differential_evolution step 66: f(x)= 0.000267533
# differential_evolution step 67: f(x)= 0.000267533
# differential_evolution step 68: f(x)= 0.000267533
# differential_evolution step 69: f(x)= 0.000267533
# differential_evolution step 70: f(x)= 0.000267533
# differential_evolution step 71: f(x)= 0.000267533
# differential_evolution step 72: f(x)= 0.000267533
# differential_evolution step 73: f(x)= 0.000267533
# differential_evolution step 74: f(x)= 0.000267533
# differential_evolution step 75: f(x)= 0.000267533
# differential_evolution step 76: f(x)= 0.000267533
# differential_evolution step 77: f(x)= 0.000267533
# differential_evolution step 78: f(x)= 0.000267533
# differential_evolution step 79: f(x)= 0.000267533
# differential_evolution step 80: f(x)= 0.000267533
# differential_evolution step 81: f(x)= 0.000267533
# differential_evolution step 82: f(x)= 0.000267533
# differential_evolution step 83: f(x)= 0.000267533
# differential_evolution step 84: f(x)= 0.000267533
# differential_evolution step 85: f(x)= 0.000267533
# differential_evolution step 86: f(x)= 0.000267533
# differential_evolution step 87: f(x)= 0.000267533
# differential_evolution step 88: f(x)= 0.000267533
# differential_evolution step 89: f(x)= 0.000267533
# differential_evolution step 90: f(x)= 0.000267533
# differential_evolution step 91: f(x)= 0.000267533
# differential_evolution step 92: f(x)= 0.000267533
# differential_evolution step 93: f(x)= 0.000267533
# differential_evolution step 94: f(x)= 0.000267533
# differential_evolution step 95: f(x)= 0.000267533
# differential_evolution step 96: f(x)= 0.000267533
# differential_evolution step 97: f(x)= 0.000267533
# differential_evolution step 98: f(x)= 0.000267533
# differential_evolution step 99: f(x)= 0.000267533
# differential_evolution step 100: f(x)= 0.000267533
# differential_evolution step 101: f(x)= 0.000267533
# differential_evolution step 102: f(x)= 0.000267533
# differential_evolution step 103: f(x)= 0.000267533
# differential_evolution step 104: f(x)= 0.000267533
# differential_evolution step 105: f(x)= 0.000267533
# differential_evolution step 106: f(x)= 0.000267533
# differential_evolution step 107: f(x)= 0.000267533
# differential_evolution step 108: f(x)= 0.000267533
# differential_evolution step 109: f(x)= 0.000267533
# differential_evolution step 110: f(x)= 0.000267533
# differential_evolution step 111: f(x)= 0.000267533
# differential_evolution step 112: f(x)= 0.000267533
# differential_evolution step 113: f(x)= 0.000267533
# differential_evolution step 114: f(x)= 0.000267533
# differential_evolution step 115: f(x)= 0.000267533
# differential_evolution step 116: f(x)= 0.000267533
# differential_evolution step 117: f(x)= 0.000267533
# differential_evolution step 118: f(x)= 0.000267533
# differential_evolution step 119: f(x)= 0.000267533
# differential_evolution step 120: f(x)= 0.000267533
# differential_evolution step 121: f(x)= 0.000267533
# differential_evolution step 122: f(x)= 0.000267533
# differential_evolution step 123: f(x)= 0.000267533
# differential_evolution step 124: f(x)= 0.000267533
# differential_evolution step 125: f(x)= 0.000267533
# differential_evolution step 126: f(x)= 0.000267533
# differential_evolution step 127: f(x)= 0.000267533
# differential_evolution step 128: f(x)= 0.000267533
# differential_evolution step 129: f(x)= 0.000267533
# differential_evolution step 130: f(x)= 0.000267533
# differential_evolution step 131: f(x)= 0.000267533
# differential_evolution step 132: f(x)= 0.000267533
# differential_evolution step 133: f(x)= 0.000267533
# differential_evolution step 134: f(x)= 0.000267533
# differential_evolution step 135: f(x)= 0.000267533
# differential_evolution step 136: f(x)= 0.000267533
# differential_evolution step 137: f(x)= 0.000267533
# differential_evolution step 138: f(x)= 0.000267533
# differential_evolution step 139: f(x)= 0.000267533
# differential_evolution step 140: f(x)= 0.000267533
# differential_evolution step 141: f(x)= 0.000267533
# differential_evolution step 142: f(x)= 0.000267533
# differential_evolution step 143: f(x)= 0.000267533
# differential_evolution step 144: f(x)= 0.000267533
# differential_evolution step 145: f(x)= 0.000267533
# differential_evolution step 146: f(x)= 0.000267533
# differential_evolution step 147: f(x)= 0.000267533
# differential_evolution step 148: f(x)= 0.000267533
# differential_evolution step 149: f(x)= 0.000267533
# differential_evolution step 150: f(x)= 0.000267533
# differential_evolution step 151: f(x)= 0.000267533
# differential_evolution step 152: f(x)= 0.000267533
# differential_evolution step 153: f(x)= 0.000267533
# differential_evolution step 154: f(x)= 0.000267533
# differential_evolution step 155: f(x)= 0.000267533
# differential_evolution step 156: f(x)= 0.000267533
# differential_evolution step 157: f(x)= 0.000255381
# differential_evolution step 158: f(x)= 0.000255381
# differential_evolution step 159: f(x)= 0.000255381
# differential_evolution step 160: f(x)= 0.000255381
# differential_evolution step 161: f(x)= 0.000255381
# differential_evolution step 162: f(x)= 0.000255381
# differential_evolution step 163: f(x)= 0.000255381
# differential_evolution step 164: f(x)= 0.000255381
# differential_evolution step 165: f(x)= 0.000255381
# differential_evolution step 166: f(x)= 0.000255381
# differential_evolution step 167: f(x)= 0.000255381
# differential_evolution step 168: f(x)= 0.000255381
# differential_evolution step 169: f(x)= 0.000255381
# differential_evolution step 170: f(x)= 0.000255381
# differential_evolution step 171: f(x)= 0.000255381
# differential_evolution step 172: f(x)= 0.000255381
# differential_evolution step 173: f(x)= 0.000255381
# differential_evolution step 174: f(x)= 0.000255381
# differential_evolution step 175: f(x)= 0.000255381
# differential_evolution step 176: f(x)= 0.000255381
# differential_evolution step 177: f(x)= 0.000255381
# differential_evolution step 178: f(x)= 0.000255381
# differential_evolution step 179: f(x)= 0.000255381
# differential_evolution step 180: f(x)= 0.00023104
# differential_evolution step 181: f(x)= 0.00023104
# differential_evolution step 182: f(x)= 0.00023104
# differential_evolution step 183: f(x)= 0.00023104
# differential_evolution step 184: f(x)= 0.00023104
# differential_evolution step 185: f(x)= 0.00023104
# differential_evolution step 186: f(x)= 0.00023104
# differential_evolution step 187: f(x)= 0.00023104
# differential_evolution step 188: f(x)= 0.00023104
# differential_evolution step 189: f(x)= 0.00023104
# differential_evolution step 190: f(x)= 0.00023104
# differential_evolution step 191: f(x)= 0.00023104
# differential_evolution step 192: f(x)= 0.00023104
# differential_evolution step 193: f(x)= 0.00023104
# differential_evolution step 194: f(x)= 0.00023104
# differential_evolution step 195: f(x)= 0.00023104
# differential_evolution step 196: f(x)= 0.00023104
# differential_evolution step 197: f(x)= 0.00023104
# differential_evolution step 198: f(x)= 0.00023104
# differential_evolution step 199: f(x)= 0.00023104
# differential_evolution step 200: f(x)= 0.00023104
# differential_evolution step 201: f(x)= 0.00023104
# differential_evolution step 202: f(x)= 0.00023104
# differential_evolution step 203: f(x)= 0.00023104
# differential_evolution step 204: f(x)= 0.00023104
# differential_evolution step 205: f(x)= 0.00023104
# differential_evolution step 206: f(x)= 0.00023104
# differential_evolution step 207: f(x)= 0.00023104
# differential_evolution step 208: f(x)= 0.00023104
# differential_evolution step 209: f(x)= 0.00023104
# differential_evolution step 210: f(x)= 0.00023104
# differential_evolution step 211: f(x)= 0.00023104
# differential_evolution step 212: f(x)= 0.00023104
# differential_evolution step 213: f(x)= 0.00023104
# differential_evolution step 214: f(x)= 0.00023104
# differential_evolution step 215: f(x)= 0.00023104
# differential_evolution step 216: f(x)= 0.00023104
# differential_evolution step 217: f(x)= 0.00023104
# differential_evolution step 218: f(x)= 0.00023104
# differential_evolution step 219: f(x)= 0.00023104
# differential_evolution step 220: f(x)= 0.00023104
# differential_evolution step 221: f(x)= 0.00023104
# differential_evolution step 222: f(x)= 0.00023104
# differential_evolution step 223: f(x)= 0.00023104
# differential_evolution step 224: f(x)= 0.00023104
# differential_evolution step 225: f(x)= 0.00023104
# differential_evolution step 226: f(x)= 0.00023104
# differential_evolution step 227: f(x)= 0.00023104
# differential_evolution step 228: f(x)= 0.00023104
# differential_evolution step 229: f(x)= 0.00023104
# differential_evolution step 230: f(x)= 0.00023104
# differential_evolution step 231: f(x)= 0.00023104
# differential_evolution step 232: f(x)= 0.00023104
# differential_evolution step 233: f(x)= 0.00023104
# differential_evolution step 234: f(x)= 0.00023104
# differential_evolution step 235: f(x)= 0.00023104
# differential_evolution step 236: f(x)= 0.00023104
# differential_evolution step 237: f(x)= 0.00023104
# differential_evolution step 238: f(x)= 0.00023104
# differential_evolution step 239: f(x)= 0.000114124
# differential_evolution step 240: f(x)= 0.000114124
# differential_evolution step 241: f(x)= 0.000114124
# differential_evolution step 242: f(x)= 0.000114124
# differential_evolution step 243: f(x)= 0.000114124
# differential_evolution step 244: f(x)= 0.000114124
# differential_evolution step 245: f(x)= 0.000114124
# differential_evolution step 246: f(x)= 0.000114124
# differential_evolution step 247: f(x)= 0.000114124
# differential_evolution step 248: f(x)= 0.000114124
# differential_evolution step 249: f(x)= 0.000114124
# differential_evolution step 250: f(x)= 0.000114124
# differential_evolution step 251: f(x)= 0.000114124
# differential_evolution step 252: f(x)= 0.000114124
# differential_evolution step 253: f(x)= 0.000114124
# differential_evolution step 254: f(x)= 0.000114124
# differential_evolution step 255: f(x)= 0.000114124
# differential_evolution step 256: f(x)= 0.000114124
# differential_evolution step 257: f(x)= 0.000114124
# differential_evolution step 258: f(x)= 0.000114124
# differential_evolution step 259: f(x)= 0.000114124
# differential_evolution step 260: f(x)= 0.000114124
# differential_evolution step 261: f(x)= 0.000114124
# differential_evolution step 262: f(x)= 0.000114124
# differential_evolution step 263: f(x)= 0.000114124
# differential_evolution step 264: f(x)= 0.000114124
# differential_evolution step 265: f(x)= 0.000114124
# differential_evolution step 266: f(x)= 0.000114124
# differential_evolution step 267: f(x)= 0.000114124
# differential_evolution step 268: f(x)= 0.000114124
# differential_evolution step 269: f(x)= 0.000114124
# differential_evolution step 270: f(x)= 0.000114124
# differential_evolution step 271: f(x)= 0.000114124
# differential_evolution step 272: f(x)= 0.000114124
# differential_evolution step 273: f(x)= 0.000114124
# differential_evolution step 274: f(x)= 0.000114124
# differential_evolution step 275: f(x)= 0.000114124
# differential_evolution step 276: f(x)= 0.000114124
# differential_evolution step 277: f(x)= 0.000114124
# differential_evolution step 278: f(x)= 0.000114124
# differential_evolution step 279: f(x)= 0.000114124
# differential_evolution step 280: f(x)= 0.000114124
# differential_evolution step 281: f(x)= 0.000114124
# differential_evolution step 282: f(x)= 0.000114124
# differential_evolution step 283: f(x)= 0.000114124
# differential_evolution step 284: f(x)= 0.000114124
# differential_evolution step 285: f(x)= 0.000114124
# differential_evolution step 286: f(x)= 0.000114124
# differential_evolution step 287: f(x)= 0.000114124
# differential_evolution step 288: f(x)= 0.000114124
# differential_evolution step 289: f(x)= 0.000114124
# differential_evolution step 290: f(x)= 0.000114124
# differential_evolution step 291: f(x)= 0.000114124
# differential_evolution step 292: f(x)= 0.000114124
# differential_evolution step 293: f(x)= 0.000114124
# differential_evolution step 294: f(x)= 0.000114124
# differential_evolution step 295: f(x)= 0.000114124
# differential_evolution step 296: f(x)= 0.000114124
# differential_evolution step 297: f(x)= 0.000114124
# differential_evolution step 298: f(x)= 0.000114124
# differential_evolution step 299: f(x)= 0.000114124
# differential_evolution step 300: f(x)= 0.000114124
# differential_evolution step 301: f(x)= 0.000114124
# differential_evolution step 302: f(x)= 0.000114124
# differential_evolution step 303: f(x)= 0.000114124
# differential_evolution step 304: f(x)= 0.000114124
# differential_evolution step 305: f(x)= 0.000114124
# differential_evolution step 306: f(x)= 0.000114124
# differential_evolution step 307: f(x)= 0.000114124
# differential_evolution step 308: f(x)= 0.000114124
# differential_evolution step 309: f(x)= 0.000114124
# differential_evolution step 310: f(x)= 0.000114124
# differential_evolution step 311: f(x)= 0.000114124
# differential_evolution step 312: f(x)= 0.000114124
# differential_evolution step 313: f(x)= 0.000114124
# differential_evolution step 314: f(x)= 0.000114124
# differential_evolution step 315: f(x)= 0.000114124
# differential_evolution step 316: f(x)= 0.000114124
# differential_evolution step 317: f(x)= 0.000114124
# differential_evolution step 318: f(x)= 0.000114124
# differential_evolution step 319: f(x)= 0.000114124
# differential_evolution step 320: f(x)= 0.000114124
# differential_evolution step 321: f(x)= 0.000114124
# differential_evolution step 322: f(x)= 0.000114124
# differential_evolution step 323: f(x)= 0.000114124
# differential_evolution step 324: f(x)= 0.000114124
# differential_evolution step 325: f(x)= 0.000114124
# differential_evolution step 326: f(x)= 0.000114124
# differential_evolution step 327: f(x)= 0.000114124
# differential_evolution step 328: f(x)= 0.000114124
# differential_evolution step 329: f(x)= 0.000114124
# differential_evolution step 330: f(x)= 0.000114124
# differential_evolution step 331: f(x)= 0.000114124
# differential_evolution step 332: f(x)= 0.000114124
# differential_evolution step 333: f(x)= 0.000114124
# differential_evolution step 334: f(x)= 0.000114124
# differential_evolution step 335: f(x)= 0.000114124
# differential_evolution step 336: f(x)= 0.000114124
# differential_evolution step 337: f(x)= 0.000114124
# differential_evolution step 338: f(x)= 0.000114124
# differential_evolution step 339: f(x)= 0.000114124
# differential_evolution step 340: f(x)= 0.000114124
# differential_evolution step 341: f(x)= 0.000114124
# differential_evolution step 342: f(x)= 0.000114124
# differential_evolution step 343: f(x)= 0.000114124
# differential_evolution step 344: f(x)= 0.000114124
# differential_evolution step 345: f(x)= 0.000114124
# differential_evolution step 346: f(x)= 0.000114124
# differential_evolution step 347: f(x)= 0.000114124
# differential_evolution step 348: f(x)= 0.000114124
# differential_evolution step 349: f(x)= 0.000114124
# differential_evolution step 350: f(x)= 0.000114124
# differential_evolution step 351: f(x)= 0.000114124
# differential_evolution step 352: f(x)= 0.000114124
# differential_evolution step 353: f(x)= 0.000114124
# differential_evolution step 354: f(x)= 0.000114124
# differential_evolution step 355: f(x)= 0.000114124
# differential_evolution step 356: f(x)= 0.000114124
# differential_evolution step 357: f(x)= 0.000114124
# differential_evolution step 358: f(x)= 0.000114124
# differential_evolution step 359: f(x)= 0.000114124
# differential_evolution step 360: f(x)= 0.000114124
# differential_evolution step 361: f(x)= 0.000114124
# differential_evolution step 362: f(x)= 0.000114124
# differential_evolution step 363: f(x)= 0.000114124
# differential_evolution step 364: f(x)= 0.000114124
# differential_evolution step 365: f(x)= 0.000114124
# differential_evolution step 366: f(x)= 0.000114124
# differential_evolution step 367: f(x)= 0.000114124
# differential_evolution step 368: f(x)= 0.000114124
# differential_evolution step 369: f(x)= 0.000114124
# differential_evolution step 370: f(x)= 0.000114124
# differential_evolution step 371: f(x)= 0.000114124
# differential_evolution step 372: f(x)= 0.000114124
# differential_evolution step 373: f(x)= 0.000114124
# differential_evolution step 374: f(x)= 0.000114124
# differential_evolution step 375: f(x)= 0.000114124
# differential_evolution step 376: f(x)= 0.000114124
# differential_evolution step 377: f(x)= 0.000114124
# differential_evolution step 378: f(x)= 0.000114124
# differential_evolution step 379: f(x)= 0.000114124
# differential_evolution step 380: f(x)= 0.000114124
# differential_evolution step 381: f(x)= 0.000114124
# differential_evolution step 382: f(x)= 0.000114124
# differential_evolution step 383: f(x)= 0.000114124
# differential_evolution step 384: f(x)= 0.000114124
# differential_evolution step 385: f(x)= 0.000114124
# differential_evolution step 386: f(x)= 0.000114124
# differential_evolution step 387: f(x)= 0.000114124
# differential_evolution step 388: f(x)= 0.000114124
# differential_evolution step 389: f(x)= 0.000114124
# differential_evolution step 390: f(x)= 0.000114124
# differential_evolution step 391: f(x)= 0.000114124
# differential_evolution step 392: f(x)= 0.000114124
# differential_evolution step 393: f(x)= 0.000114124
# differential_evolution step 394: f(x)= 0.000114124
# differential_evolution step 395: f(x)= 0.000114124
# differential_evolution step 396: f(x)= 0.000114124
# differential_evolution step 397: f(x)= 0.000114124
# differential_evolution step 398: f(x)= 0.000114124
# differential_evolution step 399: f(x)= 0.000114124
# differential_evolution step 400: f(x)= 0.000114124
# differential_evolution step 401: f(x)= 0.000114124
# differential_evolution step 402: f(x)= 0.000114124
# differential_evolution step 403: f(x)= 0.000114124
# differential_evolution step 404: f(x)= 0.000114124
# differential_evolution step 405: f(x)= 0.000114124
# differential_evolution step 406: f(x)= 0.000114124
# differential_evolution step 407: f(x)= 0.000114124
# differential_evolution step 408: f(x)= 0.000114124
# differential_evolution step 409: f(x)= 0.000114124
# differential_evolution step 410: f(x)= 0.000114124
# differential_evolution step 411: f(x)= 0.000114124
# differential_evolution step 412: f(x)= 0.000114124
# differential_evolution step 413: f(x)= 0.000114124
# differential_evolution step 414: f(x)= 0.000114124
# differential_evolution step 415: f(x)= 0.000114124
# differential_evolution step 416: f(x)= 0.000114124
# differential_evolution step 417: f(x)= 0.000114124
# differential_evolution step 418: f(x)= 0.000114124
# differential_evolution step 419: f(x)= 0.000114124
# differential_evolution step 420: f(x)= 0.000114124
# differential_evolution step 421: f(x)= 0.000114124
# differential_evolution step 422: f(x)= 0.000114124
# differential_evolution step 423: f(x)= 0.000114124
# differential_evolution step 424: f(x)= 0.000114124
# differential_evolution step 425: f(x)= 0.000114124
# differential_evolution step 426: f(x)= 0.000114124
# differential_evolution step 427: f(x)= 0.000114124
# differential_evolution step 428: f(x)= 0.000114124
# differential_evolution step 429: f(x)= 0.000114124
# differential_evolution step 430: f(x)= 0.000114124
# differential_evolution step 431: f(x)= 0.000114124
# differential_evolution step 432: f(x)= 0.000114124
# differential_evolution step 433: f(x)= 0.000114124
# differential_evolution step 434: f(x)= 0.000114124
# differential_evolution step 435: f(x)= 0.000114124
# differential_evolution step 436: f(x)= 0.000114124
# differential_evolution step 437: f(x)= 0.000114124
# differential_evolution step 438: f(x)= 0.000114124
# differential_evolution step 439: f(x)= 0.000114124
# differential_evolution step 440: f(x)= 0.000114124
# differential_evolution step 441: f(x)= 0.000114124
# differential_evolution step 442: f(x)= 0.000114124
# differential_evolution step 443: f(x)= 0.000114124
# differential_evolution step 444: f(x)= 0.000114124
# differential_evolution step 445: f(x)= 0.000114124
# differential_evolution step 446: f(x)= 0.000114124
# differential_evolution step 447: f(x)= 0.000114124
# differential_evolution step 448: f(x)= 0.000114124
# differential_evolution step 449: f(x)= 0.000114124
# differential_evolution step 450: f(x)= 0.000114124
# differential_evolution step 451: f(x)= 0.000114124
# differential_evolution step 452: f(x)= 0.000114124
# differential_evolution step 453: f(x)= 0.000114124
# differential_evolution step 454: f(x)= 0.000114124
# differential_evolution step 455: f(x)= 0.000114124
# differential_evolution step 456: f(x)= 0.000114124
# differential_evolution step 457: f(x)= 0.000114124
# differential_evolution step 458: f(x)= 0.000114124
# differential_evolution step 459: f(x)= 0.000114124
# differential_evolution step 460: f(x)= 0.000114124
# differential_evolution step 461: f(x)= 0.000114124
# differential_evolution step 462: f(x)= 0.000114124
# differential_evolution step 463: f(x)= 0.000114124
# differential_evolution step 464: f(x)= 0.000114124
# differential_evolution step 465: f(x)= 0.000114124
# differential_evolution step 466: f(x)= 0.000114124
# differential_evolution step 467: f(x)= 0.000114124
# differential_evolution step 468: f(x)= 0.000114124
# differential_evolution step 469: f(x)= 0.000114124
# differential_evolution step 470: f(x)= 0.000114124
# differential_evolution step 471: f(x)= 0.000114124
# differential_evolution step 472: f(x)= 0.000114124
# differential_evolution step 473: f(x)= 0.000114124
# differential_evolution step 474: f(x)= 0.000114124
# differential_evolution step 475: f(x)= 0.000114124
# differential_evolution step 476: f(x)= 0.000114124
# differential_evolution step 477: f(x)= 0.000114124
# differential_evolution step 478: f(x)= 0.000114124
# differential_evolution step 479: f(x)= 0.000114124
# differential_evolution step 480: f(x)= 0.000114124
# differential_evolution step 481: f(x)= 0.000114124
# differential_evolution step 482: f(x)= 0.000114124
# differential_evolution step 483: f(x)= 0.000114124
# differential_evolution step 484: f(x)= 0.000114124
# differential_evolution step 485: f(x)= 0.000114124
# differential_evolution step 486: f(x)= 0.000114124
# differential_evolution step 487: f(x)= 0.000114124
# differential_evolution step 488: f(x)= 0.000114124
# differential_evolution step 489: f(x)= 0.000114124
# differential_evolution step 490: f(x)= 0.000114124
# differential_evolution step 491: f(x)= 0.000114124
# differential_evolution step 492: f(x)= 0.000114124
# differential_evolution step 493: f(x)= 0.000114124
# differential_evolution step 494: f(x)= 0.000114124
# differential_evolution step 495: f(x)= 0.000114124
# differential_evolution step 496: f(x)= 0.000114124
# differential_evolution step 497: f(x)= 0.000114124
# differential_evolution step 498: f(x)= 0.000114124
# differential_evolution step 499: f(x)= 0.000114124
# differential_evolution step 500: f(x)= 0.000114124
# differential_evolution step 501: f(x)= 0.000114124
# differential_evolution step 502: f(x)= 0.000114124
# differential_evolution step 503: f(x)= 0.000114124
# differential_evolution step 504: f(x)= 0.000114124
# differential_evolution step 505: f(x)= 0.000114124
# differential_evolution step 506: f(x)= 0.000114124
# differential_evolution step 507: f(x)= 0.000114124
# differential_evolution step 508: f(x)= 0.000114124
# differential_evolution step 509: f(x)= 0.000114124
# differential_evolution step 510: f(x)= 0.000114124
# differential_evolution step 511: f(x)= 0.000114124
# differential_evolution step 512: f(x)= 0.000114124
# differential_evolution step 513: f(x)= 0.000114124
# differential_evolution step 514: f(x)= 0.000114124
# differential_evolution step 515: f(x)= 0.000114124
# differential_evolution step 516: f(x)= 0.000114124
# differential_evolution step 517: f(x)= 0.000114124
# differential_evolution step 518: f(x)= 0.000114124
# differential_evolution step 519: f(x)= 0.000114124
# differential_evolution step 520: f(x)= 0.000114124
# differential_evolution step 521: f(x)= 7.56779e-05
# differential_evolution step 522: f(x)= 7.56779e-05
# differential_evolution step 523: f(x)= 7.56779e-05
# differential_evolution step 524: f(x)= 7.56779e-05
# differential_evolution step 525: f(x)= 7.56779e-05
# differential_evolution step 526: f(x)= 7.56779e-05
# differential_evolution step 527: f(x)= 7.56779e-05
# differential_evolution step 528: f(x)= 7.56779e-05
# differential_evolution step 529: f(x)= 7.56779e-05
# differential_evolution step 530: f(x)= 7.56779e-05
# differential_evolution step 531: f(x)= 7.56779e-05
# differential_evolution step 532: f(x)= 7.56779e-05
# differential_evolution step 533: f(x)= 7.56779e-05
# differential_evolution step 534: f(x)= 7.56779e-05
# differential_evolution step 535: f(x)= 7.56779e-05
# differential_evolution step 536: f(x)= 7.56779e-05
# differential_evolution step 537: f(x)= 7.56779e-05
# differential_evolution step 538: f(x)= 7.56779e-05
# differential_evolution step 539: f(x)= 7.56779e-05
# differential_evolution step 540: f(x)= 7.56779e-05
# differential_evolution step 541: f(x)= 7.56779e-05
# differential_evolution step 542: f(x)= 7.56779e-05
# differential_evolution step 543: f(x)= 7.56779e-05
# differential_evolution step 544: f(x)= 7.56779e-05
# differential_evolution step 545: f(x)= 7.56779e-05
# differential_evolution step 546: f(x)= 7.56779e-05
# differential_evolution step 547: f(x)= 7.56779e-05
# differential_evolution step 548: f(x)= 7.56779e-05
# differential_evolution step 549: f(x)= 7.56779e-05
# differential_evolution step 550: f(x)= 7.56779e-05
# differential_evolution step 551: f(x)= 7.56779e-05
# differential_evolution step 552: f(x)= 7.56779e-05
# differential_evolution step 553: f(x)= 7.56779e-05
# differential_evolution step 554: f(x)= 7.56779e-05
# differential_evolution step 555: f(x)= 7.56779e-05
# differential_evolution step 556: f(x)= 7.56779e-05
# differential_evolution step 557: f(x)= 7.56779e-05
# differential_evolution step 558: f(x)= 7.56779e-05
# differential_evolution step 559: f(x)= 7.56779e-05
# differential_evolution step 560: f(x)= 7.56779e-05
# differential_evolution step 561: f(x)= 7.56779e-05
# differential_evolution step 562: f(x)= 7.56779e-05
# differential_evolution step 563: f(x)= 7.56779e-05
# differential_evolution step 564: f(x)= 7.56779e-05
# differential_evolution step 565: f(x)= 7.56779e-05
# differential_evolution step 566: f(x)= 7.56779e-05
# differential_evolution step 567: f(x)= 7.56779e-05
# differential_evolution step 568: f(x)= 7.56779e-05
# differential_evolution step 569: f(x)= 7.56779e-05
# differential_evolution step 570: f(x)= 7.56779e-05
# differential_evolution step 571: f(x)= 7.56779e-05
# differential_evolution step 572: f(x)= 7.56779e-05
# differential_evolution step 573: f(x)= 7.56779e-05
# differential_evolution step 574: f(x)= 7.56779e-05
# differential_evolution step 575: f(x)= 7.56779e-05
# differential_evolution step 576: f(x)= 7.56779e-05
# differential_evolution step 577: f(x)= 7.56779e-05
# differential_evolution step 578: f(x)= 7.56779e-05
# differential_evolution step 579: f(x)= 7.56779e-05
# differential_evolution step 580: f(x)= 7.56779e-05
# differential_evolution step 581: f(x)= 7.56779e-05
# differential_evolution step 582: f(x)= 7.56779e-05
# differential_evolution step 583: f(x)= 7.56779e-05
# differential_evolution step 584: f(x)= 7.56779e-05
# differential_evolution step 585: f(x)= 7.56779e-05
# differential_evolution step 586: f(x)= 7.56779e-05
# differential_evolution step 587: f(x)= 7.56779e-05
# differential_evolution step 588: f(x)= 7.56779e-05
# differential_evolution step 589: f(x)= 7.56779e-05
# differential_evolution step 590: f(x)= 7.56779e-05
# differential_evolution step 591: f(x)= 7.56779e-05
# differential_evolution step 592: f(x)= 7.56779e-05
# differential_evolution step 593: f(x)= 7.56779e-05
# differential_evolution step 594: f(x)= 7.56779e-05
# differential_evolution step 595: f(x)= 7.56779e-05
# differential_evolution step 596: f(x)= 7.56779e-05
# differential_evolution step 597: f(x)= 7.56779e-05
# differential_evolution step 598: f(x)= 7.56779e-05
# differential_evolution step 599: f(x)= 7.56779e-05
# differential_evolution step 600: f(x)= 7.56779e-05
# differential_evolution step 601: f(x)= 7.56779e-05
# differential_evolution step 602: f(x)= 7.56779e-05
# differential_evolution step 603: f(x)= 7.56779e-05
# differential_evolution step 604: f(x)= 7.56779e-05
# differential_evolution step 605: f(x)= 7.56779e-05
# differential_evolution step 606: f(x)= 7.56779e-05
# differential_evolution step 607: f(x)= 7.56779e-05
# differential_evolution step 608: f(x)= 7.56779e-05
# differential_evolution step 609: f(x)= 7.56779e-05
# differential_evolution step 610: f(x)= 7.56779e-05
# differential_evolution step 611: f(x)= 7.56779e-05
# differential_evolution step 612: f(x)= 7.56779e-05
# differential_evolution step 613: f(x)= 7.56779e-05
# differential_evolution step 614: f(x)= 7.56779e-05
# differential_evolution step 615: f(x)= 7.56779e-05
# differential_evolution step 616: f(x)= 7.56779e-05
# differential_evolution step 617: f(x)= 7.56779e-05
# differential_evolution step 618: f(x)= 7.56779e-05
# differential_evolution step 619: f(x)= 7.56779e-05
# differential_evolution step 620: f(x)= 7.56779e-05
# differential_evolution step 621: f(x)= 7.56779e-05
# differential_evolution step 622: f(x)= 7.56779e-05
# differential_evolution step 623: f(x)= 7.56779e-05
# differential_evolution step 624: f(x)= 7.56779e-05
# differential_evolution step 625: f(x)= 7.56779e-05
# differential_evolution step 626: f(x)= 7.56779e-05
# differential_evolution step 627: f(x)= 7.56779e-05
# differential_evolution step 628: f(x)= 7.56779e-05
# differential_evolution step 629: f(x)= 7.56779e-05
# differential_evolution step 630: f(x)= 7.56779e-05
# differential_evolution step 631: f(x)= 7.56779e-05
# differential_evolution step 632: f(x)= 7.56779e-05
# differential_evolution step 633: f(x)= 7.56779e-05
# differential_evolution step 634: f(x)= 7.56779e-05
# differential_evolution step 635: f(x)= 7.56779e-05
# differential_evolution step 636: f(x)= 7.56779e-05
# differential_evolution step 637: f(x)= 7.56779e-05
# differential_evolution step 638: f(x)= 7.56779e-05
# differential_evolution step 639: f(x)= 7.56779e-05
# differential_evolution step 640: f(x)= 7.56779e-05
# differential_evolution step 641: f(x)= 7.56779e-05
# differential_evolution step 642: f(x)= 7.56779e-05
# differential_evolution step 643: f(x)= 7.56779e-05
# differential_evolution step 644: f(x)= 7.56779e-05
# differential_evolution step 645: f(x)= 7.56779e-05
# differential_evolution step 646: f(x)= 7.56779e-05
# differential_evolution step 647: f(x)= 7.56779e-05
# differential_evolution step 648: f(x)= 7.56779e-05
# differential_evolution step 649: f(x)= 7.56779e-05
# differential_evolution step 650: f(x)= 7.56779e-05
# differential_evolution step 651: f(x)= 7.56779e-05
# differential_evolution step 652: f(x)= 7.56779e-05
# differential_evolution step 653: f(x)= 7.56779e-05
# differential_evolution step 654: f(x)= 7.56779e-05
# differential_evolution step 655: f(x)= 7.56779e-05
# differential_evolution step 656: f(x)= 7.56779e-05
# differential_evolution step 657: f(x)= 7.56779e-05
# differential_evolution step 658: f(x)= 7.56779e-05
# differential_evolution step 659: f(x)= 7.56779e-05
# differential_evolution step 660: f(x)= 7.56779e-05
# differential_evolution step 661: f(x)= 7.56779e-05
# differential_evolution step 662: f(x)= 7.56779e-05
# differential_evolution step 663: f(x)= 7.56779e-05
# differential_evolution step 664: f(x)= 7.56779e-05
# differential_evolution step 665: f(x)= 7.56779e-05
# differential_evolution step 666: f(x)= 7.56779e-05
# differential_evolution step 667: f(x)= 7.56779e-05
# differential_evolution step 668: f(x)= 7.56779e-05
# differential_evolution step 669: f(x)= 7.56779e-05
# differential_evolution step 670: f(x)= 7.56779e-05
# differential_evolution step 671: f(x)= 7.56779e-05
# differential_evolution step 672: f(x)= 7.56779e-05
# differential_evolution step 673: f(x)= 7.56779e-05
# differential_evolution step 674: f(x)= 7.56779e-05
# differential_evolution step 675: f(x)= 7.56779e-05
# differential_evolution step 676: f(x)= 7.56779e-05
# differential_evolution step 677: f(x)= 7.56779e-05
# differential_evolution step 678: f(x)= 7.56779e-05
# differential_evolution step 679: f(x)= 7.56779e-05
# differential_evolution step 680: f(x)= 7.56779e-05
# differential_evolution step 681: f(x)= 7.56779e-05
# differential_evolution step 682: f(x)= 7.56779e-05
# differential_evolution step 683: f(x)= 7.56779e-05
# differential_evolution step 684: f(x)= 7.56779e-05
# differential_evolution step 685: f(x)= 7.56779e-05
# differential_evolution step 686: f(x)= 7.56779e-05
# differential_evolution step 687: f(x)= 7.56779e-05
# differential_evolution step 688: f(x)= 7.56779e-05
# differential_evolution step 689: f(x)= 7.56779e-05
# differential_evolution step 690: f(x)= 7.56779e-05
# differential_evolution step 691: f(x)= 7.56779e-05
# differential_evolution step 692: f(x)= 7.56779e-05
# differential_evolution step 693: f(x)= 7.56779e-05
# differential_evolution step 694: f(x)= 7.56779e-05
# differential_evolution step 695: f(x)= 7.56779e-05
# differential_evolution step 696: f(x)= 7.56779e-05
# differential_evolution step 697: f(x)= 7.56779e-05
# differential_evolution step 698: f(x)= 7.56779e-05
# differential_evolution step 699: f(x)= 7.56779e-05
# differential_evolution step 700: f(x)= 7.56779e-05
# differential_evolution step 701: f(x)= 7.56779e-05
# differential_evolution step 702: f(x)= 7.56779e-05
# differential_evolution step 703: f(x)= 7.56779e-05
# differential_evolution step 704: f(x)= 7.56779e-05
# differential_evolution step 705: f(x)= 7.56779e-05
# differential_evolution step 706: f(x)= 7.56779e-05
# differential_evolution step 707: f(x)= 7.56779e-05
# differential_evolution step 708: f(x)= 7.56779e-05
# differential_evolution step 709: f(x)= 7.56779e-05
# differential_evolution step 710: f(x)= 7.56779e-05
# differential_evolution step 711: f(x)= 7.56779e-05
# differential_evolution step 712: f(x)= 7.56779e-05
# differential_evolution step 713: f(x)= 7.56779e-05
# differential_evolution step 714: f(x)= 7.56779e-05
# differential_evolution step 715: f(x)= 7.56779e-05
# differential_evolution step 716: f(x)= 7.56779e-05
# differential_evolution step 717: f(x)= 7.56779e-05
# differential_evolution step 718: f(x)= 7.56779e-05
# differential_evolution step 719: f(x)= 7.56779e-05
# differential_evolution step 720: f(x)= 7.56779e-05
# differential_evolution step 721: f(x)= 7.56779e-05
# differential_evolution step 722: f(x)= 7.56779e-05
# differential_evolution step 723: f(x)= 7.56779e-05
# differential_evolution step 724: f(x)= 7.56779e-05
# differential_evolution step 725: f(x)= 7.56779e-05
# differential_evolution step 726: f(x)= 7.56779e-05
# differential_evolution step 727: f(x)= 7.56779e-05
# differential_evolution step 728: f(x)= 7.56779e-05
# differential_evolution step 729: f(x)= 7.56779e-05
# differential_evolution step 730: f(x)= 7.56779e-05
# differential_evolution step 731: f(x)= 7.56779e-05
# differential_evolution step 732: f(x)= 7.56779e-05
# differential_evolution step 733: f(x)= 7.56779e-05
# differential_evolution step 734: f(x)= 7.56779e-05
# differential_evolution step 735: f(x)= 7.56779e-05
# differential_evolution step 736: f(x)= 7.56779e-05
# differential_evolution step 737: f(x)= 7.56779e-05
# differential_evolution step 738: f(x)= 7.56779e-05
# differential_evolution step 739: f(x)= 7.56779e-05
# differential_evolution step 740: f(x)= 7.56779e-05
# differential_evolution step 741: f(x)= 7.56779e-05
# differential_evolution step 742: f(x)= 7.56779e-05
# differential_evolution step 743: f(x)= 7.56779e-05
# differential_evolution step 744: f(x)= 7.56779e-05
# differential_evolution step 745: f(x)= 7.56779e-05
# differential_evolution step 746: f(x)= 7.56779e-05
# differential_evolution step 747: f(x)= 7.56779e-05
# differential_evolution step 748: f(x)= 7.56779e-05
# differential_evolution step 749: f(x)= 7.56779e-05
# differential_evolution step 750: f(x)= 7.56779e-05
# differential_evolution step 751: f(x)= 7.56779e-05
# differential_evolution step 752: f(x)= 7.56779e-05
# differential_evolution step 753: f(x)= 7.56779e-05
# differential_evolution step 754: f(x)= 7.56779e-05
# differential_evolution step 755: f(x)= 7.56779e-05
# differential_evolution step 756: f(x)= 7.56779e-05
# differential_evolution step 757: f(x)= 7.56779e-05
# differential_evolution step 758: f(x)= 7.56779e-05
# differential_evolution step 759: f(x)= 7.56779e-05
# differential_evolution step 760: f(x)= 7.56779e-05
# differential_evolution step 761: f(x)= 7.56779e-05
# differential_evolution step 762: f(x)= 7.56779e-05
# differential_evolution step 763: f(x)= 7.56779e-05
# differential_evolution step 764: f(x)= 7.56779e-05
# differential_evolution step 765: f(x)= 7.56779e-05
# differential_evolution step 766: f(x)= 7.56779e-05
# differential_evolution step 767: f(x)= 7.56779e-05
# differential_evolution step 768: f(x)= 7.56779e-05
# differential_evolution step 769: f(x)= 7.56779e-05
# differential_evolution step 770: f(x)= 7.56779e-05
# differential_evolution step 771: f(x)= 7.56779e-05
# differential_evolution step 772: f(x)= 7.56779e-05
# differential_evolution step 773: f(x)= 7.56779e-05
# differential_evolution step 774: f(x)= 7.56779e-05
# differential_evolution step 775: f(x)= 7.56779e-05
# differential_evolution step 776: f(x)= 7.56779e-05
# differential_evolution step 777: f(x)= 7.56779e-05
# differential_evolution step 778: f(x)= 7.56779e-05
# differential_evolution step 779: f(x)= 7.56779e-05
# differential_evolution step 780: f(x)= 7.56779e-05
# differential_evolution step 781: f(x)= 7.56779e-05
# differential_evolution step 782: f(x)= 7.56779e-05
# differential_evolution step 783: f(x)= 7.56779e-05
# differential_evolution step 784: f(x)= 7.56779e-05
# differential_evolution step 785: f(x)= 7.56779e-05
# differential_evolution step 786: f(x)= 7.56779e-05
# differential_evolution step 787: f(x)= 7.56779e-05
# differential_evolution step 788: f(x)= 7.56779e-05
# differential_evolution step 789: f(x)= 7.56779e-05
# differential_evolution step 790: f(x)= 7.56779e-05
# differential_evolution step 791: f(x)= 7.56779e-05
# differential_evolution step 792: f(x)= 7.56779e-05
# differential_evolution step 793: f(x)= 7.56779e-05
# differential_evolution step 794: f(x)= 7.56779e-05
# differential_evolution step 795: f(x)= 7.56779e-05
# differential_evolution step 796: f(x)= 7.56779e-05
# differential_evolution step 797: f(x)= 7.56779e-05
# differential_evolution step 798: f(x)= 7.56779e-05
# differential_evolution step 799: f(x)= 7.56779e-05
# differential_evolution step 800: f(x)= 7.56779e-05
# differential_evolution step 801: f(x)= 7.56779e-05
# differential_evolution step 802: f(x)= 7.56779e-05
# differential_evolution step 803: f(x)= 7.56779e-05
# differential_evolution step 804: f(x)= 7.56779e-05
# differential_evolution step 805: f(x)= 7.56779e-05
# differential_evolution step 806: f(x)= 7.56779e-05
# differential_evolution step 807: f(x)= 7.56779e-05
# differential_evolution step 808: f(x)= 7.56779e-05
# differential_evolution step 809: f(x)= 7.56779e-05
# differential_evolution step 810: f(x)= 7.56779e-05
# differential_evolution step 811: f(x)= 7.56779e-05
# differential_evolution step 812: f(x)= 7.56779e-05
# differential_evolution step 813: f(x)= 7.56779e-05
# differential_evolution step 814: f(x)= 7.56779e-05
# differential_evolution step 815: f(x)= 7.56779e-05
# differential_evolution step 816: f(x)= 7.56779e-05
# differential_evolution step 817: f(x)= 7.56779e-05
# differential_evolution step 818: f(x)= 7.56779e-05
# differential_evolution step 819: f(x)= 7.56779e-05
# differential_evolution step 820: f(x)= 7.56779e-05
# differential_evolution step 821: f(x)= 7.56779e-05
# differential_evolution step 822: f(x)= 7.56779e-05
# differential_evolution step 823: f(x)= 7.56779e-05
# differential_evolution step 824: f(x)= 7.56779e-05
# differential_evolution step 825: f(x)= 7.56779e-05
# differential_evolution step 826: f(x)= 7.56779e-05
# differential_evolution step 827: f(x)= 7.56779e-05
# differential_evolution step 828: f(x)= 7.56779e-05
# differential_evolution step 829: f(x)= 7.56779e-05
# differential_evolution step 830: f(x)= 7.56779e-05
# differential_evolution step 831: f(x)= 7.56779e-05
# differential_evolution step 832: f(x)= 7.56779e-05
# differential_evolution step 833: f(x)= 7.56779e-05
# differential_evolution step 834: f(x)= 7.56779e-05
# differential_evolution step 835: f(x)= 7.56779e-05
# differential_evolution step 836: f(x)= 7.56779e-05
# differential_evolution step 837: f(x)= 7.56779e-05
# differential_evolution step 838: f(x)= 7.56779e-05
# differential_evolution step 839: f(x)= 7.56779e-05
# differential_evolution step 840: f(x)= 7.56779e-05
# differential_evolution step 841: f(x)= 7.56779e-05
# differential_evolution step 842: f(x)= 7.56779e-05
# differential_evolution step 843: f(x)= 7.56779e-05
# differential_evolution step 844: f(x)= 7.56779e-05
# differential_evolution step 845: f(x)= 7.56779e-05
# differential_evolution step 846: f(x)= 7.56779e-05
# differential_evolution step 847: f(x)= 7.56779e-05
# differential_evolution step 848: f(x)= 7.56779e-05
# differential_evolution step 849: f(x)= 7.56779e-05
# differential_evolution step 850: f(x)= 7.56779e-05
# differential_evolution step 851: f(x)= 7.56779e-05
# differential_evolution step 852: f(x)= 7.56779e-05
# differential_evolution step 853: f(x)= 7.56779e-05
# differential_evolution step 854: f(x)= 7.56779e-05
# differential_evolution step 855: f(x)= 7.56779e-05
# differential_evolution step 856: f(x)= 7.56779e-05
# differential_evolution step 857: f(x)= 7.56779e-05
# differential_evolution step 858: f(x)= 7.56779e-05
# differential_evolution step 859: f(x)= 7.56779e-05
# differential_evolution step 860: f(x)= 7.56779e-05
# differential_evolution step 861: f(x)= 7.56779e-05
# differential_evolution step 862: f(x)= 7.56779e-05
# differential_evolution step 863: f(x)= 7.56779e-05
# differential_evolution step 864: f(x)= 7.56779e-05
# differential_evolution step 865: f(x)= 7.56779e-05
# differential_evolution step 866: f(x)= 7.56779e-05
# differential_evolution step 867: f(x)= 7.56779e-05
# differential_evolution step 868: f(x)= 7.56779e-05
# differential_evolution step 869: f(x)= 7.56779e-05
# differential_evolution step 870: f(x)= 7.56779e-05
# differential_evolution step 871: f(x)= 7.56779e-05
# differential_evolution step 872: f(x)= 7.56779e-05
# differential_evolution step 873: f(x)= 7.56779e-05
# differential_evolution step 874: f(x)= 7.56779e-05
# differential_evolution step 875: f(x)= 7.56779e-05
# differential_evolution step 876: f(x)= 7.56779e-05
# differential_evolution step 877: f(x)= 7.56779e-05
# differential_evolution step 878: f(x)= 7.56779e-05
# differential_evolution step 879: f(x)= 7.56779e-05
# differential_evolution step 880: f(x)= 7.56779e-05
# differential_evolution step 881: f(x)= 7.56779e-05
# differential_evolution step 882: f(x)= 7.56779e-05
# differential_evolution step 883: f(x)= 7.56779e-05
# differential_evolution step 884: f(x)= 7.56779e-05
# differential_evolution step 885: f(x)= 7.56779e-05
# differential_evolution step 886: f(x)= 7.56779e-05
# differential_evolution step 887: f(x)= 7.56779e-05
# differential_evolution step 888: f(x)= 7.56779e-05
# differential_evolution step 889: f(x)= 7.56779e-05
# differential_evolution step 890: f(x)= 7.56779e-05
# differential_evolution step 891: f(x)= 7.56779e-05
# differential_evolution step 892: f(x)= 7.56779e-05
# differential_evolution step 893: f(x)= 7.56779e-05
# differential_evolution step 894: f(x)= 7.56779e-05
# differential_evolution step 895: f(x)= 7.56779e-05
# differential_evolution step 896: f(x)= 7.56779e-05
# differential_evolution step 897: f(x)= 7.56779e-05
# differential_evolution step 898: f(x)= 7.56779e-05
# differential_evolution step 899: f(x)= 7.56779e-05
# differential_evolution step 900: f(x)= 7.56779e-05
# differential_evolution step 901: f(x)= 7.56779e-05
# differential_evolution step 902: f(x)= 7.56779e-05
# differential_evolution step 903: f(x)= 7.56779e-05
# differential_evolution step 904: f(x)= 7.56779e-05
# differential_evolution step 905: f(x)= 7.56779e-05
# differential_evolution step 906: f(x)= 7.56779e-05
# differential_evolution step 907: f(x)= 7.56779e-05
# differential_evolution step 908: f(x)= 7.56779e-05
# differential_evolution step 909: f(x)= 7.56779e-05
# differential_evolution step 910: f(x)= 7.56779e-05
# differential_evolution step 911: f(x)= 7.56779e-05
# differential_evolution step 912: f(x)= 7.56779e-05
# differential_evolution step 913: f(x)= 7.56779e-05
# differential_evolution step 914: f(x)= 7.56779e-05
# differential_evolution step 915: f(x)= 7.56779e-05
# differential_evolution step 916: f(x)= 7.56779e-05
# differential_evolution step 917: f(x)= 7.56779e-05
# differential_evolution step 918: f(x)= 7.56779e-05
# differential_evolution step 919: f(x)= 7.56779e-05
# differential_evolution step 920: f(x)= 7.56779e-05
# differential_evolution step 921: f(x)= 7.56779e-05
# differential_evolution step 922: f(x)= 7.56779e-05
# differential_evolution step 923: f(x)= 7.56779e-05
# differential_evolution step 924: f(x)= 7.56779e-05
# differential_evolution step 925: f(x)= 7.56779e-05
# differential_evolution step 926: f(x)= 7.56779e-05
# differential_evolution step 927: f(x)= 7.56779e-05
# differential_evolution step 928: f(x)= 7.56779e-05
# differential_evolution step 929: f(x)= 7.56779e-05
# differential_evolution step 930: f(x)= 7.56779e-05
# differential_evolution step 931: f(x)= 7.56779e-05
# differential_evolution step 932: f(x)= 7.56779e-05
# differential_evolution step 933: f(x)= 7.56779e-05
# differential_evolution step 934: f(x)= 7.56779e-05
# differential_evolution step 935: f(x)= 7.56779e-05
# differential_evolution step 936: f(x)= 7.56779e-05
# differential_evolution step 937: f(x)= 7.56779e-05
# differential_evolution step 938: f(x)= 7.56779e-05
# differential_evolution step 939: f(x)= 7.56779e-05
# differential_evolution step 940: f(x)= 7.56779e-05
# differential_evolution step 941: f(x)= 7.56779e-05
# differential_evolution step 942: f(x)= 7.56779e-05
# differential_evolution step 943: f(x)= 7.56779e-05
# differential_evolution step 944: f(x)= 7.56779e-05
# ...
# differential_evolution step 902: f(x)= 0.000101496
# differential_evolution step 903: f(x)= 0.000101496
# differential_evolution step 904: f(x)= 0.000101496
# differential_evolution step 905: f(x)= 0.000101496
# differential_evolution step 906: f(x)= 0.000101496
# differential_evolution step 907: f(x)= 0.000101496
# differential_evolution step 908: f(x)= 0.000101496
# differential_evolution step 909: f(x)= 0.000101496
# differential_evolution step 910: f(x)= 0.000101496
# differential_evolution step 911: f(x)= 0.000101496
# differential_evolution step 912: f(x)= 0.000101496
# differential_evolution step 913: f(x)= 0.000101496
# differential_evolution step 914: f(x)= 0.000101496
# differential_evolution step 915: f(x)= 0.000101496
# differential_evolution step 916: f(x)= 0.000101496
# differential_evolution step 917: f(x)= 0.000101496
# differential_evolution step 918: f(x)= 0.000101496
# differential_evolution step 919: f(x)= 0.000101496
# differential_evolution step 920: f(x)= 0.000101496
# differential_evolution step 921: f(x)= 0.000101496
# differential_evolution step 922: f(x)= 0.000101496
# differential_evolution step 923: f(x)= 0.000101496
# differential_evolution step 924: f(x)= 0.000101496
# differential_evolution step 925: f(x)= 0.000101496
# differential_evolution step 926: f(x)= 0.000101496
# differential_evolution step 927: f(x)= 0.000101496
# differential_evolution step 928: f(x)= 0.000101496
# differential_evolution step 929: f(x)= 0.000101496
# differential_evolution step 930: f(x)= 0.000101496
# differential_evolution step 931: f(x)= 0.000101496
# differential_evolution step 932: f(x)= 0.000101496
# differential_evolution step 933: f(x)= 0.000101496
# differential_evolution step 934: f(x)= 0.000101496
# differential_evolution step 935: f(x)= 0.000101496
# differential_evolution step 936: f(x)= 0.000101496
# differential_evolution step 937: f(x)= 0.000101496
# differential_evolution step 938: f(x)= 0.000101496
# differential_evolution step 939: f(x)= 0.000101496
# differential_evolution step 940: f(x)= 0.000101496
# differential_evolution step 941: f(x)= 0.000101496
# differential_evolution step 942: f(x)= 0.000101496
# differential_evolution step 943: f(x)= 0.000101496
# differential_evolution step 944: f(x)= 0.000101496
# differential_evolution step 945: f(x)= 0.000101496
# differential_evolution step 946: f(x)= 0.000101496
# differential_evolution step 947: f(x)= 0.000101496
# differential_evolution step 948: f(x)= 0.000101496
# differential_evolution step 949: f(x)= 0.000101496
# differential_evolution step 950: f(x)= 0.000101496
# differential_evolution step 951: f(x)= 0.000101496
# differential_evolution step 952: f(x)= 0.000101496
# differential_evolution step 953: f(x)= 0.000101496
# differential_evolution step 954: f(x)= 0.000101496
# differential_evolution step 955: f(x)= 0.000101496
# differential_evolution step 956: f(x)= 0.000101496
# differential_evolution step 957: f(x)= 0.000101496
# differential_evolution step 958: f(x)= 0.000101496
# differential_evolution step 959: f(x)= 0.000101496
# differential_evolution step 960: f(x)= 0.000101496
# differential_evolution step 961: f(x)= 0.000101496
# differential_evolution step 962: f(x)= 0.000101496
# differential_evolution step 963: f(x)= 0.000101496
# differential_evolution step 964: f(x)= 0.000101496
# differential_evolution step 965: f(x)= 0.000101496
# differential_evolution step 966: f(x)= 0.000101496
# differential_evolution step 967: f(x)= 0.000101496
# differential_evolution step 968: f(x)= 0.000101496
# differential_evolution step 969: f(x)= 0.000101496
# differential_evolution step 970: f(x)= 0.000101496
# differential_evolution step 971: f(x)= 0.000101496
# differential_evolution step 972: f(x)= 0.000101496
# differential_evolution step 973: f(x)= 0.000101496
# differential_evolution step 974: f(x)= 0.000101496
# differential_evolution step 975: f(x)= 0.000101496
# differential_evolution step 976: f(x)= 0.000101496
# differential_evolution step 977: f(x)= 0.000101496
# differential_evolution step 978: f(x)= 0.000101496
# differential_evolution step 979: f(x)= 0.000101496
# differential_evolution step 980: f(x)= 0.000101496
# differential_evolution step 981: f(x)= 0.000101496
# differential_evolution step 982: f(x)= 0.000101496
# differential_evolution step 983: f(x)= 0.000101496
# differential_evolution step 984: f(x)= 0.000101496
# differential_evolution step 985: f(x)= 0.000101496
# differential_evolution step 986: f(x)= 0.000101496
# differential_evolution step 987: f(x)= 0.000101496
# differential_evolution step 988: f(x)= 0.000101496
# differential_evolution step 989: f(x)= 0.000101496
# differential_evolution step 990: f(x)= 0.000101496
# differential_evolution step 991: f(x)= 0.000101496
# differential_evolution step 992: f(x)= 0.000101496
# differential_evolution step 993: f(x)= 0.000101496
# differential_evolution step 994: f(x)= 0.000101496
# differential_evolution step 995: f(x)= 0.000101496
# differential_evolution step 996: f(x)= 0.000101496
# differential_evolution step 997: f(x)= 0.000101496
# differential_evolution step 998: f(x)= 0.000101496
# differential_evolution step 999: f(x)= 0.000101496
# differential_evolution step 1000: f(x)= 0.000101496
# differential_evolution step 1001: f(x)= 0.000101496
# differential_evolution step 1002: f(x)= 0.000101496
# differential_evolution step 1003: f(x)= 0.000101496
# differential_evolution step 1004: f(x)= 0.000101496
# differential_evolution step 1005: f(x)= 0.000101496
# differential_evolution step 1006: f(x)= 0.000101496
# differential_evolution step 1007: f(x)= 0.000101496
# differential_evolution step 1008: f(x)= 0.000101496
# differential_evolution step 1009: f(x)= 0.000101496
# differential_evolution step 1010: f(x)= 0.000101496
# differential_evolution step 1011: f(x)= 0.000101496
# differential_evolution step 1012: f(x)= 0.000101496
# differential_evolution step 1013: f(x)= 0.000101496
# differential_evolution step 1014: f(x)= 0.000101496
# differential_evolution step 1015: f(x)= 0.000101496
# differential_evolution step 1016: f(x)= 0.000101496
# differential_evolution step 1017: f(x)= 0.000101496
# differential_evolution step 1018: f(x)= 0.000101496
# differential_evolution step 1019: f(x)= 0.000101496
# differential_evolution step 1020: f(x)= 0.000101496
# differential_evolution step 1021: f(x)= 0.000101496
# differential_evolution step 1022: f(x)= 0.000101496
# differential_evolution step 1023: f(x)= 0.000101496
# differential_evolution step 1024: f(x)= 0.000101496
# differential_evolution step 1025: f(x)= 0.000101496
# differential_evolution step 1026: f(x)= 0.000101496
# differential_evolution step 1027: f(x)= 0.000101496
# differential_evolution step 1028: f(x)= 0.000101496
# differential_evolution step 1029: f(x)= 0.000101496
# differential_evolution step 1030: f(x)= 0.000101496
# differential_evolution step 1031: f(x)= 0.000101496
# differential_evolution step 1032: f(x)= 0.000101496
# differential_evolution step 1033: f(x)= 0.000101496
# differential_evolution step 1034: f(x)= 0.000101496
# differential_evolution step 1035: f(x)= 0.000101496
# differential_evolution step 1036: f(x)= 0.000101496
# differential_evolution step 1037: f(x)= 0.000101496
# differential_evolution step 1038: f(x)= 0.000101496
# differential_evolution step 1039: f(x)= 0.000101496
# differential_evolution step 1040: f(x)= 0.000101496
# differential_evolution step 1041: f(x)= 0.000101496
# differential_evolution step 1042: f(x)= 0.000101496
# differential_evolution step 1043: f(x)= 0.000101496
# differential_evolution step 1044: f(x)= 0.000101496
# differential_evolution step 1045: f(x)= 0.000101496
# differential_evolution step 1046: f(x)= 0.000101496
# differential_evolution step 1047: f(x)= 0.000101496
# differential_evolution step 1048: f(x)= 0.000101496
# differential_evolution step 1049: f(x)= 0.000101496
# differential_evolution step 1050: f(x)= 0.000101496
# differential_evolution step 1051: f(x)= 0.000101496
# differential_evolution step 1052: f(x)= 0.000101496
# differential_evolution step 1053: f(x)= 0.000101496
# differential_evolution step 1054: f(x)= 0.000101496
# differential_evolution step 1055: f(x)= 0.000101496
# differential_evolution step 1056: f(x)= 0.000101496
# differential_evolution step 1057: f(x)= 0.000101496
# differential_evolution step 1058: f(x)= 0.000101496
# differential_evolution step 1059: f(x)= 0.000101496
# differential_evolution step 1060: f(x)= 0.000101496
# differential_evolution step 1061: f(x)= 0.000101496
# differential_evolution step 1062: f(x)= 0.000101496
# differential_evolution step 1063: f(x)= 0.000101496
# differential_evolution step 1064: f(x)= 0.000101496
# differential_evolution step 1065: f(x)= 0.000101496
# differential_evolution step 1066: f(x)= 0.000101496
# differential_evolution step 1067: f(x)= 0.000101496
# differential_evolution step 1068: f(x)= 0.000101496
# differential_evolution step 1069: f(x)= 0.000101496
# differential_evolution step 1070: f(x)= 0.000101496
# differential_evolution step 1071: f(x)= 0.000101496
# differential_evolution step 1072: f(x)= 0.000101496
# differential_evolution step 1073: f(x)= 0.000101496
# differential_evolution step 1074: f(x)= 0.000101496
# differential_evolution step 1075: f(x)= 0.000101496
# differential_evolution step 1076: f(x)= 0.000101496
# differential_evolution step 1077: f(x)= 0.000101496
# differential_evolution step 1078: f(x)= 0.000101496
# differential_evolution step 1079: f(x)= 0.000101496
# differential_evolution step 1080: f(x)= 0.000101496
# differential_evolution step 1081: f(x)= 0.000101496
# differential_evolution step 1082: f(x)= 0.000101496
# differential_evolution step 1083: f(x)= 0.000101496
# differential_evolution step 1084: f(x)= 0.000101496
# differential_evolution step 1085: f(x)= 0.000101496
# differential_evolution step 1086: f(x)= 0.000101496
# differential_evolution step 1087: f(x)= 0.000101496
# differential_evolution step 1088: f(x)= 0.000101496
# differential_evolution step 1089: f(x)= 0.000101496
# differential_evolution step 1090: f(x)= 0.000101496
# differential_evolution step 1091: f(x)= 0.000101496
# differential_evolution step 1092: f(x)= 0.000101496
# differential_evolution step 1093: f(x)= 0.000101496
# differential_evolution step 1094: f(x)= 0.000101496
# differential_evolution step 1095: f(x)= 0.000101496
# differential_evolution step 1096: f(x)= 0.000101496
# differential_evolution step 1097: f(x)= 0.000101496
# differential_evolution step 1098: f(x)= 0.000101496
# differential_evolution step 1099: f(x)= 0.000101496
# differential_evolution step 1100: f(x)= 0.000101496
# differential_evolution step 1101: f(x)= 0.000101496
# differential_evolution step 1102: f(x)= 0.000101496
# differential_evolution step 1103: f(x)= 0.000101496
# differential_evolution step 1104: f(x)= 0.000101496
# differential_evolution step 1105: f(x)= 0.000101496
# differential_evolution step 1106: f(x)= 0.000101496
# differential_evolution step 1107: f(x)= 0.000101496
# differential_evolution step 1108: f(x)= 0.000101496
# differential_evolution step 1109: f(x)= 0.000101496
# differential_evolution step 1110: f(x)= 0.000101496
# differential_evolution step 1111: f(x)= 0.000101496
# differential_evolution step 1112: f(x)= 0.000101496
# differential_evolution step 1113: f(x)= 0.000101496
# differential_evolution step 1114: f(x)= 0.000101496
# differential_evolution step 1115: f(x)= 0.000101496
# differential_evolution step 1116: f(x)= 0.000101496
# differential_evolution step 1117: f(x)= 0.000101496
# differential_evolution step 1118: f(x)= 0.000101496
# differential_evolution step 1119: f(x)= 0.000101496
# differential_evolution step 1120: f(x)= 0.000101496
# differential_evolution step 1121: f(x)= 0.000101496
# differential_evolution step 1122: f(x)= 0.000101496
# differential_evolution step 1123: f(x)= 0.000101496
# differential_evolution step 1124: f(x)= 0.000101496
# differential_evolution step 1125: f(x)= 0.000101496
# differential_evolution step 1126: f(x)= 0.000101496
# differential_evolution step 1127: f(x)= 0.000101496
# differential_evolution step 1128: f(x)= 0.000101496
# differential_evolution step 1129: f(x)= 0.000101496
# differential_evolution step 1130: f(x)= 0.000101496
# differential_evolution step 1131: f(x)= 0.000101496
# differential_evolution step 1132: f(x)= 0.000101496
# differential_evolution step 1133: f(x)= 0.000101496
# differential_evolution step 1134: f(x)= 0.000101496
# differential_evolution step 1135: f(x)= 0.000101496
# differential_evolution step 1136: f(x)= 0.000101496
# differential_evolution step 1137: f(x)= 0.000101496
# differential_evolution step 1138: f(x)= 0.000101496
# differential_evolution step 1139: f(x)= 0.000101496
# differential_evolution step 1140: f(x)= 0.000101496
# differential_evolution step 1141: f(x)= 0.000101496
# differential_evolution step 1142: f(x)= 0.000101496
# differential_evolution step 1143: f(x)= 0.000101496
# differential_evolution step 1144: f(x)= 0.000101496
# differential_evolution step 1145: f(x)= 0.000101496
# differential_evolution step 1146: f(x)= 0.000101496
# differential_evolution step 1147: f(x)= 0.000101496
# differential_evolution step 1148: f(x)= 0.000101496
# differential_evolution step 1149: f(x)= 0.000101496
# differential_evolution step 1150: f(x)= 0.000101496
# differential_evolution step 1151: f(x)= 0.000101496
# differential_evolution step 1152: f(x)= 0.000101496
# differential_evolution step 1153: f(x)= 0.000101496
# differential_evolution step 1154: f(x)= 0.000101496
# differential_evolution step 1155: f(x)= 0.000101496
# differential_evolution step 1156: f(x)= 0.000101496
# differential_evolution step 1157: f(x)= 0.000101496
# differential_evolution step 1158: f(x)= 0.000101496
# differential_evolution step 1159: f(x)= 0.000101496
# differential_evolution step 1160: f(x)= 0.000101496
# differential_evolution step 1161: f(x)= 0.000101496
# differential_evolution step 1162: f(x)= 0.000101496
# differential_evolution step 1163: f(x)= 0.000101496
# differential_evolution step 1164: f(x)= 0.000101496
# differential_evolution step 1165: f(x)= 0.000101496
# differential_evolution step 1166: f(x)= 0.000101496
# differential_evolution step 1167: f(x)= 0.000101496
# differential_evolution step 1168: f(x)= 0.000101496
# differential_evolution step 1169: f(x)= 0.000101496
# differential_evolution step 1170: f(x)= 0.000101496
# differential_evolution step 1171: f(x)= 0.000101496
# differential_evolution step 1172: f(x)= 0.000101496
# differential_evolution step 1173: f(x)= 0.000101496
# differential_evolution step 1174: f(x)= 0.000101496
# differential_evolution step 1175: f(x)= 0.000101496
# differential_evolution step 1176: f(x)= 0.000101496
# differential_evolution step 1177: f(x)= 0.000101496
# differential_evolution step 1178: f(x)= 0.000101496
# differential_evolution step 1179: f(x)= 0.000101496
# differential_evolution step 1180: f(x)= 0.000101496
# differential_evolution step 1181: f(x)= 0.000101496
# differential_evolution step 1182: f(x)= 0.000101496
# differential_evolution step 1183: f(x)= 0.000101496
# differential_evolution step 1184: f(x)= 0.000101496
# differential_evolution step 1185: f(x)= 0.000101496
# differential_evolution step 1186: f(x)= 0.000101496
# differential_evolution step 1187: f(x)= 0.000101496
# differential_evolution step 1188: f(x)= 0.000101496
# differential_evolution step 1189: f(x)= 0.000101496
# differential_evolution step 1190: f(x)= 0.000101496
# differential_evolution step 1191: f(x)= 0.000101496
# differential_evolution step 1192: f(x)= 0.000101496
# differential_evolution step 1193: f(x)= 0.000101496
# differential_evolution step 1194: f(x)= 0.000101496
# differential_evolution step 1195: f(x)= 0.000101496
# differential_evolution step 1196: f(x)= 0.000101496
# differential_evolution step 1197: f(x)= 0.000101496
# differential_evolution step 1198: f(x)= 0.000101496
# differential_evolution step 1199: f(x)= 0.000101496
# differential_evolution step 1200: f(x)= 0.000101496
#  ->  360344  ->  False  ->  1.7057286572218253e-07
#      fun: 1.7057286572218253e-07
#      jac: array([-2.07145255e-06,  3.11477371e-06,  3.14750430e-06,  1.73227955e-06,
#         4.54540014e-07,  1.55961137e-06,  2.59927221e-07, -3.03384604e-06,
#        -4.78362368e-07,  2.92610654e-06])
#  message: 'Maximum number of iterations has been exceeded.'
#     nfev: 360344
#      nit: 1200
#  success: False
#        x: array([-3.15651136,  3.16409881,  3.16433691,  3.15404558, -3.13815215,
#         3.1527904 ,  3.14334436, -3.16351012, -3.14493181,  3.16272641])
